# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Инструкция/-На-календаре-1-ноября-2019-года,-в-бизнес-плане-заложено,-что-пользователи-должны-окупаться-не-позднее-чем-через-две-недели-после-привлечения." data-toc-modified-id="Инструкция/-На-календаре-1-ноября-2019-года,-в-бизнес-плане-заложено,-что-пользователи-должны-окупаться-не-позднее-чем-через-две-недели-после-привлечения.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Инструкция/ На календаре 1 ноября 2019 года, в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения.</a></span></li><li><span><a href="#Шаг-1.-Загрузка-и-подготовка-данных-к-анализу." data-toc-modified-id="Шаг-1.-Загрузка-и-подготовка-данных-к-анализу.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Шаг 1. Загрузка и подготовка данных к анализу.</a></span><ul class="toc-item"><li><span><a href="#Описание-данных." data-toc-modified-id="Описание-данных.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Описание данных.</a></span></li><li><span><a href="#Подготовка-данных-к-анализу." data-toc-modified-id="Подготовка-данных-к-анализу.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Подготовка данных к анализу.</a></span></li><li><span><a href="#Обзор-проведённой-подготовительной-работы." data-toc-modified-id="Обзор-проведённой-подготовительной-работы.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Обзор проведённой подготовительной работы.</a></span></li><li><span><a href="#Наблюдения-из-первичного-анализа-данных." data-toc-modified-id="Наблюдения-из-первичного-анализа-данных.-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Наблюдения из первичного анализа данных.</a></span></li></ul></li><li><span><a href="#Шаг-2.-Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии." data-toc-modified-id="Шаг-2.-Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Шаг 2. Функции для расчета и анализа LTV, ROI, удержания и конверсии.</a></span><ul class="toc-item"><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI." data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функции для расчета и анализа LTV, ROI.</a></span></li><li><span><a href="#Функции-для-расчета-и-анализа-удержания." data-toc-modified-id="Функции-для-расчета-и-анализа-удержания.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Функции для расчета и анализа удержания.</a></span></li><li><span><a href="#Функции-для-расчета-и-анализа-конверсии." data-toc-modified-id="Функции-для-расчета-и-анализа-конверсии.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Функции для расчета и анализа конверсии.</a></span></li><li><span><a href="#Функции-для-визуализации." data-toc-modified-id="Функции-для-визуализации.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Функции для визуализации.</a></span></li></ul></li><li><span><a href="#Шаг-3.-Проведём-исследовательский-анализ-данных." data-toc-modified-id="Шаг-3.-Проведём-исследовательский-анализ-данных.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Шаг 3. Проведём исследовательский анализ данных.</a></span><ul class="toc-item"><li><span><a href="#Создание-пользовательских-профилей.-Определение-минимальной-и-максимальной-дат-привлечения-пользователей." data-toc-modified-id="Создание-пользовательских-профилей.-Определение-минимальной-и-максимальной-дат-привлечения-пользователей.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Создание пользовательских профилей. Определение минимальной и максимальной дат привлечения пользователей.</a></span></li><li><span><a href="#Определим-страны,-из-которых-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей.-Создадим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-из-каждой-страны." data-toc-modified-id="Определим-страны,-из-которых-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей.-Создадим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-из-каждой-страны.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Определим страны, из которых пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Создадим таблицу, отражающую количество пользователей и долю платящих из каждой страны.</a></span></li><li><span><a href="#Узнаем,-какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи.-Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-устройства." data-toc-modified-id="Узнаем,-какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи.-Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-устройства.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Узнаем, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства.</a></span></li><li><span><a href="#Изучим-рекламные-источники-привлечения-и-определим-каналы,-из-которых-пришло-больше-всего-платящих-пользователей.-Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-канала-привлечения.-Напишем-промежуточные-выводы." data-toc-modified-id="Изучим-рекламные-источники-привлечения-и-определим-каналы,-из-которых-пришло-больше-всего-платящих-пользователей.-Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-канала-привлечения.-Напишем-промежуточные-выводы.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения. Напишем промежуточные выводы.</a></span></li><li><span><a href="#Выводы-по-исследовательскому-анализу." data-toc-modified-id="Выводы-по-исследовательскому-анализу.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Выводы по исследовательскому анализу.</a></span></li></ul></li><li><span><a href="#Шаг-4.-Маркетинг" data-toc-modified-id="Шаг-4.-Маркетинг-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Шаг 4. Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Посчитаем-общую-сумму-расходов-на-маркетинг.-Выясним,-как-траты-распределены-по-источникам.-Визуализируем-изменения-метрик-во-времени." data-toc-modified-id="Посчитаем-общую-сумму-расходов-на-маркетинг.-Выясним,-как-траты-распределены-по-источникам.-Визуализируем-изменения-метрик-во-времени.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Посчитаем общую сумму расходов на маркетинг. Выясним, как траты распределены по источникам. Визуализируем изменения метрик во времени.</a></span></li><li><span><a href="#Узнаем,-сколько-в-среднем-стоило-привлечение-одного-пользователя-из-каждого-источника.-Рассчитаем-средний-CAC-на-одного-пользователя-для-всего-проекта-и-для-каждого-источника-трафика.-Используем-профили-пользователей.-Напишем-промежуточные-выводы." data-toc-modified-id="Узнаем,-сколько-в-среднем-стоило-привлечение-одного-пользователя-из-каждого-источника.-Рассчитаем-средний-CAC-на-одного-пользователя-для-всего-проекта-и-для-каждого-источника-трафика.-Используем-профили-пользователей.-Напишем-промежуточные-выводы.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Узнаем, сколько в среднем стоило привлечение одного пользователя из каждого источника. Рассчитаем средний CAC на одного пользователя для всего проекта и для каждого источника трафика. Используем профили пользователей. Напишем промежуточные выводы.</a></span></li><li><span><a href="#Анализ-расходов-на-маркетинг." data-toc-modified-id="Анализ-расходов-на-маркетинг.-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Анализ расходов на маркетинг.</a></span></li></ul></li><li><span><a href="#Шаг-5.-Оценим-окупаемость-рекламы" data-toc-modified-id="Шаг-5.-Оценим-окупаемость-рекламы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Шаг 5. Оценим окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Проанализируем-общую-окупаемость-рекламы.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-общую-окупаемость-рекламы.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Проанализируем общую окупаемость рекламы. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI.-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по странам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-в-разбивке-по-устройствам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-окупаемость-рекламы-в-разбивке-по-устройствам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI.-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы в разбивке по устройствам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Построим-и-изучим-графики-конверсии-и-удержания-с-разбивкой-по-устройствам,-странам,-рекламным-каналам.-Получим-ответы-вопросы:" data-toc-modified-id="Построим-и-изучим-графики-конверсии-и-удержания-с-разбивкой-по-устройствам,-странам,-рекламным-каналам.-Получим-ответы-вопросы:-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Построим и изучим графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам. Получим ответы вопросы:</a></span></li><li><span><a href="#Выводы-по-окупаемости-рекламы." data-toc-modified-id="Выводы-по-окупаемости-рекламы.-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Выводы по окупаемости рекламы.</a></span></li></ul></li><li><span><a href="#ВЫВОДЫ-ПО-ВСЕМ-РАЗДЕЛАМ" data-toc-modified-id="ВЫВОДЫ-ПО-ВСЕМ-РАЗДЕЛАМ-7"><span class="toc-item-num">7&nbsp;&nbsp;</span><strong>ВЫВОДЫ ПО ВСЕМ РАЗДЕЛАМ</strong></a></span><ul class="toc-item"><li><span><a href="#Наблюдения-из-первичного-анализа-данных." data-toc-modified-id="Наблюдения-из-первичного-анализа-данных.-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Наблюдения из первичного анализа данных.</a></span></li><li><span><a href="#Выводы-по-исследовательскому-анализу." data-toc-modified-id="Выводы-по-исследовательскому-анализу.-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Выводы по исследовательскому анализу.</a></span></li><li><span><a href="#Анализ-расходов-на-маркетинг." data-toc-modified-id="Анализ-расходов-на-маркетинг.-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Анализ расходов на маркетинг.</a></span></li><li><span><a href="#Вывод-по-анализу-окупаемости." data-toc-modified-id="Вывод-по-анализу-окупаемости.-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Вывод по анализу окупаемости.</a></span></li><li><span><a href="#Финальный-анализ-данных-и-рекомендации." data-toc-modified-id="Финальный-анализ-данных-и-рекомендации.-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span><strong>Финальный анализ данных и рекомендации.</strong></a></span></li></ul></li></ul></div>

# %% [markdown]
# # "What are you looking for? Procrastinate Pro+?"

# %% [markdown]
# ## Инструкция/ На календаре 1 ноября 2019 года, в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения.
#
# **Шаг 1. Загрузите данные и подготовьте их к анализу.**
#
# 1.1. Положите данные о визитах, заказах и рекламных тратах в переменные.
#
# 1.2. Подготовьте данные к анализу. Убедитесь, что тип данных во всех колонках соответствует значениям. Проверьте отсутствие дубликатов.
#
# **Шаг 2. Задайте функции для расчета и анализа LTV, ROI, удержания и конверсии.**
#
# Разрешается использовать функции get_profiles(), get_retention(), get_conversion(), get_ltv(), а также plot_retention(), plot_conversion() и plot_ltv_roi(), с которыми вы познакомились в теоретических уроках.
#
# **Шаг 3. Проведите исследовательский анализ данных.**
#
# 3.1. Создайте пользовательские профили. Определите минимальную и максимальную даты привлечения пользователей.
#
# 3.2. Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
#
# 3.3. Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
#
# 3.4. Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
# Напишите промежуточные выводы.
#
# **Шаг 4. Маркетинг.**
#
# 4.1. Посчитайте общую сумму расходов на маркетинг. Выясните, как траты распределены по источникам. Визуализируйте изменения метрик во времени.
#
# 4.2. Узнайте, сколько в среднем стоило привлечение одного пользователя из каждого источника. Рассчитайте средний CAC на одного пользователя для всего проекта и для каждого источника трафика. Используйте профили пользователей.
# Напишите промежуточные выводы.
#
# **Шаг 5. Оцените окупаемость рекламы.**
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы.
#
# Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# 5.1. Проанализируйте общую окупаемость рекламы. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
# 5.2. Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
# 5.3. Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
# Опишите обнаруженные проблемы и напишите промежуточные выводы.
#
# 5.4. Постройте и изучите графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам.
# Ответьте на такие вопросы:
#
# •	Окупается ли реклама в целом?
#
# •	Какие устройства, страны и каналы могут снижать окупаемость рекламы?
#
# •	Чем могут быть вызваны проблемы окупаемости?
#
# Опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.
#
# **Шаг 6. Напишите выводы.**
#
# 6.1. Выделите причины неэффективности привлечения пользователей.
#
# 6.2. Сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# <a id = id_1></a>
# ## Шаг 1. Загрузка и подготовка данных к анализу.

# %% [markdown]
# ### Описание данных.
#
# В вашем распоряжении три датасета.
#
# visits_info_short.csv хранит лог сервера с информацией о посещениях сайта,
#
# orders_info_short.csv — информацию о покупках,
#
# costs_info_short.csv — информацию о расходах на рекламу.
#
# **Структура visits_info_short.csv**
#
# User Id — уникальный идентификатор пользователя,
# Region — страна пользователя,
# Device — тип устройства пользователя,
# Channel — идентификатор источника перехода,
# Session Start — дата и время начала сессии,
# Session End — дата и время окончания сессии.
#
# **Структура orders_info_short.csv**
#
# User Id — уникальный идентификатор пользователя,
# Event Dt — дата и время покупки,
# Revenue — сумма заказа.
#
# **Структура costs_info_short.csv**
# Channel — идентификатор рекламного источника,
# Dt — дата проведения рекламной кампании,
# Costs — расходы на эту кампанию.

# %%
#  импорт библиотек.
import pandas as pd
import numpy as np
import time
from datetime import datetime
from datetime import date, timedelta 
from matplotlib import pyplot as plt
import seaborn as sns
from tqdm import tqdm
# %matplotlib inline

# %%
#Снижает размерность чисел для вывода на экран на всем проекте + помогает с экспоненциальной записью чисел.
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ### Подготовка данных к анализу.

# %%
# Информацию о расходах на рекламу.
data_costs_info= pd.read_csv('/datasets/costs_info_short.csv')
data_costs_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
# Создам копию первичного датафрейма.
costs = data_costs_info.copy() 
costs
# Out:
#               dt         Channel  costs
# 0     2019-05-01        FaceBoom 113.30
# 1     2019-05-02        FaceBoom  78.10
# 2     2019-05-03        FaceBoom  85.80
# 3     2019-05-04        FaceBoom 136.40
# 4     2019-05-05        FaceBoom 122.10
# ...          ...             ...    ...
# 1795  2019-10-23  lambdaMediaAds   4.00
# 1796  2019-10-24  lambdaMediaAds   6.40
# 1797  2019-10-25  lambdaMediaAds   8.80
# 1798  2019-10-26  lambdaMediaAds   8.80
# 1799  2019-10-27  lambdaMediaAds  12.00
#
# [1800 rows x 3 columns]

# %%
# переименование столбцов.
costs = costs.rename(columns={'Channel': 'channel'})
costs
# Out:
#               dt         channel  costs
# 0     2019-05-01        FaceBoom 113.30
# 1     2019-05-02        FaceBoom  78.10
# 2     2019-05-03        FaceBoom  85.80
# 3     2019-05-04        FaceBoom 136.40
# 4     2019-05-05        FaceBoom 122.10
# ...          ...             ...    ...
# 1795  2019-10-23  lambdaMediaAds   4.00
# 1796  2019-10-24  lambdaMediaAds   6.40
# 1797  2019-10-25  lambdaMediaAds   8.80
# 1798  2019-10-26  lambdaMediaAds   8.80
# 1799  2019-10-27  lambdaMediaAds  12.00
#
# [1800 rows x 3 columns]

# %%
# преобразуем данные о времени.
costs['dt'] = pd.to_datetime(costs['dt'], format="%Y-%m-%d")
#канал приведем к строковому типу.
costs['channel'] = costs['channel'].astype('str')
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   datetime64[ns]
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 42.3+ KB

# %%
# поиск пропусков.
costs.isna().sum()
# Out:
# dt         0
# channel    0
# costs      0
# dtype: int64

# %%
# поиск дубликатов.
costs.duplicated(keep = False).sum()
# Out:
# 0

# %%
# ещё раз, на всякий случай.
costs.duplicated(['dt','costs'],keep = False).sum()
# Out:
# 12

# %%
duplicated_df = costs[costs.duplicated(['dt','costs'],keep = False)] #результат — датафрейм с дубликатами
print(duplicated_df)
# Out:
#              dt             channel  costs
# 268  2019-07-28        MediaTornado   4.32
# 304  2019-09-02        MediaTornado   5.04
# 323  2019-09-21        MediaTornado   6.48
# 336  2019-10-04        MediaTornado   6.96
# 808  2019-07-28             YRabbit   4.32
# 844  2019-09-02             YRabbit   5.04
# 863  2019-09-21             YRabbit   6.48
# 876  2019-10-04             YRabbit   6.96
# 981  2019-07-21          AdNonSense  10.50
# 1071 2019-10-19          AdNonSense  15.75
# 1341 2019-07-21  OppleCreativeMedia  10.50
# 1431 2019-10-19  OppleCreativeMedia  15.75

# %%
costs['dt'].value_counts()
# Out:
# 2019-10-10    10
# 2019-06-01    10
# 2019-08-30    10
# 2019-10-14    10
# 2019-06-12    10
#               ..
# 2019-05-24    10
# 2019-07-08    10
# 2019-08-22    10
# 2019-10-06    10
# 2019-08-26    10
# Name: dt, Length: 180, dtype: int64

# %%
costs.pivot_table(index ='dt', columns = 'channel', values = 'costs' , aggfunc = 'sum').T
# сводная таблица стоимости привления клиента по различным каналам по дням.
# Out:
# dt                  2019-05-01  2019-05-02  2019-05-03  2019-05-04  \
# channel
# AdNonSense               40.95       34.65       47.25       51.45
# FaceBoom                113.30       78.10       85.80      136.40
# LeapBob                   2.52        2.94        2.73        3.99
# MediaTornado              6.24        5.04        6.96        9.36
# OppleCreativeMedia        4.25        4.25        5.75        4.25
# RocketSuperAds           21.06       16.97       16.38       17.55
# TipTop                   80.00       55.00       64.00       70.00
# WahooNetBanner           10.80        7.20        8.40       10.80
# YRabbit                   8.10        9.90        9.00       15.60
# lambdaMediaAds           17.60       16.80       16.80       17.60
#
# dt                  2019-05-05  2019-05-06  2019-05-07  2019-05-08  \
# channel
# AdNonSense               36.75       43.05       30.45       37.80
# FaceBoom                122.10      118.80      101.20      100.10
# ...

# %%
m = costs.groupby(['channel'])['costs'].sum().sort_values(ascending=False)
m # Отсортированные в порядке убывания стоимости привлечения клиентов наименования источников трафика.
# Out:
# channel
# TipTop               54,751.30
# FaceBoom             32,445.60
# WahooNetBanner        5,151.00
# AdNonSense            3,911.25
# OppleCreativeMedia    2,151.25
# RocketSuperAds        1,833.00
# LeapBob               1,797.60
# lambdaMediaAds        1,557.60
# MediaTornado            954.48
# YRabbit                 944.22
# Name: costs, dtype: float64

# %% [markdown]
# 1. Создан датафрейм costs, являющийся копией data_costs_info, в который вносятся изменения и он же применяется в работе. costs содержит 1800 строк и 3 столбца.
# 2. Переименование: 'Channel' = 'channel'.
# 3. Замена типа данных в столбце 'dt' произведена. Пропуски и дубликаты не выявлены.
# 4. Таблица содержит сведения о 180 днях и 10 платформах для привлечения клиентов.
# 5. Тройка самых дорогих представлена ниже:
#
# TipTop               54,751
#
# FaceBoom             32,445
#
# WahooNetBanner        5,151

# %%
# Информацию о покупках.
data_orders_info =  pd.read_csv('/datasets/orders_info_short.csv')
data_orders_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
# Создам копию первичного датафрейма.
orders = data_orders_info.copy() 
orders
# Out:
#             User Id             Event Dt  Revenue
# 0      188246423999  2019-05-01 23:09:52     4.99
# 1      174361394180  2019-05-01 12:24:04     4.99
# 2      529610067795  2019-05-01 11:34:04     4.99
# 3      319939546352  2019-05-01 15:34:40     4.99
# 4      366000285810  2019-05-01 13:59:51     4.99
# ...             ...                  ...      ...
# 40207  651604369137  2019-10-31 16:19:07     4.99
# 40208  275341387049  2019-10-31 01:17:17     4.99
# 40209  374656616484  2019-10-31 06:17:29     4.99
# 40210  168548862926  2019-10-31 22:46:19     4.99
# 40211  329994900775  2019-10-31 13:29:06     4.99
#
# [40212 rows x 3 columns]

# %%
# переименование столбцов.
orders = orders.rename(columns={'User Id': 'user_id', 'Event Dt': 'event_dt', 'Revenue': 'revenue'})
orders
# Out:
#             user_id             event_dt  revenue
# 0      188246423999  2019-05-01 23:09:52     4.99
# 1      174361394180  2019-05-01 12:24:04     4.99
# 2      529610067795  2019-05-01 11:34:04     4.99
# 3      319939546352  2019-05-01 15:34:40     4.99
# 4      366000285810  2019-05-01 13:59:51     4.99
# ...             ...                  ...      ...
# 40207  651604369137  2019-10-31 16:19:07     4.99
# 40208  275341387049  2019-10-31 01:17:17     4.99
# 40209  374656616484  2019-10-31 06:17:29     4.99
# 40210  168548862926  2019-10-31 22:46:19     4.99
# 40211  329994900775  2019-10-31 13:29:06     4.99
#
# [40212 rows x 3 columns]

# %%
# преобразуем данные о времени.
orders['event_dt'] = pd.to_datetime(orders['event_dt'], format="%Y-%m-%d")
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %%
# поиск пропусков.
orders.isna().sum()
# Out:
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64

# %%
# поиск дубликатов.
orders.duplicated(keep = False).sum()
# Out:
# 0

# %%
# ещё раз, на всякий случай.
orders.duplicated(['user_id','event_dt','revenue'],keep = False).sum()
# Out:
# 0

# %%
# определю количество уникальных пользователей.
orders['user_id'].nunique()
# Out:
# 8881

# %%
# просмотрим суммы выручки.
n = orders.groupby(['user_id'])['revenue'].sum().sort_values(ascending=False)
n
# Out:
# user_id
# 905723035964   149.88
# 649616333931   140.90
# 897756565239   134.82
# 641347422979   131.83
# 547684681026   129.83
#                 ...
# 499675789107     4.99
# 499931699698     4.99
# 46006712         4.99
# 500328626970     4.99
# 999895427370     4.99
# Name: revenue, Length: 8881, dtype: float64

# %%
# сколько повторений 4,99?
orders.loc[orders.loc[:,'revenue'] == 4.99].count()
# Out:
# user_id     38631
# event_dt    38631
# revenue     38631
# dtype: int64

# %%
# общая сумма заказов
print('Сумма заказов за весь период исследования:', orders['revenue'].sum())
# Out:
# Сумма заказов за весь период исследования: 215962.88

# %% [markdown]
# 1. Создан датафрейм orders, являющийся копией data_orders_info, в который вносятся изменения и он же применяется в работе. data_orders содержит 40212 строк и 3 столбца.
# 2. Заголовки переименованы: 'User Id'='user_id', 'Event Dt'='event_date', 'Revenue'='revenue'.
# 3. Замена типа данных в столбце 'event_date' произведена. Пропуски и дубликаты не выявлены.
# 4. Датафрейм содержит информацию о 8881 заказе пользователей. Самая крупная сумма заказа 149,88. Сумма 4,99 повторилась свыше 38000 раз, это, наверно, стоимость подписки, или иной аналогичный платёж.

# %%
# посещениях сайта.
data_visits_info =  pd.read_csv('/datasets/visits_info_short.csv')

# %%
# Создам копию первичного датафрейма.
visits = data_visits_info.copy() 
visits
# Out:
#              User Id         Region   Device         Channel  \
# 0       981449118918  United States   iPhone         organic
# 1       278965908054  United States   iPhone         organic
# 2       590706206550  United States      Mac         organic
# 3       326433527971  United States  Android          TipTop
# 4       349773784594  United States      Mac         organic
# ...              ...            ...      ...             ...
# 309896  329994900775             UK       PC         LeapBob
# 309897  334903592310         France       PC  lambdaMediaAds
# 309898  540102010126        Germany       PC         organic
# 309899  308736936846        Germany      Mac         organic
# 309900  109329042535        Germany       PC  lambdaMediaAds
#
#               Session Start          Session End
# 0       2019-05-01 02:36:01  2019-05-01 02:45:01
# 1       2019-05-01 04:46:31  2019-05-01 04:47:35
# 2       2019-05-01 14:09:25  2019-05-01 15:32:08
# ...

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
# переименование столбцов.
visits = visits.rename(
    columns={'User Id': 'user_id', 'Region': 'region', 'Device': 'device', 
                                          'Channel': 'channel', 'Session Start': 'session_start',
            'Session End': 'session_end'}
)
visits
# Out:
#              user_id         region   device         channel  \
# 0       981449118918  United States   iPhone         organic
# 1       278965908054  United States   iPhone         organic
# 2       590706206550  United States      Mac         organic
# 3       326433527971  United States  Android          TipTop
# 4       349773784594  United States      Mac         organic
# ...              ...            ...      ...             ...
# 309896  329994900775             UK       PC         LeapBob
# 309897  334903592310         France       PC  lambdaMediaAds
# 309898  540102010126        Germany       PC         organic
# 309899  308736936846        Germany      Mac         organic
# 309900  109329042535        Germany       PC  lambdaMediaAds
#
#               session_start          session_end
# 0       2019-05-01 02:36:01  2019-05-01 02:45:01
# 1       2019-05-01 04:46:31  2019-05-01 04:47:35
# 2       2019-05-01 14:09:25  2019-05-01 15:32:08
# ...

# %%
# преобразуем данные о времени.
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %%
# поиск пропусков.
visits.isna().sum()
# Out:
# user_id          0
# region           0
# device           0
# channel          0
# session_start    0
# session_end      0
# dtype: int64

# %%
# поиск дубликатов.
visits.duplicated(keep = False).sum()
# Out:
# 0

# %%
# ещё раз, на всякий случай.
visits.duplicated(['user_id','region','device'],keep = False).sum()
# Out:
# 229862

# %%
# ещё проверка.
visits.duplicated(['user_id','session_start','session_end'],keep = False).sum()
# Out:
# 0

# %% [markdown]
# Совпадение является неполным, так как отличаются временные показатели

# %%
# случайный пример для иллюстрации.
visits.loc[visits['user_id'] == 540102010126]
# Out:
#              user_id   region device  channel       session_start  \
# 308655  540102010126  Germany     PC  organic 2019-10-27 04:03:43
# 309898  540102010126  Germany     PC  organic 2019-10-31 01:40:48
#
#                session_end
# 308655 2019-10-27 04:09:59
# 309898 2019-10-31 01:41:31

# %%
print('Всего уникальных пользователей за исследуемый период - ',visits['user_id'].nunique())
# Out:
# Всего уникальных пользователей за исследуемый период -  150008

# %%
print('Всего уникальных стран за исследуемый период - ',visits['region'].nunique())
# Out:
# Всего уникальных стран за исследуемый период -  4

# %%
# количество сессий для каждого региона.
visits['region'].value_counts()
# Out:
# United States    207327
# UK                36419
# France            35396
# Germany           30759
# Name: region, dtype: int64

# %%
# дооля сессий для каждого региона в общем объёме.
(visits.groupby(visits['region']).size() / len(visits['region'])).to_frame().style.format('{:.2%}')
# Out:
# <style  type="text/css" >
# </style><table id="T_e7d1e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e7d1e_level0_row0" class="row_heading level0 row0" >France</th>
#                         <td id="T_e7d1e_row0_col0" class="data row0 col0" >11.42%</td>
#             </tr>
#             <tr>
#                         <th id="T_e7d1e_level0_row1" class="row_heading level0 row1" >Germany</th>
#                         <td id="T_e7d1e_row1_col0" class="data row1 col0" >9.93%</td>
#             </tr>
#             <tr>
#                         <th id="T_e7d1e_level0_row2" class="row_heading level0 row2" >UK</th>
#                         <td id="T_e7d1e_row2_col0" class="data row2 col0" >11.75%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# Больше всего посещений приходится на жителей из США. Наименее активны пользователи из Германии.

# %%
# доля устройств, применяемых пользователями.
(visits.groupby(visits['device']).size() / len(visits['device'])).to_frame().style.format('{:.2%}')
# Out:
# <style  type="text/css" >
# </style><table id="T_90873_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_90873_level0_row0" class="row_heading level0 row0" >Android</th>
#                         <td id="T_90873_row0_col0" class="data row0 col0" >23.42%</td>
#             </tr>
#             <tr>
#                         <th id="T_90873_level0_row1" class="row_heading level0 row1" >Mac</th>
#                         <td id="T_90873_row1_col0" class="data row1 col0" >20.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_90873_level0_row2" class="row_heading level0 row2" >PC</th>
#                         <td id="T_90873_row2_col0" class="data row2 col0" >20.23%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# Больше всего посещений приходится на пользователей iPhone. Наименее активны пользователи Mac.

# %%
(visits.groupby(visits['channel']).size() / len(visits['channel'])).to_frame().style.format('{:.2%}')
# Out:
# <style  type="text/css" >
# </style><table id="T_76133_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_76133_level0_row0" class="row_heading level0 row0" >AdNonSense</th>
#                         <td id="T_76133_row0_col0" class="data row0 col0" >2.22%</td>
#             </tr>
#             <tr>
#                         <th id="T_76133_level0_row1" class="row_heading level0 row1" >FaceBoom</th>
#                         <td id="T_76133_row1_col0" class="data row1 col0" >15.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_76133_level0_row2" class="row_heading level0 row2" >LeapBob</th>
#                         <td id="T_76133_row2_col0" class="data row2 col0" >5.49%</td>
#             </tr>
# ...

# %% [markdown]
# Отметим, что наибольшая часть пользователей приходила через канал "organic", т.е. попадали на сайт или лендинг из результатов обычной поисковой выдачи, а не с рекламных объявлений.
#
# На втором месте канал TipTop, далее FaceBoom

# %% [markdown]
# 1.Создан датафрейм visits, являющийся копией data_visits_info, в который вносятся изменения и он же применяется в работе. data_visits содержит 309901 строк и 6 столбца.
#
# 2.Заголовки переименованы: 'User Id'='user_id', 'Region'='region', 'Device'='device', 'Channel'='channel', 'Session Start'= 'session_start', 'Session End'= 'session_end'.
#
# 3.Замена типа данных в столбцах 'session_start', 'session_end' произведена. Пропуски и дубликаты не выявлены.

# %% [markdown]
# ### Обзор проведённой подготовительной работы.
#
# **Описание данных**
#
# В вашем распоряжении три датасета.
#
# **visits_info_short.csv** хранит лог сервера с информацией о посещениях сайта,
#
# **orders_info_short.csv**— информацию о покупках,
#
# **costs_info_short.csv** — информацию о расходах на рекламу.
#
# **Структура visits_info_short.csv**
#
# User Id — уникальный идентификатор пользователя,
# Region — страна пользователя,
# Device — тип устройства пользователя,
# Channel — идентификатор источника перехода,
# Session Start — дата и время начала сессии,
# Session End — дата и время окончания сессии.
#
# **Структура orders_info_short.csv**
#
# User Id — уникальный идентификатор пользователя,
# Event Dt — дата и время покупки,
# Revenue — сумма заказа.
#
# **Структура costs_info_short.csv**
# Channel — идентификатор рекламного источника,
# Dt — дата проведения рекламной кампании,
# Costs — расходы на эту кампанию.
#
# 1.1. Создан датафрейм **costs, являющийся копией data_costs_info**, в который вносятся изменения и он же применяется в работе. costs содержит 1800 строк и 3 столбца.
#
# 1.2. Переименование: 'Channel' = 'channel'.
#
# 1.3. Замена типа данных в столбце 'dt' произведена. Пропуски и дубликаты не выявлены.
#
# 1.4 Создан датафрейм **orders, являющийся копией data_orders_info,** в который вносятся изменения и он же применяется в работе. data_orders содержит 40212 строк и 3 столбца.
#
# 1.6. Заголовки переименованы: 'User Id'='user_id', 'Event Dt'='event_date', 'Revenue'='revenue'.
#
# 1.7. Замена типа данных в столбце 'event_date' произведена. Пропуски и дубликаты не выявлены.
#
# 1.8.Создан датафрейм visits, являющийся копией data_visits_info, в который вносятся изменения и он же применяется в работе. data_visits содержит 309901 строк и 6 столбца.
#
# 1.9.Заголовки переименованы: 'User Id'='user_id', 'Region'='region', 'Device'='device', 'Channel'='channel', 'Session Start'= 'session_start', 'Session End'= 'session_end'.
#
# 1.10.Замена типа данных в столбцах 'session_start', 'session_end' произведена. Пропуски и дубликаты не выявлены.
#
#
# ### Наблюдения из первичного анализа данных.
#
# Информация, представленная для анализа:
#
# содержит данные о 8881 заказе пользователей. **Самая крупная сумма заказа 149,88. Сумма 4,99 повторилась свыше 38000 раз, это, наверно, стоимость подписки, или иной аналогичный платёж**;
#
# содержит сведения о 180 днях и 10 платформах для привлечения клиентов.
#
# **Тройка самых дорогих каналов** представлена ниже:
#
# **TipTop               54,751**
#
# **FaceBoom             32,445**
#
# **WahooNetBanner        5,151**
#
# Всего уникальных пользователей за исследуемый период -  150008
#
# **Больше всего посещений приходится на пользователей iPhone**. Таблица популярности устройств представлена ниже:
#
# iPhone	36.34%
#
# Android	23.42%
#
# PC	20.23%
#
# Mac	20.01%
#
# **Больше всего посещений приходится на жителей из США.** Таблица данных по странам ниже:
#
# United States	66.90%
#
# UK	11.75%
#
# France	11.42%
#
# Germany	9.93%
#
# Отмечу, что **наибольшая часть пользователей приходила через канал "organic"**, т.е. попадали на сайт или лендинг из результатов обычной поисковой выдачи, а не с рекламных объявлений.
#
# **На втором месте по привлечению потока - канал TipTop, далее FaceBoom**

# %% [markdown]
# ## Шаг 2. Функции для расчета и анализа LTV, ROI, удержания и конверсии.

# %% [markdown]
# ### Функции для расчета и анализа LTV, ROI.

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функции для расчета и анализа удержания.

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функции для расчета и анализа конверсии.

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функции для визуализации.

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.legend(bbox_to_anchor=(1.3, 1))
    plt.show()

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    plt.legend(bbox_to_anchor=(1.3, 1))
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.legend(bbox_to_anchor=(1.3, 1))
    plt.show()

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['dt'] = pd.to_datetime(profiles['dt'], format="%Y-%m-%d")
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())


    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# LTV, или Lifetime Value, — это «пожизненная ценность» клиента, то есть общая сумма денег, которую один клиент в среднем приносит компании со всех своих покупок. В теории эта метрика включает все прошлые, нынешние и будущие покупки пользователя. На практике чаще анализируют LTV за определённый срок — первые 1, 3, 7 и 14 дней после регистрации.
#
# Задача компании — найти такие рекламные источники, которые привлекут пользователей с LTV, в несколько раз превышающим CAC. В таких случаях ROI будет намного выше единицы.
#
# LTV и ROI никогда не снижаются.

# %% [markdown]
# ## Шаг 3. Проведём исследовательский анализ данных.

# %% [markdown]
# <a id = id_1></a>
# ### Создание пользовательских профилей. Определение минимальной и максимальной дат привлечения пользователей.

# %%
profiles = get_profiles(visits, orders, costs)
display(profiles.head(5))
# Out:
#     user_id            first_ts     channel  device         region         dt  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States 2019-05-07
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States 2019-07-09
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France 2019-10-01
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany 2019-08-22
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States 2019-10-02
#
#        month  payer  acquisition_cost
# 0 2019-05-01   True              1.09
# 1 2019-07-01  False              1.11
# 2 2019-10-01  False              0.00
# 3 2019-08-01  False              0.99
# 4 2019-10-01  False              0.23

# %%
# доступный интервал привлечения пользователей
min_analysis_date = profiles['dt'].min()
observation_date = profiles['dt'].max()  # момент анализа

# %%
print('Минимальная дата привлечения пользователей', min_analysis_date)
# Out:
# Минимальная дата привлечения пользователей 2019-05-01 00:00:00

# %%
print('Максимальная дата привлечения пользователей',observation_date)
# Out:
# Максимальная дата привлечения пользователей 2019-10-27 00:00:00

# %% [markdown]
# **Результат по 4.1**:
#
# Минимальная дата привлечения пользователей 2019-05-01.
#
# Максимальная дата привлечения пользователей 2019-10-27.
#
# В представленных датафреймах находятся данные за необходимый преиод времени

# %% [markdown]
# <a id = id_1></a>
# ### Определим страны, из которых пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Создадим таблицу, отражающую количество пользователей и долю платящих из каждой страны.

# %%
# опредение уникальных стран
profiles['region'].value_counts()
# Out:
# United States    100002
# UK                17575
# France            17450
# Germany           14981
# Name: region, dtype: int64

# %%
# доля отдельныч стран
(profiles.groupby(profiles['region']).size() / len(profiles['region'])).to_frame().style.format('{:.2%}')
# Out:
# <style  type="text/css" >
# </style><table id="T_d70e7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d70e7_level0_row0" class="row_heading level0 row0" >France</th>
#                         <td id="T_d70e7_row0_col0" class="data row0 col0" >11.63%</td>
#             </tr>
#             <tr>
#                         <th id="T_d70e7_level0_row1" class="row_heading level0 row1" >Germany</th>
#                         <td id="T_d70e7_row1_col0" class="data row1 col0" >9.99%</td>
#             </tr>
#             <tr>
#                         <th id="T_d70e7_level0_row2" class="row_heading level0 row2" >UK</th>
#                         <td id="T_d70e7_row2_col0" class="data row2 col0" >11.72%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# Пользователи, зарегистрированные в США, занимают 66,7% от общего объёма.

# %% [markdown]
# **Покупатели == платящие пользователи**

# %%
country = profiles.query('payer==True') # выборка из profiles по покупателям
country.groupby('region')['user_id'].nunique() # уникальные покупатели из каждой страны
# Out:
# region
# France            663
# Germany           616
# UK                700
# United States    6902
# Name: user_id, dtype: int64

# %% [markdown]
# Пользователи, зарегистрированные в США, занимают 66,7% от общего объёма.

# %% [markdown]
# **Создадим таблицу, отражающую количество пользователей и долю платящих из каждой страны.¶**

# %%
country_pay = pd.DataFrame() # создаю пустой датафрейм и наполняю столбцами
# данный столбец отразит количество уникальных пользователей
country_pay['Пользователи'] = profiles.groupby('region')['user_id'].count()
# данный столбец отразит долю уникальных пользователей из каждой страны
country_pay['Пользователи,%'] = country_pay['Пользователи'] / profiles['region'].count() * 100
country_pay.style.format({'Пользователи': '{:.2f}%'})
# данный столбец отразит количество уникальных покупателей
country_pay['Покупатели'] = country.groupby('region')['user_id'].nunique()
# данный столбец отразит долю уникальных покупателей из каждой страны
country_pay['Покупатели,%'] = country_pay['Покупатели']/profiles.groupby('region')['user_id'].count()*100
country_pay.sort_values(by='Пользователи', ascending=False)
# Out:
#                Пользователи  Пользователи,%  Покупатели  Покупатели,%
# region
# United States        100002           66.66        6902          6.90
# UK                    17575           11.72         700          3.98
# France                17450           11.63         663          3.80
# Germany               14981            9.99         616          4.11

# %% [markdown]
# **Страны, из которых пользователи приходят в приложение:**
#
# США, Великобритания, Франция и Германия.
#
# **Наибольшая активность у пользователей из США.**
#
# **Наименьшая активность у представителей Германии.**

# %% [markdown]
# <a id = id_1></a>
# ### Узнаем, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства.

# %%
profiles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150008 entries, 0 to 150007
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           150008 non-null  int64
#  1   first_ts          150008 non-null  datetime64[ns]
#  2   channel           150008 non-null  object
#  3   device            150008 non-null  object
#  4   region            150008 non-null  object
#  5   dt                150008 non-null  datetime64[ns]
#  6   month             150008 non-null  datetime64[ns]
#  7   payer             150008 non-null  bool
#  8   acquisition_cost  150008 non-null  float64
# dtypes: bool(1), datetime64[ns](3), float64(1), int64(1), object(3)
# memory usage: 10.4+ MB

# %%
profiles['device'].value_counts()
# Out:
# iPhone     54479
# Android    35032
# PC         30455
# Mac        30042
# Name: device, dtype: int64

# %%
(profiles.groupby(profiles['device']).size() / len(profiles['device'])).to_frame().style.format('{:.2%}')
# Out:
# <style  type="text/css" >
# </style><table id="T_c220f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c220f_level0_row0" class="row_heading level0 row0" >Android</th>
#                         <td id="T_c220f_row0_col0" class="data row0 col0" >23.35%</td>
#             </tr>
#             <tr>
#                         <th id="T_c220f_level0_row1" class="row_heading level0 row1" >Mac</th>
#                         <td id="T_c220f_row1_col0" class="data row1 col0" >20.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_c220f_level0_row2" class="row_heading level0 row2" >PC</th>
#                         <td id="T_c220f_row2_col0" class="data row2 col0" >20.30%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# Самое популярное устройство - iPhone

# %%
country = profiles.query('payer==True')
country.groupby('device')['user_id'].nunique()
# Out:
# device
# Android    2050
# Mac        1912
# PC         1537
# iPhone     3382
# Name: user_id, dtype: int64

# %% [markdown]
# Тенденция популярности iPhone сохранилась и у тех, кто оплачивает свои заказы

# %% [markdown]
# **Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства.**

# %%
device_pay = pd.DataFrame() # создаю пустой датафрейм и наполняю столбцами
# данный столбец отразит количество устройств, через которые осуществляют доступ уникальные пользователи
device_pay['Устройства'] = profiles.groupby('device')['user_id'].count()
# данный столбец отразит долю устройств для всех пользователей
device_pay['Устройства,%'] = device_pay['Устройства'] / profiles['device'].count() * 100
device_pay.style.format({'Устройства,%': '{:.2f}%'})
# Out:
# <style  type="text/css" >
# </style><table id="T_7c788_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Устройства</th>        <th class="col_heading level0 col1" >Устройства,%</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7c788_level0_row0" class="row_heading level0 row0" >Android</th>
#                         <td id="T_7c788_row0_col0" class="data row0 col0" >35032</td>
#                         <td id="T_7c788_row0_col1" class="data row0 col1" >23.35%</td>
#             </tr>
#             <tr>
#                         <th id="T_7c788_level0_row1" class="row_heading level0 row1" >Mac</th>
#                         <td id="T_7c788_row1_col0" class="data row1 col0" >30042</td>
# ...

# %%
# данный столбец отразит количество уникальных покупателей
device_pay['Устройства покупателей'] = country.groupby('device')['user_id'].nunique()
# данный столбец отразит долю устройства, через которое происходит доступ уникальных покупателей 
device_pay['Устройства покупателей,%'] = device_pay['Устройства покупателей']/profiles.groupby('device')['user_id'].count()*100
device_pay.sort_values(by='Устройства покупателей', ascending=False)
# Out:
#          Устройства  Устройства,%  Устройства покупателей  \
# device
# iPhone        54479         36.32                    3382
# Android       35032         23.35                    2050
# Mac           30042         20.03                    1912
# PC            30455         20.30                    1537
#
#          Устройства покупателей,%
# device
# iPhone                       6.21
# Android                      5.85
# Mac                          6.36
# PC                           5.05

# %% [markdown]
# **Устройства, которыми пользуются клиенты и устройства, предпочитаемые покупателями.**
#
# Android, Mac, PC, iPhone.
#
# **Предпочитаемым устройством является iPhone как для пользователей, так и для покупателей.**

# %% [markdown]
# <a id = id_1></a>
# ### Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения. Напишем промежуточные выводы.

# %%
channel_pay = pd.DataFrame() # создаю пустой датафрейм и наполняю столбцами
# данный столбец отразит количество уникальных пользователей, пришедщих через канал
channel_pay['Источник'] = profiles.groupby('channel')['user_id'].count()
# данный столбец отразит долю уникальных пользователей из каждого канала
channel_pay['Доля источника,%'] = channel_pay['Источник'] / profiles['channel'].count() * 100
channel_pay.style.format({'Доля источника,%': '{:.2f}%'})
channel_pay.sort_values(by='Источник', ascending=False)
# Out:
#                     Источник  Доля источника,%
# channel
# organic                56439             37.62
# FaceBoom               29144             19.43
# TipTop                 19561             13.04
# OppleCreativeMedia      8605              5.74
# LeapBob                 8553              5.70
# WahooNetBanner          8553              5.70
# RocketSuperAds          4448              2.97
# MediaTornado            4364              2.91
# YRabbit                 4312              2.87
# AdNonSense              3880              2.59
# lambdaMediaAds          2149              1.43

# %%
# данный столбец отразит количество уникальных покупателей
channel_pay['Канал покупателей'] = country.groupby('channel')['user_id'].nunique()
# данный столбец отразит долю устройства, через которое происходит доступ уникальных покупателей 
channel_pay['Доля канала покупателей,%'] = channel_pay['Канал покупателей']/profiles.groupby('channel')['user_id'].count()*100
channel_pay.sort_values(by='Доля канала покупателей,%', ascending=False)
# Out:
#                     Источник  Доля источника,%  Канал покупателей  \
# channel
# FaceBoom               29144             19.43               3557
# AdNonSense              3880              2.59                440
# lambdaMediaAds          2149              1.43                225
# TipTop                 19561             13.04               1878
# RocketSuperAds          4448              2.97                352
# WahooNetBanner          8553              5.70                453
# YRabbit                 4312              2.87                165
# MediaTornado            4364              2.91                156
# LeapBob                 8553              5.70                262
# OppleCreativeMedia      8605              5.74                233
# organic                56439             37.62               1160
#
#                     Доля канала покупателей,%
# channel
# FaceBoom                                12.20
# AdNonSense                              11.34
# ...

# %% [markdown]
# **Рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей.**
#
# 1. Значительный поток пользователей приходит через органический канал, то есть аудитории известно о наличии развлекательного приложения Procrastinate Pro+, однако, недостаточно сведений о нём и пользователи самостоятельно производят поиск информации. Несмотря на то, что треть всего трафика приходится на "органический", лишь 2% становятся покупателями.
#
# 2. Самыми дорогими с точки зрения вложений являются
#
# TipTop, при этом только 13% общего трафика и доля пользователей, ставших покупателями - 9,6%.
#
# FaceBoom - 19% общего трафика и доля пользователей, ставших покупателями - 12,2% (максимум из списка).
#
# WahooNetBanner - 5,7% общего трафика и доля пользователей, ставших покупателями - 5,3% (максимум в % отношении).
#
# 3. AdNonSense, lambdaMediaAds занимают лишь 2,6 % и 1,4% от объёма трафика соответственно, но доля пользователей, совершивших покупку через эти каналы, велика - 11,3% и 10,5%.

# %% [markdown]
# ### Выводы по исследовательскому анализу.
#
# **Страны, из которых пользователи приходят в приложение:**
#
# США, Великобритания, Франция и Германия.
#
# **Наибольшая активность у пользователей из США.**
#
# **Наименьшая активность у представителей Германии.**
#
# **Устройства, которыми пользуются клиенты и устройства, предпочитаемые покупателями.**
#
# Android, Mac, PC, iPhone.
#
# **Предпочитаемым устройством является iPhone как для пользователей, так и для покупателей.**
#
# **Рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей.**
#
# 1. Значительный поток пользователей приходит через органический канал, то есть аудитории известно о наличии развлекательного приложения Procrastinate Pro+, однако, недостаточно сведений о нём и пользователи самостоятельно производят поиск информации. Несмотря на то, что треть всего трафика приходится на "органический", лишь 2% становятся покупателями.
#
# 2. Самыми дорогими с точки зрения вложений являются
#
# TipTop, при этом только 13% общего трафика и доля пользователей, ставших покупателями - 9,6%.
#
# FaceBoom - 19% общего трафика и доля пользователей, ставших покупателями - 12,2% (максимум из списка).
#
# WahooNetBanner - 5,7% общего трафика и доля пользователей, ставших покупателями - 5,3% (максимум в % отношении).
#
# 3. AdNonSense, lambdaMediaAds занимают лишь 2,6 % и 1,4% от объёма трафика соответственно, но доля пользователей, совершивших покупку через эти каналы, велика - 11,3% и 10,5%.

# %%
(profiles
    .pivot_table(index='channel', values='payer', aggfunc=['sum', 'count', 'mean'])
    .reset_index()
    .rename(columns={'count': 'all_users','sum':'paying_users', 'mean': 'ratio'})
    .droplevel(1,axis=1) 
    .sort_values(by='ratio', ascending=False) 
    .style.format({'ratio': '{:.2%}'})
)
# Out:
# <style  type="text/css" >
# </style><table id="T_0b321_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >channel</th>        <th class="col_heading level0 col1" >paying_users</th>        <th class="col_heading level0 col2" >all_users</th>        <th class="col_heading level0 col3" >ratio</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0b321_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_0b321_row0_col0" class="data row0 col0" >FaceBoom</td>
#                         <td id="T_0b321_row0_col1" class="data row0 col1" >3557</td>
#                         <td id="T_0b321_row0_col2" class="data row0 col2" >29144</td>
#                         <td id="T_0b321_row0_col3" class="data row0 col3" >12.20%</td>
#             </tr>
#             <tr>
#                         <th id="T_0b321_level0_row1" class="row_heading level0 row1" >0</th>
# ...

# %% [markdown]
# ## Шаг 4. Маркетинг

# %% [markdown]
# ### Посчитаем общую сумму расходов на маркетинг. Выясним, как траты распределены по источникам. Визуализируем изменения метрик во времени.

# %%
display(profiles)
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %% [markdown]
# **общая сумма расходов на маркетинг**

# %%
np.ceil(profiles['acquisition_cost'].sum()) # из profiles
# Out:
# 105498.0

# %%
costs.describe()
# Out:
#          costs
# count 1,800.00
# mean     58.61
# std     107.74
# min       0.80
# 25%       6.50
# 50%      12.29
# 75%      33.60
# max     630.00

# %%
np.ceil(costs['costs'].sum()) # из costs
# Out:
# 105498.0

# %% [markdown]
# **Общая сумма расходов на маркетинг составила 105 498 у.е.**

# %%
ad = profiles.groupby('channel')['acquisition_cost'].sum()
ad.sort_values(ascending=False)
# Out:
# channel
# TipTop               54,751.30
# FaceBoom             32,445.60
# WahooNetBanner        5,151.00
# AdNonSense            3,911.25
# OppleCreativeMedia    2,151.25
# RocketSuperAds        1,833.00
# LeapBob               1,797.60
# lambdaMediaAds        1,557.60
# MediaTornado            954.48
# YRabbit                 944.22
# organic                   0.00
# Name: acquisition_cost, dtype: float64

# %%
# расходы в %
traf_cost = (profiles.groupby('channel')['acquisition_cost'].sum()/profiles['acquisition_cost'].sum())
traf_cost.sort_values(ascending = False)
# Out:
# channel
# TipTop               0.52
# FaceBoom             0.31
# WahooNetBanner       0.05
# AdNonSense           0.04
# OppleCreativeMedia   0.02
# RocketSuperAds       0.02
# LeapBob              0.02
# lambdaMediaAds       0.01
# MediaTornado         0.01
# YRabbit              0.01
# organic              0.00
# Name: acquisition_cost, dtype: float64

# %%
# построим график для оценки вложений в отдельные источники:
ad.plot.bar();
plt.title('Общие расходы на маркетинг канала', fontsize=20)
plt.xlabel('источник')
plt.ylabel('у.е.')
plt.legend()
plt.xticks(rotation=75);

# %% [markdown]
# Самыми дорогими с точки зрения вложений являются TipTop и FaceBoom. Остальные каналы даже близко не подходят к лидерам по объёму расходов. Данные направления являются наиболее перспективными на взгляд маркетологов.

# %% [markdown]
# **ДИНАМИКА РАСХОДОВ НА ПРИВЛЕЧЕНИЕ КЛИЕНТОВ В РАЗРЕЗЕ ВРЕМЕНИ**

# %%
# Сводная таблица для выявления сумм расходов во временном разрезе.
k = profiles.pivot_table(index='month', values='acquisition_cost', aggfunc='sum')
k.sort_values(by = 'acquisition_cost', ascending = False).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_85ed6_row0_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_85ed6_row1_col0{
#             background-color:  #de614d;
#             color:  #000000;
#         }#T_85ed6_row2_col0{
#             background-color:  #e26952;
#             color:  #000000;
#         }#T_85ed6_row3_col0{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_85ed6_row4_col0{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_85ed6_row5_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_85ed6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >acquisition_cost</th>    </tr>    <tr>        <th class="index_name level0" >month</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
k = profiles.pivot_table(index='month', values='acquisition_cost', aggfunc='sum')
k.sort_values(by = 'month', ascending = True)
# Out:
#             acquisition_cost
# month
# 2019-05-01          9,978.57
# 2019-06-01         15,090.04
# 2019-07-01         16,447.06
# 2019-08-01         20,657.87
# 2019-09-01         22,441.34
# 2019-10-01         20,882.41

# %% [markdown]
# Максимум расходов был произведён в сентябре, минимум же пришёлся на май. В целом, расходы снизились летом и возросли в "холодный" период. Поток инвестици начал активно прирастать в августе, когда уже появляется возможность отвлечь потенциальных клиентов от шашлыков и пляжа.

# %%
# Визуализация.
profiles.pivot_table(index='month', values='acquisition_cost', aggfunc='sum').plot(grid=True, figsize=(10, 5))
plt.title("Расходы в месяц на привлечение клиентов",fontsize=15)
plt.xlabel("Месяцы",fontsize=10)
plt.ylabel("Расходы",fontsize=10)
plt.show();

# %%
# Визуализация.
profiles.pivot_table(index='month', columns = 'channel', values='acquisition_cost', aggfunc='sum').plot(grid=True, figsize=(10, 5))
plt.title("Расходы в месяц на привлечение клиентов с учётом источника трафика",fontsize=15)
plt.xlabel("Месяцы",fontsize=10)
plt.ylabel("Расходы",fontsize=10)
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show();

# %% [markdown]
# Максимальный уровень расходов, приходящийся на сентябрь, связан с вложениями в TipTop.
#
# Возрастание расходов в августе - инвестирование в FaceBoom.
#
# **TipTop и FaceBoom заняли 83% бюджета.**

# %% [markdown]
# Для внесения чёткости в наблюдаемую картину, исключу organic - он бесплатный, а линию даёт, а также FaceBoom и TipTop как самых ярких, что видно на графике выше.

# %%
tra_dis = profiles[~profiles['channel'].isin(['TipTop', 'FaceBoom', 'organic'])].pivot_table(
        index='month', columns='channel', values='acquisition_cost', aggfunc='sum')
tra_dis.plot(grid=True, figsize=(10, 5))
plt.title("Расходы в месяц на привлечение клиентов с учётом истоника трафика",fontsize=15)
plt.xlabel("Месяцы",fontsize=10)
plt.ylabel("Расходы",fontsize=10)
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show();

# %% [markdown]
# **Дам оценку вложениям в каждый из отобранных каналов, сумма инвестиций в которые составила 17%:**
#
# **WahooNetBanner       5% бюджета:** прирост финансирования в июне и августе, общё, вложения колеблются в исследуемом периоде от 800 до 1000 у.е. в месяц;
#
# **AdNonSense           4% бюджета:** пик финансирования в мае, общё, вложения колеблются в исследуемом периоде около отметки в 600 у.е. в месяц;
#
# **OppleCreativeMedia   2%:** прирост финансирования в июне, в исследуемом периоде около отметки в 400 у.е. в месяц;
#
# **RocketSuperAds       2%:**  пик финансирования в мае, вложения колеблются в исследуемом периоде от 200 до 400 у.е. в месяц с тенденцией к 200 у.е к концу периода;
#
# **LeapBob              2%:** финансирования в исследуемом периоде от 300 до 400 у.е. в месяц с постоянной тенденцией;
#
# **lambdaMediaAds       1%:** пик финансирования в мае, вложения колеблются в исследуемом периоде от 200 до 400 у.е. в месяц с тенденцией к 200 у.е. к концу периода;
#
# **MediaTornado         1%:** ровный поток инвестиций, не превышающий 200 у.е.;
#
# **YRabbit              1%:** пик финансирования в мае - 300 у.е., далее ровный поток инвестиций, не превышающий 200 у.е.

# %%
profiles.pivot_table(index='dt', columns='channel', values='acquisition_cost', aggfunc='sum'
                                    ).plot(grid=True, figsize=(20, 11))
plt.title("Затраты в разрезе каналов",fontsize=30)
plt.xlabel("Период",fontsize=20)
plt.ylabel("Расходы",fontsize=20)
plt.show();

# %% [markdown]
# ### Узнаем, сколько в среднем стоило привлечение одного пользователя из каждого источника. Рассчитаем средний CAC на одного пользователя для всего проекта и для каждого источника трафика. Используем профили пользователей. Напишем промежуточные выводы.

# %% [markdown]
# **Стоимость привлечения клиента канала за исследуемый период**

# %%
channel_client = pd.DataFrame() # создаю пустой датафрейм и наполняю столбцами
# данный столбец отразит долю уникальных пользователей из каждого канала
channel_client['Количество пользователей'] =profiles.groupby('channel')['user_id'].count()
# данный столбец отразит величину расходов, произведённых для каждого направления
channel_client['Расходы на привлечение через канал в целом'] = ad
# данный столбец отразит долю уникальных пользователей из каждого канала
channel_client['Расходы на привлечение на одного пользователя'] = channel_client['Расходы на привлечение через канал в целом'] / channel_client['Количество пользователей'] * 100
channel_client.style.format({'Расходы на привлечение на одного пользователя': '{:.2f}'})
channel_client.sort_values(by='Расходы на привлечение на одного пользователя', ascending=False)
# Out:
#                     Количество пользователей  \
# channel
# TipTop                                 19561
# FaceBoom                               29144
# AdNonSense                              3880
# lambdaMediaAds                          2149
# WahooNetBanner                          8553
# RocketSuperAds                          4448
# OppleCreativeMedia                      8605
# YRabbit                                 4312
# MediaTornado                            4364
# LeapBob                                 8553
# organic                                56439
#
#                     Расходы на привлечение через канал в целом  \
# channel
# TipTop                                               54,751.30
# FaceBoom                                             32,445.60
# AdNonSense                                            3,911.25
# lambdaMediaAds                                        1,557.60
# WahooNetBanner                                        5,151.00
# ...

# %%
channel_client['Расходы на привлечение на одного пользователя'].describe()
# Out:
# count    11.00
# mean     68.70
# std      78.47
# min       0.00
# 25%      21.88
# 50%      41.21
# 75%      86.64
# max     279.90
# Name: Расходы на привлечение на одного пользователя, dtype: float64

# %%
# сводная таблица для определения расходов в среднем для отдельных каналов, на одну сессию.
j =profiles.groupby('channel').agg({'acquisition_cost':'mean'}).sort_values(by= 'acquisition_cost', ascending = False).round(2)
j
# Out:
#                     acquisition_cost
# channel
# TipTop                          2.80
# FaceBoom                        1.11
# AdNonSense                      1.01
# lambdaMediaAds                  0.72
# WahooNetBanner                  0.60
# RocketSuperAds                  0.41
# OppleCreativeMedia              0.25
# YRabbit                         0.22
# MediaTornado                    0.22
# LeapBob                         0.21
# organic                         0.00

# %% [markdown]
# **Средняя стоимость привлечения клиентов в разрезе каналов, исходя из 1 сессии:** колеблется от 2,8 у.е. для TipTop до 0,21 у.е. - LeapBob.	Серьёзный разброс в приоритетности направлений продвижения.

# %%
# сводная таблица для определения отдельных каналов и стран
q =profiles.groupby(['region','channel']).agg({'acquisition_cost':'mean'}).sort_values(by= 'region', ascending = False).round(2)
q
# Out:
#                                   acquisition_cost
# region        channel
# United States organic                         0.00
#               YRabbit                         0.22
#               TipTop                          2.80
#               RocketSuperAds                  0.41
#               MediaTornado                    0.22
#               FaceBoom                        1.11
# UK            LeapBob                         0.21
#               organic                         0.00
#               lambdaMediaAds                  0.73
#               WahooNetBanner                  0.60
#               OppleCreativeMedia              0.25
#               AdNonSense                      1.01
# Germany       organic                         0.00
#               lambdaMediaAds                  0.73
#               WahooNetBanner                  0.60
#               OppleCreativeMedia              0.25
#               LeapBob                         0.21
# ...

# %% [markdown]
# **Исследование каналов привлечения в разрезе стран показывает, что рынок США обладает собственными каналами, которые не применяются для Европы.**

# %% [markdown]
# ### Анализ расходов на маркетинг.
#
# **Общая сумма расходов на маркетинг составила 105 498 у.е., в том числе:**
#
# TipTop               54,751
#
# FaceBoom             32,445
#
# WahooNetBanner        5,151
#
# AdNonSense            3,911
#
# OppleCreativeMedia    2,151
#
# RocketSuperAds        1,833
#
# LeapBob               1,797
#
# lambdaMediaAds        1,557
#
# MediaTornado            954
#
# YRabbit                 944
#
#
# **Стоимость привлечения клиента канала за исследуемый период**
#
# channel	- Количество пользователей - Расходы на привлечение через канал в целом - Расходы на привлечение на одного пользователя
#
# TipTop	- 19561	- 54,751- 280
#
# FaceBoom	- 29144 - 32,445 - 111
#
# AdNonSense	- 3880 -3,911 -	101
#
# lambdaMediaAds	- 2149 -1,557 -	72
#
# WahooNetBanner - 8553 -	5,151 - 60
#
# RocketSuperAds	- 4448 - 1,833 - 41
#
# OppleCreativeMedia	- 8605 - 2,151 - 25
#
# YRabbit	 - 4312	- 944 -	22
#
# MediaTornado - 4364 - 954 -	22
#
# LeapBob	- 8553	- 1,798 - 21
#
# organic	- 56439	 - 0.00	- 0.00
#
#
#
# **Максимальный уровень расходов, приходящийся на сентябрь, связан с вложениями в TipTop.**
#
# **Возрастание расходов в августе - инвестирование в FaceBoom.**
#
# **TipTop и FaceBoom заняли 83% бюджета.**
#
# **Дам оценку вложениям в каждый из отобранных каналов, сумма инвестиций в которые составила 17%:**
#
# **WahooNetBanner       5% бюджета:** прирост финансирования в июне и августе, общё, вложения колеблются в исследуемом периоде от 800 до 1000 у.е. в месяц;
#
# **AdNonSense           4% бюджета:** пик финансирования в мае, общё, вложения колеблются в исследуемом периоде около отметки в 600 у.е. в месяц;
#
# **OppleCreativeMedia   2%:** прирост финансирования в июне, в исследуемом периоде около отметки в 400 у.е. в месяц;
#
# **RocketSuperAds       2%:**  пик финансирования в мае, вложения колеблются в исследуемом периоде от 200 до 400 у.е. в месяц с тенденцией к 200 у.е к концу периода;
#
# **LeapBob              2%:** финансирования в исследуемом периоде от 300 до 400 у.е. в месяц с постоянной тенденцией;
#
# **lambdaMediaAds       1%:** пик финансирования в мае, вложения колеблются в исследуемом периоде от 200 до 400 у.е. в месяц с тенденцией к 200 у.е. к концу периода;
#
# **MediaTornado         1%:** ровный поток инвестиций, не превышающий 200 у.е.;
#
# **YRabbit              1%:** пик финансирования в мае - 300 у.е., далее ровный поток инвестиций, не превышающий 200 у.е.
#
# **Средняя стоимость привлечения клиентов в разрезе каналов, исходя из 1 сессии:** колеблется от 2,8 у.е. для TipTop до 0,21 у.е. - LeapBob. Серьёзный разброс в приоритетности направлений продвижения.
# Полная таблица представлена ниже, у.е.\сессия:
#
# TipTop	      2.80
#
# FaceBoom	  1.11
#
# AdNonSense	1.01
#
# lambdaMediaAds	0.72
#
# WahooNetBanner	0.60
#
# RocketSuperAds	0.41
#
# OppleCreativeMedia	0.25
#
# YRabbit	0.22
#
# MediaTornado	0.22
#
# LeapBob	0.21
#
# **Исследование каналов привлечения в разрезе стран показывает, что рынок США обладает собственными каналами, которые не применяются для Европы.**

# %% [markdown]
# ## Шаг 5. Оценим окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы.
#
# Считаем, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения.

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа 
horizon_days = 14  # горизонт анализа 
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# ### Проанализируем общую окупаемость рекламы. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# **Проанализирована общую окупаемость рекламы. Построены графики LTV и ROI, а также графики динамики LTV, CAC и ROI.**
#
# LTV - это «пожизненная ценность» клиента, то есть общая сумма денег, которую один клиент в среднем приносит компании со всех своих покупок.
#
# CAC  — стоимость привлечения одного клиента. Сумма денег, в которую компании обходится каждый новый клиент. В сущности, CAC — это инвестиции в маркетинг.
#
# ROI - окупаемость инвестиций. В экономике одного покупателя эта метрика показывает, на сколько процентов LTV превысил CAC. Ещё говорят: на сколько процентов «окупились» клиенты.
#
# **Давая общую оценку маркетинговым расходам, на основе полученных графиков и проведённых расчётов, можно утверждать следующее:**
#
# LTV в течение двухнедельного, установленного в плане периода, неизменно увеличивается. В динамике наблюдается провал до минимума в середине мая, пик в середине июня, но в целом, *показатель находится в рамках одного коридора 0,8:1,0* (график LTV, график Динамика LTV пользователей на 14 день).
#
# Однако, САС тоже растёт, причём намного динамичнее *от 0,75 до 1,3* к концу периода в 180 дней(график Динамика стоимости привлечения пользователей).
#
# В целом, рекламные расходы не окупились, так как *LTV приблизился, но не пересёк линию окупаемости с графика ROI*.
#
# График Динамика ROI пользователей на 14 день демонстрирует, что *к концу мая* окупаемость прекратилась. *В середине июня ситуация улучшилась,однако, за этим последовал основательный спад, продлившийся до конца исследуемого периода.*

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
# смотрим окупаемость с разбивкой по каналам

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# **В результате анализа окупаемости рекламы с разбивкой по рекламным каналам установлено следующее:**
#
# LTV в течение двухнедельного, установленного в плане периода, неизменно увеличивается у всех каналов(график LTV).Максимальный темп прироста демонстрирует **lambdaMediaAds**, который стартует с уровня 0,5 в начале конрольного периода и доходит до 1,7. Доля приходящегося бюджета - 1%. График "Динамика LTV пользователей на 14 день" показывает, что данный источник имеет ярко выраженную динамику в поведении в исследуемом 6-ти месячном периоде, причём подъёмы значительнее падений. График "Динамика стоимости привлечения пользователей" в отношении канала lambdaMediaAds носит практически неменяющийся характер. Согласно Графику ROI канал lambdaMediaAds относится к группе из 5 лидирующих в плане превышения порога окупаемости источников трафика, наряду с YRabbit (доля бюджета 1%), MediaTornado (доля бюджета 1%), RocketSuperAds (доля бюджета 2%), LeapBob ((доля бюджета 2%).
# OppleCreativeMedia  (доля бюджета 2%) и WahooNetBanner  (доля бюджета 5%) также относятся к каналам, чьи графики  находятся выше уровня окупаемости.  Яркая динимика продемонстрирована YRabbit на графике "Динамика ROI пользователей на 14 день" в июле. ледует также отметить Следует отметить RocketSuperAds и MediaTornado с осенними всплесками.
#
# Если учесть низкий уровень капиталовложений в **lambdaMediaAds(доля бюджета 1%), YRabbit (доля бюджета 1%), MediaTornado (доля бюджета 1%), RocketSuperAds (доля бюджета 2%), LeapBob ((доля бюджета 2%), OppleCreativeMedia  (доля бюджета 2%) и WahooNetBanner  (доля бюджета 5%) - 13% бюджета на всех  для компании **являются окупаемыми и выгодными**. Наилучший показатель активности в течение 6-тимесячного периода по возврату вложений имеет - YRabbit, пики его актиности пришлись июль 2019г.
#
# Рассмотрим самый дорогой канал TipTop, расходы на который составили 52% бюджета. Согласно графику LTV его стартовый уровень - *0,3 и финальный показатель тоже ниже - 1,5*. График "Динамика LTV пользователей на 14 день" показывает нам, что в период с мая по ноябрь 2019г доход, приносимый пользователями этого канала носил хаотичный характер и взлёты компенсировались падениями. График "Динамика стоимости привлечения пользователей" в отношении канала TipTop имеет быстровозрастающую динамику и является единственным в свём роде. График ROI канала TipTop ярко демонстрирует неспосбность к окупаемости, *находясь на уровне 0,6 как максимальном, при уровне окупаемости на значении 1. Что подтверждается и
# графиком "Динамика ROI пользователей на 14 день", где отрицательный показатель достигается к коннцу мая и имеет нисходящую тенденцию до конца исследуемого периода*. Вывод: **канал TipTop не окупается в исследуемом периоде.**
#
# Второй по стоимости вложений источник трафика - FaceBoom, расходы на который составили 31% бюджета. Согласно графику LTV его стартовый уровень 0,6 и финальный показатель тоже ниже - 0,8. Малоактивная динамика. График "Динамика LTV пользователей на 14 день" показывает нам, что в период с мая по ноябрь 2019г доход, приносимый пользователями этого канала носил неяркий синусоидоподобный характер, взлёты компенсировались падениями. График "Динамика стоимости привлечения пользователей" в отношении канала FaceBoom носит линейный практически неменяющийся вид, выступая гранью для менее дорогих в привлечении каналов на данном графике. График ROI канала FaceBoom ярко демонстрирует неспосбность к окупаемости, находясь на уровне 0,8 при уровне окупаемости на значении 1. Что поддтверждается и графиком "Динамика ROI пользователей на 14 день", *где линия не покидает зону неокупаемости*. Вывод: **канал FaceBoom не окупается в исследуемом периоде.**
#
# Далее рассмотрим канал **AdNonSense**, его доля 4% бюджета, но он входит в тройку некупаемых, вместе с выше перечисленными.
# Согласно графику LTV, графику "Динамика LTV пользователей на 14 день" показывает нам, что в период с мая по ноябрь 2019г доход, приносимый пользователями этого канала носил хаотичный характер и взлёты компенсировались падениями. График ROI канала AdNonSense ярко демонстрирует неспосбность к окупаемости, находясь на уровне 0,9 при уровне окупаемости на значении 1. Что поддтверждается и графиком "Динамика ROI пользователей на 14 день". В группе неокупаемых каналов, у него наилучшие показатели, так как объём расходов значительно ниже. Вывод: **канал AdNonSense не окупается в исследуемом периоде.**

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по странам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
# Опишите обнаруженные проблемы и напишите промежуточные выводы.

# %%
# смотрим окупаемость с разбивкой по странам

dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# **Проанализирована окупаемость рекламы с разбивкой по странам**
#
# Согласно графику LTV все 4 представленных региона демонстрируют стойкую восходящую динамику на протяжении 2-хнедельного периода, в течение 6 месячного исследуемого периода движение линий-стран укладывается в общий коридор. Активнее остальных LTV у США. Однако, график "Динамика стоимости привлечения пользователей" в отношении Северной Америки является резко контрастирующим с иными странами, имеет быстрорастущую динамику к увеличению стоимости привлечения. Что и приводит к тому, что окупаемость рекламы в США ниже уровня окупаемости.**США являются единственным направлением, которое не окупается.**. График ROI ярко показывает невозвратность вложений в самый объёмный сегмент рынка, в длительном исследованном периоде положительное значение ROI для США имело место лишь во 2 декаде мая, после чего носило жёсткую отрицательную динамику.  Интересно отметить, как динамично и разнонаправленно отражена динамика стоимости привлечения пользователей для США и европейских стран. Отличные показатели ROI имеет Великобритания в длительном периоде. В целом, стоит отметить, что динамика ROI для европейских стран носит компенсаторный характер: провал у одного - подъём у другого.

# %% [markdown]
# ### Проанализируем окупаемость рекламы в разбивке по устройствам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
# смотрим окупаемость с разбивкой по устройствам

dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# **При анализе окупаемости в разрезе устройств** установлено: что самые дорогие каналы iPhone и Mac, при этом они же имеют отрицательную окупаемость, едва достигая отметки 0,7 при уровне окупаемости в районе 1. Наиболее перспективный канал PC, его динамика возврата инвестиций снижалась медленнее остальных, при это уровень вложений самый низкий, а пиковых моментов в положительной области, в отличие от всех остальных, много. В двухнедельном разрезе окупаемость достигается лишь для данного устройства.

# %% [markdown]
# ### Построим и изучим графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам. Получим ответы вопросы:
# • Окупается ли реклама в целом?
#
# • Какие устройства, страны и каналы могут снижать окупаемость рекламы?
#
# • Чем могут быть вызваны проблемы окупаемости?
#
# Опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %%
dimensions = ['channel']
# смотрим конверсию с разбивкой по каналам трафика

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# **Давая оценку конверсии в разрезе каналов трафика следует отметить:**
# в плановом 14-дневном периоде уровень конверсии носит линейный характер, который достигается на 4 день и примерно на одном уровне идёт до конца. Группа с лучшими показателями по конверсии 14 дней:FaceBoom,AdNonSense,lambdaMediaAds,TipTop. В целом, можно утверждать, что динамика конверсии носит хаотичный характер. В длительном периоде у lambdaMediaAds наибольшее количество положительных всплесков, ровно и себя показывает FaceBoom (не имеет серьёзных провалов).

# %%
dimensions = ['device']
# смотрим конверсию с разбивкой по устройствам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# **Отмечая конверсию в разрезе применяемых устройств**, подчеркну, что лидерами выступают как в коротком, так и полном периодах исследования - Mac, iPhone. Положительная динамика наблюдается на всех платформах, с явным аутсайдером - PC и яркой двусторонней динамикой Android.

# %%
dimensions = ['region']
# смотрим конверсию с разбивкой по странам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# **Давая оценку региональной конверсии**, следует отметить:
#
# конверсия для США значительно выше, чем для остальных стран, которые идут в единой группе.
#
# Для США наблюдается малозначительная динамика роста показателя конверсии после 6 дня.
#
# Начиная с 8 дня рост конверсии для группы из Франции, Германии, Великобритании прекращается.
#
# В 180-тидневном периоде тенденция следующая: США имеет высокий уровень конверсии, в европейской группе наблюдаются противоположнонаправленные всплески в мае, Великобритания показывает положительный пик в середине августа и пик падения в сентябре вместе с Германией, чей значительный всплеск пришёлся на конец сентября.

# %%
# смотрим удержание с разбивкой по устройствам
dimensions = ['device']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Удержание пользователей и покупателей в разрезе применяемых устройств** имеет чёткую нисходящую тенденцию для всех. Динамика удержания покупателей, применяющих Mac и PC носит в исследуемом периоде (05.2019-10.2019) очень неуравновешенный характер с всплесками и падениями. Следует отметить, что динамика удержания покупателй с платформы PC, имея на своём пути провалы, в целом, неплохая.

# %%
# смотрим удержание с разбивкой по странам
dimensions = ['region']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Удержание пользователей и покупателей в разрезе стран** имеет чёткую нисходящую тенденцию для всех. Динамика удержания покупателей в исследуемом периоде имеет "рваный" неуравновешанный характер для  Франции, Германии, Великобритании.  График для покупателей из США носит целостный характер, однако находится на минимальном уровне.  Динамика удержания пользователей в том же периоде находится на уровне максимально приближенном к нулевому.

# %%
# смотрим удержание с разбивкой по источникам трафика
dimensions = ['channel']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Удержание пользователей и покупателей в разрезе источников трафика** имеет чёткую нисходящую тенденцию для всех, особенно быстро отрицательная тенденция проявляется у FaceBoom и AdNonSense.
#
# Динамика удержания покупателей в исследуемом периоде (05.2019-10.2019) имеет "рваный" неуравновешанный характер. Причём проследить данный показатель удаётся только в отношении FaceBoom с экстремально низким уровнем. Динамика удержания пользователей в том же периоде для всех каналов находится на уровне максимально приближенном к нулевому.

# %% [markdown]
# ### Выводы по окупаемости рекламы.
# Проанализирована общую окупаемость рекламы. Построены графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# LTV - это «пожизненная ценность» клиента, то есть общая сумма денег, которую один клиент в среднем приносит компании со всех своих покупок.
# CAC — стоимость привлечения одного клиента. Сумма денег, в которую компании обходится каждый новый клиент. В сущности, CAC — это инвестиции в маркетинг.
# ROI - окупаемость инвестиций. В экономике одного покупателя эта метрика показывает, на сколько процентов LTV превысил CAC. Ещё говорят: на сколько процентов «окупились» клиенты.
# Давая общую оценку маркетинговым расходам, на основе полученных графиков и проведённых расчётов, можно утверждать следующее:
# LTV в течение двухнедельного, установленного в плане периода, неизменно увеличивается. В динамике наблюдается провал до минимума в середине мая, пик в середине июня, но в целом, показатель находится в рамках одного коридора 0,8:1,0 (график LTV, график Динамика LTV пользователей на 14 день).
# Однако, САС тоже растёт, причём намного динамичнее от 0,75 до 1,3 к концу периода в 180 дней(график Динамика стоимости привлечения пользователей).
# В целом, рекламные расходы не окупились, так как LTV приблизился, но не пересёк линию окупаемости с графика ROI.
# График Динамика ROI пользователей на 14 день демонстрирует, что к концу мая окупаемость прекратилась. В середине июня ситуация улучшилась, однако, за этим последовал основательный спад, продлившийся до конца исследуемого периода.
# **В результате анализа окупаемости рекламы с разбивкой по рекламным каналам установлено следующее:**
#
# LTV в течение двухнедельного, установленного в плане периода, неизменно увеличивается у всех каналов(график LTV).Максимальный темп прироста демонстрирует **lambdaMediaAds**, который стартует с уровня 0,5 в начале конрольного периода и доходит до 1,7. Доля приходящегося бюджета - 1%. График "Динамика LTV пользователей на 14 день" показывает, что данный источник имеет ярко выраженную динамику в поведении в исследуемом 6-ти месячном периоде, причём подъёмы значительнее падений. График "Динамика стоимости привлечения пользователей" в отношении канала lambdaMediaAds носит практически неменяющийся характер. Согласно Графику ROI канал lambdaMediaAds относится к группе из 5 лидирующих в плане превышения порога окупаемости источников трафика, наряду с YRabbit (доля бюджета 1%), MediaTornado (доля бюджета 1%), RocketSuperAds (доля бюджета 2%), LeapBob ((доля бюджета 2%).
# OppleCreativeMedia  (доля бюджета 2%) и WahooNetBanner  (доля бюджета 5%) также относятся к каналам, чьи графики  находятся выше уровня окупаемости.  Яркая динимика продемонстрирована YRabbit на графике "Динамика ROI пользователей на 14 день" в июле. ледует также отметить Следует отметить RocketSuperAds и MediaTornado с осенними всплесками.
#
# Если учесть низкий уровень капиталовложений в **lambdaMediaAds(доля бюджета 1%), YRabbit (доля бюджета 1%), MediaTornado (доля бюджета 1%), RocketSuperAds (доля бюджета 2%), LeapBob ((доля бюджета 2%), OppleCreativeMedia  (доля бюджета 2%) и WahooNetBanner  (доля бюджета 5%) - 13% бюджета на всех  для компании **являются окупаемыми и выгодными**. Наилучший показатель активности в течение 6-тимесячного периода по возврату вложений имеет - YRabbit, пики его актиности пришлись июль 2019г.
#
# Рассмотрим самый дорогой канал TipTop, расходы на который составили 52% бюджета. Согласно графику LTV его стартовый уровень - *0,3 и финальный показатель тоже ниже - 1,5*. График "Динамика LTV пользователей на 14 день" показывает нам, что в период с мая по ноябрь 2019г доход, приносимый пользователями этого канала носил хаотичный характер и взлёты компенсировались падениями. График "Динамика стоимости привлечения пользователей" в отношении канала TipTop имеет быстровозрастающую динамику и является единственным в свём роде. График ROI канала TipTop ярко демонстрирует неспосбность к окупаемости, *находясь на уровне 0,6 как максимальном, при уровне окупаемости на значении 1. Что подтверждается и
# графиком "Динамика ROI пользователей на 14 день", где отрицательный показатель достигается к коннцу мая и имеет нисходящую тенденцию до конца исследуемого периода*. Вывод: **канал TipTop не окупается в исследуемом периоде.**
#
# Второй по стоимости вложений источник трафика - FaceBoom, расходы на который составили 31% бюджета. Согласно графику LTV его стартовый уровень 0,6 и финальный показатель тоже ниже - 0,8. Малоактивная динамика. График "Динамика LTV пользователей на 14 день" показывает нам, что в период с мая по ноябрь 2019г доход, приносимый пользователями этого канала носил неяркий синусоидоподобный характер, взлёты компенсировались падениями. График "Динамика стоимости привлечения пользователей" в отношении канала FaceBoom носит линейный практически неменяющийся вид, выступая гранью для менее дорогих в привлечении каналов на данном графике. График ROI канала FaceBoom ярко демонстрирует неспосбность к окупаемости, находясь на уровне 0,8 при уровне окупаемости на значении 1. Что поддтверждается и графиком "Динамика ROI пользователей на 14 день", *где линия не покидает зону неокупаемости*. Вывод: **канал FaceBoom не окупается в исследуемом периоде.**
#
# Далее рассмотрим канал **AdNonSense**, его доля 4% бюджета, но он входит в тройку некупаемых, вместе с выше перечисленными.
# Согласно графику LTV, графику "Динамика LTV пользователей на 14 день" показывает нам, что в период с мая по ноябрь 2019г доход, приносимый пользователями этого канала носил хаотичный характер и взлёты компенсировались падениями. График ROI канала AdNonSense ярко демонстрирует неспосбность к окупаемости, находясь на уровне 0,9 при уровне окупаемости на значении 1. Что поддтверждается и графиком "Динамика ROI пользователей на 14 день". В группе неокупаемых каналов, у него наилучшие показатели, так как объём расходов значительно ниже. Вывод: **канал AdNonSense не окупается в исследуемом периоде.**
# **Проанализирована окупаемость рекламы с разбивкой по странам**
#
# Согласно графику LTV все 4 представленных региона демонстрируют стойкую восходящую динамику на протяжении 2-хнедельного периода, в течение 6 месячного исследуемого периода движение линий-стран укладывается в общий коридор. Активнее остальных LTV у США. Однако,график "Динамика стоимости привлечения пользователей" в отношении Северной Америки является резко контрастирующим с иными странами, имеет быстрорастущую динамику к увеличению стоимости привлечения. Что и приводит к тому, что окупаемость рекламы в США ниже уровня окупаемости и после первой декады июня **США являются единственным направлением, которое не окупается.**. График ROI ярко показывает невозвратность вложений в самый объёмый сегмнт рынка, в длительном исследованном периоде положительное значение ROI для США имело место лишь во 2 декаде мая, после чего носило жёсткую отрицательную динамику.  Интересно отметить, как динамично и разнонаправленно отражена динамика стоимости привлечения пользователей для США и европейских стран.
#
# **Проанализирована окупаемость рекламы с разбивкой по странам**
#
# Согласно графику LTV все 4 представленных региона демонстрируют стойкую восходящую динамику на протяжении 2-хнедельного периода, в течение 6 месячного исследуемого периода движение линий-стран укладывается в общий коридор. Активнее остальных LTV у США. Однако, график "Динамика стоимости привлечения пользователей" в отношении Северной Америки является резко контрастирующим с иными странами, имеет быстрорастущую динамику к увеличению стоимости привлечения. Что и приводит к тому, что окупаемость рекламы в США ниже уровня окупаемости. **США являются единственным направлением, которое не окупается.**. График ROI ярко показывает невозвратность вложений в самый объёмный сегмент рынка, в длительном исследованном периоде положительное значение ROI для США имело место лишь во 2 декаде мая, после чего носило жёсткую отрицательную динамику.  Интересно отметить, как динамично и разнонаправленно отражена динамика стоимости привлечения пользователей для США и европейских стран. Отличные показатели ROI имеет Великобритания в длительном периоде. В целом, стоит отметить, что динамика ROI для европейских стран носит компенсаторный характер: провал у одного - подъём у другого.
#
# **При анализе окупаемости в разрезе устройств** установлено: что самые дорогие каналы iPhone и Mac, при этом они же имеют отрицательную окупаемость, едва достигая отметки 0,7 при уровне окупаемости в районе 1. Наиболее перспективный канал PC, его динамика возврата инвестиций снижалась медленнее остальных, при это уровень вложений самый низкий, а пиковых моментов в положительной области, в отличие от всех остальных, много. В двухнедельном разрезе окупаемость достигается лишь для данного устройства.
#
# **Давая оценку конверсии в разрезе каналов трафика следует отметить:**
# в плановом 14-дневном периоде уровень конверсии носит линейный характер, который достигается на 4 день и  примерно на одном уровне идёт до конца. Группа с лучшими показателями по конверсии 14 дней:FaceBoom,AdNonSense,lambdaMediaAds,TipTop. В целом, можно утверждать, что динамика конверсии носит хаотичный характер. В длительном периоде у lambdaMediaAds наибольшее количество положительных всплесков, ровно и себя показывает FaceBoom (не имеет серьёзных провалов).
# **Отмечая конверсию в разрезе применяемых устройств**, подчеркну, что лидерами выступают как в коротком, так и полном периодах исследования - Mac, iPhone. Положительная динамика наблюдается на всех платформах, с явным аутсайдером - PC и яркой двусторонней динамикой Android.
# **Давая оценку региональной конверсии**, следует отметить:
#
# конверсия для США значительно выше, чем для остальных стран, которые идут в единой группе.
#
# Для США наблюдается малозначительная динамика роста показателя конверсии после 6 дня.
#
# Начиная с 8 дня рост конверсии для группы из Франции, Германии, Великобритании прекращается.
#
# В 180-тидневном периоде тенденция следующая: США имеет высокий уровень конверсии, в европейской группе наблюдаются противоположнонаправленные всплески в мае, Великобритания показывает положительный пик в середине августа и пик падения в сентябре вместе с Германией, чей значительный всплеск пришёлся на конец сентября.
#
# **Удержание пользователей и покупателей в разрезе применяемых устройств** имеет чёткую нисходящую тенденцию для всех. Динамика удержания покупателей, применяющих Mac и PC носит в исследуемом периоде (05.2019-10.2019) очень не уравновешенный характер с всплесками и падениями. Следует отметить, что динамика удержания покупателей с платформы PC, имея на своём пути провалы, в целом, неплохая. Динамика удержания пользователей в том же периоде находится на уровне максимально приближенном к нулевому.
#
# **Удержание пользователей и покупателей в разрезе стран** имеет чёткую нисходящую тенденцию для всех. Динамика удержания покупателей в исследуемом периоде имеет "рваный" неуравновешанный характер для  Франции, Германии, Великобритании.  График для покупателей из США носит целостный характер, однако находится на минимальном уровне.  Динамика удержания пользователей в том же периоде находится на уровне максимально приближенном к нулевому.

# %% [markdown]
# ## **ВЫВОДЫ ПО ВСЕМ РАЗДЕЛАМ**
#
# Здесь приведены полные цитаты выводов из разделов исследования.

# %% [markdown]
# ### Наблюдения из первичного анализа данных.
#
# Информация, представленная для анализа:
#
# содержит данные о 8881 заказе пользователей. **Самая крупная сумма заказа 149,88. Сумма 4,99 повторилась свыше 38000 раз, это, наверно, стоимость подписки, или иной аналогичный платёж**;
#
# содержит сведения о 180 днях и 10 платформах для привлечения клиентов.
#
# **Тройка самых дорогих каналов** представлена ниже (у.е.):
#
# **TipTop               54,751**
#
# **FaceBoom             32,445**
#
# **WahooNetBanner        5,151**
#
# Всего уникальных пользователей за исследуемый период -  150008
#
# **Больше всего посещений приходится на пользователей iPhone**. Таблица популярности устройств представлена ниже:
#
# iPhone	36.34%
#
# Android	23.42%
#
# PC	20.23%
#
# Mac	20.01%
#
# **Больше всего посещений приходится на жителей из США.** Таблица данных по странам ниже:
#
# United States	66.90%
#
# UK	11.75%
#
# France	11.42%
#
# Germany	9.93%
#
# Отмечу, что **наибольшая часть пользователей приходила через канал "organic"**, т.е. попадали на сайт или лендинг из результатов обычной поисковой выдачи, а не с рекламных объявлений.
#
# **На втором месте по привлечению потока - канал TipTop, далее FaceBoom**

# %% [markdown]
# ### Выводы по исследовательскому анализу.
#
# **Страны, из которых пользователи приходят в приложение:**
#
# США, Великобритания, Франция и Германия.
#
# **Наибольшая активность у пользователей из США.**
#
# **Наименьшая активность у представителей Германии.**
#
# **Устройства, которыми пользуются клиенты и устройства, предпочитаемые покупателями.**
#
# Android, Mac, PC, iPhone.
#
# **Предпочитаемым устройством является iPhone как для пользователей, так и для покупателей.**
#
# **Рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей.**
#
# 1. Значительный поток пользователей приходит через органический канал, то есть аудитории известно о наличии развлекательного приложения Procrastinate Pro+, однако, недостаточно сведений о нём и пользователи самостоятельно производят поиск информации. Несмотря на то, что треть всего трафика приходится на "органический", лишь 2% становятся покупателями.
#
# 2. Самыми дорогими с точки зрения вложений являются
#
# TipTop, при этом только 13% общего трафика и доля пользователей, ставших покупателями - 9,6%.
#
# FaceBoom - 19% общего трафика и доля пользователей, ставших покупателями - 12,2% (максимум из списка).
#
# WahooNetBanner - 5,7% общего трафика и доля пользователей, ставших покупателями - 5,3% (максимум в % отношении).
#
# 3. AdNonSense, lambdaMediaAds занимают лишь 2,6 % и 1,4% от объёма трафика соответственно, но доля пользователей, совершивших покупку через эти каналы, велика - 11,3% и 10,5%.

# %% [markdown]
# ### Анализ расходов на маркетинг.
#
# **Общая сумма расходов на маркетинг составила 105 498 у.е., в том числе:**
#
# TipTop               54,751
#
# FaceBoom             32,445
#
# WahooNetBanner        5,151
#
# AdNonSense            3,911
#
# OppleCreativeMedia    2,151
#
# RocketSuperAds        1,833
#
# LeapBob               1,797
#
# lambdaMediaAds        1,557
#
# MediaTornado            954
#
# YRabbit                 944
#
#
# **Стоимость привлечения клиента канала за исследуемый период**
#
# channel	- Количество пользователей - Расходы на привлечение через канал в целом - Расходы на привлечение на одного пользователя
#
# TipTop	- 19561	- 54,751- 280
#
# FaceBoom	- 29144 - 32,445 - 111
#
# AdNonSense	- 3880 -3,911 -	101
#
# lambdaMediaAds	- 2149 -1,557 -	72
#
# WahooNetBanner - 8553 -	5,151 - 60
#
# RocketSuperAds	- 4448 - 1,833 - 41
#
# OppleCreativeMedia	- 8605 - 2,151 - 25
#
# YRabbit	 - 4312	- 944 -	22
#
# MediaTornado - 4364 - 954 -	22
#
# LeapBob	- 8553	- 1,798 - 21
#
# organic	- 56439	 - 0.00	- 0.00
#
#
#
# **Максимальный уровень расходов, приходящийся на сентябрь, связан с вложениями в TipTop.**
#
# **Возрастание расходов в августе - инвестирование в FaceBoom.**
#
# **TipTop и FaceBoom заняли 83% бюджета.**
#
# **Дам оценку вложениям в каждый из отобранных каналов, сумма инвестиций в которые составила 17%:**
#
# **WahooNetBanner       5% бюджета:** прирост финансирования в июне и августе, общё, вложения колеблются в исследуемом периоде от 800 до 1000 у.е. в месяц;
#
# **AdNonSense           4% бюджета:** пик финансирования в мае, общё, вложения колеблются в исследуемом периоде около отметки в 600 у.е. в месяц;
#
# **OppleCreativeMedia   2%:** прирост финансирования в июне, в исследуемом периоде около отметки в 400 у.е. в месяц;
#
# **RocketSuperAds       2%:**  пик финансирования в мае, вложения колеблются в исследуемом периоде от 200 до 400 у.е. в месяц с тенденцией к 200 у.е к концу периода;
#
# **LeapBob              2%:** финансирования в исследуемом периоде от 300 до 400 у.е. в месяц с постоянной тенденцией;
#
# **lambdaMediaAds       1%:** пик финансирования в мае, вложения колеблются в исследуемом периоде от 200 до 400 у.е. в месяц с тенденцией к 200 у.е. к концу периода;
#
# **MediaTornado         1%:** ровный поток инвестиций, не превышающий 200 у.е.;
#
# **YRabbit              1%:** пик финансирования в мае - 300 у.е., далее ровный поток инвестиций, не превышающий 200 у.е.
#
# **Средняя стоимость привлечения клиентов в разрезе каналов, исходя из 1 сессии:** колеблется от 2,8 у.е. для TipTop до 0,21 у.е. - LeapBob. Серьёзный разброс в приоритетности направлений продвижения.
# Полная таблица представлена ниже, у.е.\сессия:
#
# TipTop	      2.80
#
# FaceBoom	  1.11
#
# AdNonSense	1.01
#
# lambdaMediaAds	0.72
#
# WahooNetBanner	0.60
#
# RocketSuperAds	0.41
#
# OppleCreativeMedia	0.25
#
# YRabbit	0.22
#
# MediaTornado	0.22
#
# LeapBob	0.21

# %% [markdown]
# ### Вывод по анализу окупаемости.
# Проанализирована общую окупаемость рекламы. Построены графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# LTV - это «пожизненная ценность» клиента, то есть общая сумма денег, которую один клиент в среднем приносит компании со всех своих покупок.
# CAC — стоимость привлечения одного клиента. Сумма денег, в которую компании обходится каждый новый клиент. В сущности, CAC — это инвестиции в маркетинг.
# ROI - окупаемость инвестиций. В экономике одного покупателя эта метрика показывает, на сколько процентов LTV превысил CAC. Ещё говорят: на сколько процентов «окупились» клиенты.
# Давая общую оценку маркетинговым расходам, на основе полученных графиков и проведённых расчётов, можно утверждать следующее:
# LTV в течение двухнедельного, установленного в плане периода, неизменно увеличивается. В динамике наблюдается провал до минимума в середине мая, пик в середине июня, но в целом, показатель находится в рамках одного коридора 0,8:1,0 (график LTV, график Динамика LTV пользователей на 14 день).
# Однако, САС тоже растёт, причём намного динамичнее от 0,75 до 1,3 к концу периода в 180 дней(график Динамика стоимости привлечения пользователей).
# В целом, рекламные расходы не окупились, так как LTV приблизился, но не пересёк линию окупаемости с графика ROI.
# График Динамика ROI пользователей на 14 день демонстрирует, что к концу мая окупаемость прекратилась. В середине июня ситуация улучшилась, однако, за этим последовал основательный спад, продлившийся до конца исследуемого периода.
# **В результате анализа окупаемости рекламы с разбивкой по рекламным каналам установлено следующее:**
#
# LTV в течение двухнедельного, установленного в плане периода, неизменно увеличивается у всех каналов(график LTV).Максимальный темп прироста демонстрирует **lambdaMediaAds**, который стартует с уровня 0,5 в начале конрольного периода и доходит до 1,7. Доля приходящегося бюджета - 1%. График "Динамика LTV пользователей на 14 день" показывает, что данный источник имеет ярко выраженную динамику в поведении в исследуемом 6-ти месячном периоде, причём подъёмы значительнее падений. График "Динамика стоимости привлечения пользователей" в отношении канала lambdaMediaAds носит практически неменяющийся характер. Согласно Графику ROI канал lambdaMediaAds относится к группе из 5 лидирующих в плане превышения порога окупаемости источников трафика, наряду с YRabbit (доля бюджета 1%), MediaTornado (доля бюджета 1%), RocketSuperAds (доля бюджета 2%), LeapBob ((доля бюджета 2%).
# OppleCreativeMedia  (доля бюджета 2%) и WahooNetBanner  (доля бюджета 5%) также относятся к каналам, чьи графики  находятся выше уровня окупаемости.  Яркая динимика продемонстрирована YRabbit на графике "Динамика ROI пользователей на 14 день" в июле. ледует также отметить Следует отметить RocketSuperAds и MediaTornado с осенними всплесками.
#
# Если учесть низкий уровень капиталовложений в **lambdaMediaAds(доля бюджета 1%), YRabbit (доля бюджета 1%), MediaTornado (доля бюджета 1%), RocketSuperAds (доля бюджета 2%), LeapBob ((доля бюджета 2%), OppleCreativeMedia  (доля бюджета 2%) и WahooNetBanner  (доля бюджета 5%) - 13% бюджета на всех  для компании **являются окупаемыми и выгодными**. Наилучший показатель активности в течение 6-тимесячного периода по возврату вложений имеет - YRabbit, пики его актиности пришлись июль 2019г.
#
# Рассмотрим самый дорогой канал TipTop, расходы на который составили 52% бюджета. Согласно графику LTV его стартовый уровень - *0,3 и финальный показатель тоже ниже - 1,5*. График "Динамика LTV пользователей на 14 день" показывает нам, что в период с мая по ноябрь 2019г доход, приносимый пользователями этого канала носил хаотичный характер и взлёты компенсировались падениями. График "Динамика стоимости привлечения пользователей" в отношении канала TipTop имеет быстровозрастающую динамику и является единственным в свём роде. График ROI канала TipTop ярко демонстрирует неспосбность к окупаемости, *находясь на уровне 0,6 как максимальном, при уровне окупаемости на значении 1. Что подтверждается и
# графиком "Динамика ROI пользователей на 14 день", где отрицательный показатель достигается к коннцу мая и имеет нисходящую тенденцию до конца исследуемого периода*. Вывод: **канал TipTop не окупается в исследуемом периоде.**
#
# Второй по стоимости вложений источник трафика - FaceBoom, расходы на который составили 31% бюджета. Согласно графику LTV его стартовый уровень 0,6 и финальный показатель тоже ниже - 0,8. Малоактивная динамика. График "Динамика LTV пользователей на 14 день" показывает нам, что в период с мая по ноябрь 2019г доход, приносимый пользователями этого канала носил неяркий синусоидоподобный характер, взлёты компенсировались падениями. График "Динамика стоимости привлечения пользователей" в отношении канала FaceBoom носит линейный практически неменяющийся вид, выступая гранью для менее дорогих в привлечении каналов на данном графике. График ROI канала FaceBoom ярко демонстрирует неспосбность к окупаемости, находясь на уровне 0,8 при уровне окупаемости на значении 1. Что поддтверждается и графиком "Динамика ROI пользователей на 14 день", *где линия не покидает зону неокупаемости*. Вывод: **канал FaceBoom не окупается в исследуемом периоде.**
#
# Далее рассмотрим канал **AdNonSense**, его доля 4% бюджета, но он входит в тройку некупаемых, вместе с выше перечисленными.
# Согласно графику LTV, графику "Динамика LTV пользователей на 14 день" показывает нам, что в период с мая по ноябрь 2019г доход, приносимый пользователями этого канала носил хаотичный характер и взлёты компенсировались падениями. График ROI канала AdNonSense ярко демонстрирует неспосбность к окупаемости, находясь на уровне 0,9 при уровне окупаемости на значении 1. Что поддтверждается и графиком "Динамика ROI пользователей на 14 день". В группе неокупаемых каналов, у него наилучшие показатели, так как объём расходов значительно ниже. Вывод: **канал AdNonSense не окупается в исследуемом периоде.**
# **Проанализирована окупаемость рекламы с разбивкой по странам**
#
# Согласно графику LTV все 4 представленных региона демонстрируют стойкую восходящую динамику на протяжении 2-хнедельного периода, в течение 6 месячного исследуемого периода движение линий-стран укладывается в общий коридор. Активнее остальных LTV у США. Однако,график "Динамика стоимости привлечения пользователей" в отношении Северной Америки является резко контрастирующим с иными странами, имеет быстрорастущую динамику к увеличению стоимости привлечения. Что и приводит к тому, что окупаемость рекламы в США ниже уровня окупаемости и после первой декады июня **США являются единственным направлением, которое не окупается.**. График ROI ярко показывает невозвратность вложений в самый объёмый сегмнт рынка, в длительном исследованном периоде положительное значение ROI для США имело место лишь во 2 декаде мая, после чего носило жёсткую отрицательную динамику.  Интересно отметить, как динамично и разнонаправленно отражена динамика стоимости привлечения пользователей для США и европейских стран.
#
# **Проанализирована окупаемость рекламы с разбивкой по странам**
#
# Согласно графику LTV все 4 представленных региона демонстрируют стойкую восходящую динамику на протяжении 2-хнедельного периода, в течение 6 месячного исследуемого периода движение линий-стран укладывается в общий коридор. Активнее остальных LTV у США. Однако, график "Динамика стоимости привлечения пользователей" в отношении Северной Америки является резко контрастирующим с иными странами, имеет быстрорастущую динамику к увеличению стоимости привлечения. Что и приводит к тому, что окупаемость рекламы в США ниже уровня окупаемости и после первой декады июня **США являются единственным направлением, которое не окупается.**. График ROI ярко показывает невозвратность вложений в самый объёмный сегмент рынка, в длительном исследованном периоде положительное значение ROI для США имело место лишь во 2 декаде мая, после чего носило жёсткую отрицательную динамику.  Интересно отметить, как динамично и разнонаправленно отражена динамика стоимости привлечения пользователей для США и европейских стран. Отличные показатели ROI имеет Великобритания в длительном периоде. В целом, стоит отметить, что динамика ROI для европейских стран носит компенсаторный характер: провал у одного - подъём у другого.
#
# **При анализе окупаемости в разрезе устройств** установлено: что самые дорогие каналы iPhone и Mac, при этом они же имеют отрицательную окупаемость, едва достигая отметки 0,7 при уровне окупаемости в районе 1. Наиболее перспективный канал PC, его динамика возврата инвестиций снижалась медленнее остальных, при это уровень вложений самый низкий, а пиковых моментов в положительной области, в отличие от всех остальных, много. В двухнедельном разрезе окупаемость достигается лишь для данного устройства.
#
# **Давая оценку конверсии в разрезе каналов трафика следует отметить:**
# в плановом 14-дневном периоде уровень конверсии носит линейный характер, который достигается на 4 день и  примерно на одном уровне идёт до конца. Группа с лучшими показателями по конверсии 14 дней:FaceBoom,AdNonSense,lambdaMediaAds,TipTop. В целом, можно утверждать, что динамика конверсии носит хаотичный характер. В длительном периоде у lambdaMediaAds наибольшее количество положительных всплесков, ровно и себя показывает FaceBoom (не имеет серьёзных провалов).
# **Отмечая конверсию в разрезе применяемых устройств**, подчеркну, что лидерами выступают как в коротком, так и полном периодах исследования - Mac, iPhone. Положительная динамика наблюдается на всех платформах, с явным аутсайдером - PC и яркой двусторонней динамикой Android.
# **Давая оценку региональной конверсии**, следует отметить:
#
# конверсия для США значительно выше, чем для остальных стран, которые идут в единой группе.
#
# Для США наблюдается малозначительная динамика роста показателя конверсии после 6 дня.
#
# Начиная с 8 дня рост конверсии для группы из Франции, Германии, Великобритании прекращается.
#
# В 180-тидневном периоде тенденция следующая: США имеет высокий уровень конверсии, в европейской группе наблюдаются противоположнонаправленные всплески в мае, Великобритания показывает положительный пик в середине августа и пик падения в сентябре вместе с Германией, чей значительный всплеск пришёлся на конец сентября.
#
# **Удержание пользователей и покупателей в разрезе применяемых устройств** имеет чёткую нисходящую тенденцию для всех. Динамика удержания покупателей, применяющих Mac и PC носит в исследуемом периоде (05.2019-10.2019) очень не уравновешенный характер с всплесками и падениями. Следует отметить, что динамика удержания покупателей с платформы PC, имея на своём пути провалы, в целом, неплохая. Динамика удержания пользователей в том же периоде находится на уровне максимально приближенном к нулевому.
#
# **Удержание пользователей и покупателей в разрезе стран** имеет чёткую нисходящую тенденцию для всех. Динамика удержания покупателей в исследуемом периоде имеет "рваный" неуравновешанный характер для  Франции, Германии, Великобритании.  График для покупателей из США носит целостный характер, однако находится на минимальном уровне.  Динамика удержания пользователей в том же периоде находится на уровне максимально приближенном к нулевому.

# %% [markdown]
# ### **Финальный анализ данных и рекомендации.**

# %% [markdown]
# **Окупается ли реклама в целом?**
#
# Сумма заказов за весь период исследования: 215 963 у.е.
#
# Общая сумма расходов на маркетинг составила 105 498 у.е.
#
# В целом, рекламные расходы не окупились, так как LTV максимально приблизился, но не пересёк линию окупаемости с графика ROI.
#
# График Динамика ROI пользователей на 14 день демонстрирует, что *к концу мая* окупаемость прекратилась. *В середине июня ситуация улучшилась,однако, за этим последовал основательный спад, продлившийся до конца исследуемого периода.*
#
# LTV в течение двухнедельного, установленного в плане периода, неизменно увеличивается. В динамике наблюдается провал до минимума в середине мая, пик в середине июня, но в целом, *показатель находится в рамках одного коридора 0,8:1,0* (график LTV, график Динамика LTV пользователей на 14 день).
#
# Однако, САС тоже растёт, причём намного динамичнее *от 0,75 до 1,3* к концу периода в 180 дней(график Динамика стоимости привлечения пользователей).
#
# Отмечу следующее: маркетинговые расходы прирастают, достигая пика в сентябре. Так как период окупаемости предусмотрен в 14 дней, есть основания полагать, что максимальный уровень доходности должен быть достигнут к октябрю. Однако, к концу исследуемого периода показатель окупаемости инвестиций достигает своего минимума. В целом хочется отметить хаотичность и неконтролируемый характер поведения клиентов. Это свидетельствует о том, что некорректно расставлены приоритеты при произведении инвестиций в источники трафика.
#
# **Из исследованных 10 каналов 3 являются убыточными:**
#
# •	самый дорогой канал TipTop, расходы на который составили 52% бюджета не окупается в исследуемом периоде.
#
# •	второй по стоимости вложений источник трафика - FaceBoom, расходы на который составили 31% бюджета не окупается в исследуемом периоде.
#
# •	канал AdNonSense, его доля 4% бюджета также приносит убытки.
#
# При этом 13% капиталовложений приходятся на окупаемые каналы: lambdaMediaAds(доля бюджета 1%), YRabbit (доля бюджета 1%), MediaTornado (доля бюджета 1%), RocketSuperAds (доля бюджета 2%), LeapBob ((доля бюджета 2%), OppleCreativeMedia (доля бюджета 2%) и WahooNetBanner (доля бюджета 5%).
#
# А также следует отметить тот факт, что максимум пользователей приходит из «органического» источника.
#
# **Давая оценку конверсии в разрезе каналов трафика следует отметить:**
#
# в плановом 14-дневном периоде уровень конверсии носит линейный характер, кото-рый достигается на 4 день и примерно на одном уровне идёт до конца. Группа с лучшими показателяи по конверсии в 14 дней: FaceBoom, AdNonSense, lambdaMediaAds, TipTop. В целом, можно утверждать, что динамика конверсии носит хаотичный характер.В длительном периоде у lambdaMediaAds наибольшее количество положительных всплесков, ровно и себя показывает FaceBoom (не имеет серьёзных провалов).
#
# Удержание пользователей и покупателей в разрезе источников трафика имеет чёткую нисходящую тенденцию для всех, особенно быстро отрицательная тенденция проявляется у FaceBoom и AdNonSense.
#
# Динамика удержания покупателей в исследуемом периоде (05.2019-10.2019) имеет "рваный" неуравновешанный характер. Причём проследить данный показатель удаётся только в отношении FaceBoom с экстремально низким уровнем. Динамика удержания пользователей в том же периоде для всех каналов находится на уровне максимально приближенном к нулевому.
#
#
# **В разрезе стран**
#
# Пользователи из США составляют значительную долю и являются самыми активными. Однако, график "Динамика стоимости привлечения пользователей" в отношении Северной Америки является резко контрастирующим с иными странами, имеет быстрорастущую динамику к увеличению стоимости привлечения. Что и приводит к тому, что только окупаемость рекламы в США ниже требуемого уровня и после первой декады июня США являются единственным направлением, которое не окупается.
# В итоге для США получается, что самые большие расходы приносят самую большую конверсию и самое низкое удержание.
#
# Группа стран: Франция, Германия и Великобритания имеет сходную динамику – окупаемость рекламы имеет место. Конверсия ниже, чем у США, но удержание намного лучше, при условии меньшей стоимости.
#
# Можно предположить, что жители США испытывают больший первоначальный интерес к приложению, однако в долгосрочной перспективе его теряют. Следует проработать концепцию целевого потребителя, больше узнать и лучше понять его потребности. Неплохой показатель удержания для группы стран говорит о том, что имеет смысл сместить точку капиталовложений, чтобы иметь возможность строить длительные отношения с клиентом, а не привлекать постоянно новых и дорогих. Что и происходит с США.
#
# **Исследование каналов привлечения в разрезе стран показывает, что рынок США обладает собственными каналами, которые не при-меняются для Европы.**
#
# **В разрезе устройств**
#
# **При анализе окупаемости в разрезе устройств** установлено: что самые дорогие каналы iPhone и Mac, при этом они же имеют отрицательную окупаемость. Наиболее перспективный канал PC, его динамика возврата инвестиций снижалась медленнее остальных, при это уровень вложений самый низкий.
#
# **Отмечая конверсию в разрезе применяемых устройств**, подчеркну, что лидерами выступают как в коротком, так и полном периодах исследования - Mac, iPhone. Положительная динамика наблюдается на всех платформах, с явным аутсайдером - PC.
#
# **Удержание пользователей и покупателей в разрезе применяемых устройств** имеет чёткую нисходящую тенденцию для всех. Динамика удержания покупателей, применяющих Mac и PC носит в исследуемом периоде (05.2019-10.2019) очень неуравновешанный характер с всплесками и падениями. Динамика удержания пользователей в том же периоде находится на уровне максимально приближенном к нулевому.
#
# Исследование каналов привлечения показывает, что рынок США обладает собственными каналами, которые не применяются для Европы. Решение специалистов отдела маркетинга продиктовано тем, что доля США в первичном трафике около 70%, конверсия быстрая, финансовые усилия были направлены на расширение каналов, связанных именно с США: TipTop и FaceBoom. Это подтверждается и устройствами, которые применяются при работе приложения - Mac, iPhone. Однако, при вложении 87% бюджета в результате окупае-мость не достигнута.
#
# **Пользователи из Северной Америки отличаются по ментальности от европейцев. Для данного региона имеет смысл разработать соб-ственный вариант контента или адаптировать имеющийся.**
#
# **Рекомендуется детально изучить особенности продвижения приложений для американского рынка с целью оптимизации расходов. Чётко зонировать маркетинговый отдел, выделить или привлечь группу специалистов, обладающих опытом в продвижении продуктов для данного рынка.**
#
# Рынок Европы имеет собственные каналы, которые продемонстрировали положительную динамику при низком уровне капиталовложений в 13% бюджета. **Следует обратить внимание на платформу PC как перспективную. Рекомендуется усилить присутствие в европейском реигионе, сформировать группу специалистов для работы с клиентами Европы.** Совершенно очевидно, что приложение лучше подходит для данного рынка.
#
# Значительный объём «органического» трафика свидетельствует о том, что наши клиенты слышали о нас, но в своём «родном» циф-ровом поле не нашли. Конверсия данного канала невелика, но, безусловно важна. **Рекомендуется провести исследовательскую работу «органического» источника**: установить в каких поисковых системах, как часто производятся запросы, какими особенностями обладают пользователи. В виду низкой конверсии в покупателей можно сделать вывод о том, что исследуемое приложение вмещает специфический контент, который неинтересен широким массам. Можно усилить присутствие через бесплатный пробный период без регистрации, **после установления особенностей потенциального «органического»  клиента можно будет понять какими именно каналами можно будет его превратить в покупателя.**
