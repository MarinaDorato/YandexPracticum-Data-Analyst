# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#план-процесса:" data-toc-modified-id="план-процесса:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>план процесса:</a></span><ul class="toc-item"><li><span><a href="#дополнительная-информация" data-toc-modified-id="дополнительная-информация-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>дополнительная информация</a></span></li></ul></li><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Первичный-анализ-данных." data-toc-modified-id="Первичный-анализ-данных.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Первичный анализ данных.</a></span></li><li><span><a href="#Оценка-переменных" data-toc-modified-id="Оценка-переменных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Оценка переменных</a></span><ul class="toc-item"><li><span><a href="#last_price-23699-non-null-float64---цена-на-момент-снятия-с-публикации." data-toc-modified-id="last_price-23699-non-null-float64---цена-на-момент-снятия-с-публикации.-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>last_price 23699 non-null float64 - цена на момент снятия с публикации.</a></span></li><li><span><a href="#total_area---23699-non-null-float64---площадь-квартиры-в-квадратных-метрах-(м²)." data-toc-modified-id="total_area---23699-non-null-float64---площадь-квартиры-в-квадратных-метрах-(м²).-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>total_area - 23699 non-null float64 - площадь квартиры в квадратных метрах (м²).</a></span></li><li><span><a href="#total_images---23699-non-null-int64---число-фотографий-квартиры-в-объявлении.-Не-является-определяющим" data-toc-modified-id="total_images---23699-non-null-int64---число-фотографий-квартиры-в-объявлении.-Не-является-определяющим-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>total_images - 23699 non-null int64 - число фотографий квартиры в объявлении. <em>Не является определяющим</em></a></span></li><li><span><a href="#rooms-23699-non-null-int64---число-комнат." data-toc-modified-id="rooms-23699-non-null-int64---число-комнат.-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>rooms 23699 non-null int64 - число комнат.</a></span></li><li><span><a href="#ceiling_height-14504-non-null-float64---высота-потолков-(м)." data-toc-modified-id="ceiling_height-14504-non-null-float64---высота-потолков-(м).-2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>ceiling_height 14504 non-null float64 - высота потолков (м).</a></span></li><li><span><a href="#floors_total-23613-non-null-float64---всего-этажей-в-доме." data-toc-modified-id="floors_total-23613-non-null-float64---всего-этажей-в-доме.-2.2.6"><span class="toc-item-num">2.2.6&nbsp;&nbsp;</span>floors_total 23613 non-null float64 - всего этажей в доме.</a></span></li><li><span><a href="#kitchen_area-21421-non-null-float64---площадь-кухни-в-квадратных-метрах-(м²)." data-toc-modified-id="kitchen_area-21421-non-null-float64---площадь-кухни-в-квадратных-метрах-(м²).-2.2.7"><span class="toc-item-num">2.2.7&nbsp;&nbsp;</span>kitchen_area 21421 non-null float64 - площадь кухни в квадратных метрах (м²).</a></span></li><li><span><a href="#living_area-21796-non-null-float64---жилая-площадь-в-квадратных-метрах-(м²)." data-toc-modified-id="living_area-21796-non-null-float64---жилая-площадь-в-квадратных-метрах-(м²).-2.2.8"><span class="toc-item-num">2.2.8&nbsp;&nbsp;</span>living_area 21796 non-null float64 - жилая площадь в квадратных метрах (м²).</a></span></li><li><span><a href="#floor-23699-non-null-int64---этаж" data-toc-modified-id="floor-23699-non-null-int64---этаж-2.2.9"><span class="toc-item-num">2.2.9&nbsp;&nbsp;</span>floor 23699 non-null int64 - этаж</a></span></li><li><span><a href="#balcony-12180-non-null-float64---число-балконов" data-toc-modified-id="balcony-12180-non-null-float64---число-балконов-2.2.10"><span class="toc-item-num">2.2.10&nbsp;&nbsp;</span>balcony 12180 non-null float64 - число балконов</a></span></li><li><span><a href="#airports_nearest-18157-non-null-float64---расстояние-до-ближайшего-аэропорта-в-метрах-(м)---получены-автоматически" data-toc-modified-id="airports_nearest-18157-non-null-float64---расстояние-до-ближайшего-аэропорта-в-метрах-(м)---получены-автоматически-2.2.11"><span class="toc-item-num">2.2.11&nbsp;&nbsp;</span>airports_nearest 18157 non-null float64 - расстояние до ближайшего аэропорта в метрах (м) - получены автоматически</a></span></li><li><span><a href="#cityCenters_nearest-18180-non-null-float64---расстояние-до-центра-города-(м)---получены-автоматически" data-toc-modified-id="cityCenters_nearest-18180-non-null-float64---расстояние-до-центра-города-(м)---получены-автоматически-2.2.12"><span class="toc-item-num">2.2.12&nbsp;&nbsp;</span>cityCenters_nearest 18180 non-null float64 - расстояние до центра города (м) - получены автоматически</a></span></li><li><span><a href="#parks_around3000---18181-non-null-float64---число-парков-в-радиусе-3-км---получены-автоматически" data-toc-modified-id="parks_around3000---18181-non-null-float64---число-парков-в-радиусе-3-км---получены-автоматически-2.2.13"><span class="toc-item-num">2.2.13&nbsp;&nbsp;</span>parks_around3000 - 18181 non-null float64 - число парков в радиусе 3 км - получены автоматически</a></span></li><li><span><a href="#parks_nearest---8079-non-null-float64---расстояние-до-ближайшего-парка-(м)---получены-автоматически" data-toc-modified-id="parks_nearest---8079-non-null-float64---расстояние-до-ближайшего-парка-(м)---получены-автоматически-2.2.14"><span class="toc-item-num">2.2.14&nbsp;&nbsp;</span>parks_nearest - 8079 non-null float64 - расстояние до ближайшего парка (м) - получены автоматически</a></span></li><li><span><a href="#ponds_nearest---9110-non-null-float64---расстояние-до-ближайшего-водоёма-(м)---получены-автоматически" data-toc-modified-id="ponds_nearest---9110-non-null-float64---расстояние-до-ближайшего-водоёма-(м)---получены-автоматически-2.2.15"><span class="toc-item-num">2.2.15&nbsp;&nbsp;</span>ponds_nearest - 9110 non-null float64 - расстояние до ближайшего водоёма (м) - получены автоматически</a></span></li><li><span><a href="#days_exposition---20518-non-null-float64---сколько-дней-было-размещено-объявление-(от-публикации-до-снятия)" data-toc-modified-id="days_exposition---20518-non-null-float64---сколько-дней-было-размещено-объявление-(от-публикации-до-снятия)-2.2.16"><span class="toc-item-num">2.2.16&nbsp;&nbsp;</span>days_exposition - 20518 non-null float64 - сколько дней было размещено объявление (от публикации до снятия)</a></span></li><li><span><a href="#first_day_exposition-23699-non-null-object---дата-публикации" data-toc-modified-id="first_day_exposition-23699-non-null-object---дата-публикации-2.2.17"><span class="toc-item-num">2.2.17&nbsp;&nbsp;</span>first_day_exposition 23699 non-null object - дата публикации</a></span></li><li><span><a href="#is_apartment-2775-non-null-object---апартаменты-(булев-тип)" data-toc-modified-id="is_apartment-2775-non-null-object---апартаменты-(булев-тип)-2.2.18"><span class="toc-item-num">2.2.18&nbsp;&nbsp;</span>is_apartment 2775 non-null object - апартаменты (булев тип)</a></span></li><li><span><a href="#locality_name-23650-non-null-object---название-населённого-пункта" data-toc-modified-id="locality_name-23650-non-null-object---название-населённого-пункта-2.2.19"><span class="toc-item-num">2.2.19&nbsp;&nbsp;</span>locality_name 23650 non-null object - название населённого пункта</a></span></li><li><span><a href="#studio-23699-non-null-bool---квартира-студия-(булев-тип)" data-toc-modified-id="studio-23699-non-null-bool---квартира-студия-(булев-тип)-2.2.20"><span class="toc-item-num">2.2.20&nbsp;&nbsp;</span>studio 23699 non-null bool - квартира-студия (булев тип)</a></span></li><li><span><a href="#open_plan-23699-non-null-bool---свободная-планировка-(булев-тип)" data-toc-modified-id="open_plan-23699-non-null-bool---свободная-планировка-(булев-тип)-2.2.21"><span class="toc-item-num">2.2.21&nbsp;&nbsp;</span>open_plan 23699 non-null bool - свободная планировка (булев тип)</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Замена-пропусков-и-изменение-типа-данных" data-toc-modified-id="Замена-пропусков-и-изменение-типа-данных-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Замена пропусков и изменение типа данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Расчёт-цены-квадратного-метра" data-toc-modified-id="Расчёт-цены-квадратного-метра-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Расчёт цены квадратного метра</a></span></li><li><span><a href="#Расчёт-дня-недели,-месяца-и-года-публикации-объявления" data-toc-modified-id="Расчёт-дня-недели,-месяца-и-года-публикации-объявления-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Расчёт дня недели, месяца и года публикации объявления</a></span></li><li><span><a href="#Этаж-квартиры-cгруппирован-по-вариантам-—-первый,-последний,-другой" data-toc-modified-id="Этаж-квартиры-cгруппирован-по-вариантам-—-первый,-последний,-другой-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Этаж квартиры cгруппирован по вариантам — первый, последний, другой</a></span></li><li><span><a href="#Рассчитаны-соотношения-жилой-и-общей-площади,-а-также-площади-кухни-к-общей." data-toc-modified-id="Рассчитаны-соотношения-жилой-и-общей-площади,-а-также-площади-кухни-к-общей.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Рассчитаны соотношения жилой и общей площади, а также площади кухни к общей.</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Исследована-цена" data-toc-modified-id="Исследована-цена-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Исследована цена</a></span></li><li><span><a href="#Исследован-показатель-Общая-площадь" data-toc-modified-id="Исследован-показатель-Общая-площадь-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Исследован показатель Общая площадь</a></span></li><li><span><a href="#Исследован-показатель-Количество-комнат" data-toc-modified-id="Исследован-показатель-Количество-комнат-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Исследован показатель Количество комнат</a></span></li><li><span><a href="#Исследован-показатель-Высота-потолков" data-toc-modified-id="Исследован-показатель-Высота-потолков-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Исследован показатель Высота потолков</a></span></li><li><span><a href="#Исследовано-Время-продажи-квартиры." data-toc-modified-id="Исследовано-Время-продажи-квартиры.-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Исследовано Время продажи квартиры.</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Исследовано-влияние-факторов-на-стоимость-квартиры" data-toc-modified-id="Исследовано-влияние-факторов-на-стоимость-квартиры-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Исследовано влияние факторов на стоимость квартиры</a></span><ul class="toc-item"><li><span><a href="#исследована-зависимость-цены-от-площади,-числа-комнат,-удалённости-от-центра" data-toc-modified-id="исследована-зависимость-цены-от-площади,-числа-комнат,-удалённости-от-центра-5.7.1"><span class="toc-item-num">5.7.1&nbsp;&nbsp;</span>исследована зависимость цены от площади, числа комнат, удалённости от центра</a></span></li><li><span><a href="#Исследована-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Исследована-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-5.7.2"><span class="toc-item-num">5.7.2&nbsp;&nbsp;</span>Исследована зависимость от даты размещения: дня недели, месяца и года.</a></span></li><li><span><a href="#Исследована-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-в-вариантах:-первом,-последнем-или-другом." data-toc-modified-id="Исследована-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-в-вариантах:-первом,-последнем-или-другом.-5.7.3"><span class="toc-item-num">5.7.3&nbsp;&nbsp;</span>Исследована зависимость цены от того, на каком этаже расположена квартира: в вариантах: первом, последнем или другом.</a></span></li><li><span><a href="#10-населённых-пунктов" data-toc-modified-id="10-населённых-пунктов-5.7.4"><span class="toc-item-num">5.7.4&nbsp;&nbsp;</span>10 населённых пунктов</a></span></li><li><span><a href="#Выделить-и-исследовать-продажу-квартир-в-центре." data-toc-modified-id="Выделить-и-исследовать-продажу-квартир-в-центре.-5.7.5"><span class="toc-item-num">5.7.5&nbsp;&nbsp;</span>Выделить и исследовать продажу квартир в центре.</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# Добрых дней, меня зовут Марина, это мой третий проект. Я благодарю за время, которое вы уделите моему проекту. Буду признательна за альтернативные методы решения задач.

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# **Наша задача** — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ##  план процесса:
#
# **рассчитать и отразить в таблице:**
#
# 1. цену квадратного метра;
#
# 2. день недели, месяц и год публикации объявления;
#
# 3. этаж квартиры; варианты — первый, последний, другой;
#
# 4. соотношение жилой и общей площади, а также отношение площади кухни к общей.
#
# **Необходимо выполнить следующие шаги:**
#
# 1.	Изучить следующие параметры: площадь, цена, число комнат, высота потолков. Построить гистограммы для каждого параметра.
#
# 2.	Изучить время продажи квартиры. Постройть гистограмму. Посчитайть среднее и медиану. Описать, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?
#
# 3.	Убрать редкие и выбивающиеся значения. Описать, какие особенности обнаружены.
#
# 4.	Установить какие факторы больше всего влияют на стоимость квартиры?
#
# 4.1. Изучить, зависит ли цена от площади, числа комнат, удалённости от центра.
#
# 4.2. Изучить зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.
#
# 4.3. Также изучить зависимость от даты размещения: дня недели, месяца и года.
#
#
# 5.	Выберать 10 населённых пунктов с наибольшим числом объявлений. Посчитать среднюю цену квадратного метра в этих населённых пунктах. Выделить среди них населённые пункты с самой высокой и низкой стоимостью жилья. (Эти данные можно найти по имени в столбце locality_name).
#
# 6.	Изучить предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделить квартиры в Санкт-Петербурге (locality_name). *Наша задача — выяснить, какая область входит в центр*. Создадим столбец с расстоянием до центра в километрах: округлим до целых значений. После этого посчитаем среднюю цену для каждого километра. Построим график: он должен показывать, как цена зависит от удалённости от центра. Определим границу, где график сильно меняется, — это и будет центральная зона.
#
# 7.	Выделить сегмент квартир в центре. Проанализировать эту территорию и изучить следующие параметры: площадь, цена, число комнат, высота потолков. Также выделить факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделать выводы. Отличаются ли они от общих выводов по всему городу?
#
# **Сформировать итоговый вывод и рекомендации**

# %% [markdown]
# ### дополнительная информация

# %% [markdown]
# По данным статьи, размещённой на сайте Журнала Этажи
#
# https://j.etagi.com/ps/ocenka-nedvizhimosti/
#
# Сaмый oчeвидный и глaвный фaктop, кoтopый влияeт нa цeнy:
#
# 💎ceбecтoимocть нeдвижимocти, т.е. цeна нa cтpoитeльныe мaтepиaлы и pacxoды нa cтpoитeльcтвo — oплaтy тpyдa paбoчим, зaтpaты нa пpoeктнyю дoкyмeнтaцию, тpaнcпopтиpoвкy мaтepиaлoв и дpyгиe.
#
# Taкжe нa cтoимocть влияют мнoжecтвo дpyгиx пapaмeтpoв, нe зaвиcящиx oт pacxoдoв нa cтpoитeльcтвo:
#
# 💎 cитyaция нa pынкe
#
# 💎 ceзoннocть
#
# 💎 мecтoпoлoжeниe
#
# 💎 инфpacтpyктypa paйoнa или нaceлeннoгo пyнктa
#
# 💎 cтeпeнь изнoca
#
# 💎 мaтepиaл cтeн
#
# 💎 экoлoгичecкaя oбcтaнoвкa
#
# 💎 нaличиe бaлкoнa
#
# 💎 xapaктepиcтики двopa

# %% [markdown]
# **Критерии оценки рыночной стоимости жилья согласно сведениям РБК** (https://realty.rbc.ru/news/6185223c9a7947626cebabb7)**определяются основными параметрами, которые могут в ту или иную сторону менять рыночную стоимость жилья, разделяются на ключевые и второстепенные.**
#
# **Общие критерии оценки рыночной стоимости:**
#
# •	конъюнктура рынка, состояние спроса и предложения на подобные объекты;
#
# •	типовое или уникальное жилье, тип постройки, спрос на серию дома;
#
# •	**расположение жилья;**
#
# •	транспортная инфраструктура и перспективы ее развития;
#
# •	экологическая обстановка;
#
# •	социальная и коммерческая инфраструктура района: поликлиники, школы, торговые центры, парки.
#
# **Существенные факторы, влияющие на рыночную стоимость:**
#
# •	**площадь квартиры, количество комнат;**
#
# •	**этажность дома и расположение квартиры на конкретном этаже;**
#
# •	наличие лифта/лифтов;
#
# •	**стандартная или индивидуальная планировка;**
#
# •	техническое состояние, наличие современного ремонта;
#
# •	**соотношение общей и жилой площадей, площадь кухни;**
#
# •	наличие раздельного или совмещенного санузла или нескольких санузлов в помещении.
#
# **Второстепенные факторы** — **высота потолков, вид из окон, наличие балкона** или лоджии. Эти факторы не так важны, как вышеперечисленные, однако для конкретного покупателя именно они могут выходить на первый план при выборе объекта. Их также обязательно учитывают при определении рыночной стоимости квартиры.

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# ###  Первичный анализ данных.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
import seaborn as sns
import datetime


df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
df.info()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# ...

# %% [markdown]
# Описание данных
# 1.	total_images            23699 non-null int64 - число фотографий квартиры в объявлении
# 2.	last_price              23699 non-null float64 - цена на момент снятия с публикации
# 3.	total_area              23699 non-null float64 - площадь квартиры в квадратных метрах (м²)
# 4.	first_day_exposition    23699 non-null object - дата публикации
# 5.	rooms                   23699 non-null int64 - число комнат
# 6.	ceiling_height          14504 non-null float64 - высота потолков (м)
# 7.	floors_total            23613 non-null float64 - всего этажей в доме
# 8.	living_area             21796 non-null float64 - жилая площадь в квадратных метрах (м²)
# 9.	floor                   23699 non-null int64 - этаж
# 10.	is_apartment            2775 non-null object - апартаменты (булев тип) Почти каждая десятая сделка на московском рынке жилья приходится на апартаменты. Этот вид недвижимости востребован среди инвесторов и людей, для которых не важна прописка. Одна из причин популярности апартаментов — более низкая по сравнению с квартирами цена, в среднем они дешевле на 20%. РБК: https://realty.rbc.ru/news/5f86a4eb9a7947ef12606382)
# 11.	studio                  23699 non-null bool - квартира-студия (булев тип) Студия — это однокомнатная квартира без перегородок. Комната и кухня не разделены стеной, а находятся в одном пространстве. Иногда в это пространство входит еще и прихожая. Главное отличие студии от однушки — отсутствие стены между комнатами и кухней. Если цените простор, лучше подойдет студия (www.journal.tinkoff.ru)
# 12.	open_plan               23699 non-null bool - свободная планировка (булев тип) Открытая планировка представляет собой единое жилое помещение, в котором отсутствуют перегородки, а несущие элементы сведены к минимуму. Разметка помещений, конечно, имеется – о них говорят коммуникации и выходы вентиляций (https://decor-p.ru/)
# 13.	kitchen_area            21421 non-null float64 - площадь кухни в квадратных метрах (м²)
# 14.	balcony                 12180 non-null float64 - число балконов
# 15.	locality_name           23650 non-null object - название населённого пункта
# 16.	airports_nearest        18157 non-null float64 - расстояние до ближайшего аэропорта в метрах (м) - получены автоматически
# 17.	cityCenters_nearest     18180 non-null float64 - расстояние до центра города (м) - получены автоматически
# 18.	parks_around3000        18181 non-null float64 - число парков в радиусе 3 км - получены автоматически
# 19.	parks_nearest           8079 non-null float64 - расстояние до ближайшего парка (м) - получены автоматически
# 20.	ponds_around3000        18181 non-null float64 - число водоёмов в радиусе 3 км - получены автоматически
# 21.	ponds_nearest           9110 non-null float64 - расстояние до ближайшего водоёма (м) - получены автоматически
# 22.	days_exposition         20518 non-null float64 - сколько дней было размещено объявление (от публикации до снятия)

# %%
#  общая характеристика
df.describe().T
# Out:
#                        count          mean           std      min         25%  \
# total_images         23699.0  9.858475e+00  5.682529e+00      0.0        6.00
# last_price           23699.0  6.541549e+06  1.088701e+07  12190.0  3400000.00
# total_area           23699.0  6.034865e+01  3.565408e+01     12.0       40.00
# rooms                23699.0  2.070636e+00  1.078405e+00      0.0        1.00
# ceiling_height       14504.0  2.771499e+00  1.261056e+00      1.0        2.52
# floors_total         23613.0  1.067382e+01  6.597173e+00      1.0        5.00
# living_area          21796.0  3.445785e+01  2.203045e+01      2.0       18.60
# floor                23699.0  5.892358e+00  4.885249e+00      1.0        2.00
# kitchen_area         21421.0  1.056981e+01  5.905438e+00      1.3        7.00
# balcony              12180.0  1.150082e+00  1.071300e+00      0.0        0.00
# airports_nearest     18157.0  2.879367e+04  1.263088e+04      0.0    18585.00
# ...

# %%
# заменю экспоненциальное представление
pd.set_option("display.float_format", "{:.2f}".format)
df.describe().T
# Out:
#                        count       mean         std      min        25%  \
# total_images        23699.00       9.86        5.68     0.00       6.00
# last_price          23699.00 6541548.77 10887013.27 12190.00 3400000.00
# total_area          23699.00      60.35       35.65    12.00      40.00
# rooms               23699.00       2.07        1.08     0.00       1.00
# ceiling_height      14504.00       2.77        1.26     1.00       2.52
# floors_total        23613.00      10.67        6.60     1.00       5.00
# living_area         21796.00      34.46       22.03     2.00      18.60
# floor               23699.00       5.89        4.89     1.00       2.00
# kitchen_area        21421.00      10.57        5.91     1.30       7.00
# balcony             12180.00       1.15        1.07     0.00       0.00
# airports_nearest    18157.00   28793.67    12630.88     0.00   18585.00
# cityCenters_nearest 18180.00   14191.28     8608.39   181.00    9238.00
# ...

# %% [markdown]
# ### Оценка переменных
# #### last_price 23699 non-null float64 - цена на момент снятия с публикации.

# %%
# получим общую информацию о данных столбца
print(df['last_price'].value_counts()) # вернёт уникальные значения и их количество;

quantity_of_pass = df['last_price'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

print(len(df['last_price'])) # покажет длину столбца

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/len(df['last_price'])

print('Доля пропусков в столбце last_price:{:.1%}'.format(share_of_pass))
# Out:
# 4500000.00     342
# 3500000.00     291
# 4000000.00     260
# 4300000.00     260
# 4200000.00     259
#               ...
# 4412094.00       1
# 6416000.00       1
# 4581000.00       1
# 34551000.00      1
# 6029433.00       1
# Name: last_price, Length: 2978, dtype: int64
# 0
# 23699
# Доля пропусков в столбце last_price:0.0%

# %%
# построим гистограму для last_price, увидим частоту:
plt.hist(df['last_price'], bins = 30, color = '#ccff00', range=(0, 20000000))
plt.axvline(df['last_price'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['last_price'].mean(), color='orange', linestyle='--', label='mean')
plt.title('Цена на момент снятия с публикации', fontsize=20)
plt.xlabel('финальная цена')
plt.ylabel('частота')
plt.legend()
plt.xticks(rotation=15);

# %%
# построим диаграмму размаха:
df.boxplot('last_price') 
plt.ylim(0, 12000000);

# %%
# построим структуру данных:
df['last_price'].describe()
# Out:
# count       23699.00
# mean      6541548.77
# std      10887013.27
# min         12190.00
# 25%       3400000.00
# 50%       4650000.00
# 75%       6800000.00
# max     763000000.00
# Name: last_price, dtype: float64

# %%
share_of_deviation_pr = len(df.query('last_price > 1 and last_price > 11900000')) / len(df) #  доля выбросов
print(share_of_deviation_pr)
print(len(df.query('1 >  last_price|last_price > 11900000'))) #  количество данных в выбросе
print('Доля выброса данных в столбце last_price:{:.1%}'.format(share_of_deviation_pr))
# Out:
# 0.08582640617747585
# 2034
# Доля выброса данных в столбце last_price:8.6%

# %% [markdown]
# **Вывод**
#
# столбец **last_price** не содержит пропусков, требуется замена типа данных на int (вряд ли при продаже квартиры кто-то до копеек устанавливает цену). Доля выброса данных в столбце last_price:8.6%. Демонстрирует, во-первых, огромный разброс в данных,а во-вторых, не указана единица измерения (рубли, рубли/кв.м.). Вопрос с единицами измерения - в баг-репорт. А сама дельта может объясняться тем, что часть объявлений относится к аренде, часть к продажам недвижимости. Большая часть значений тяготеет к медианному и находится в области 3,2 - 4,2 млн. Для построения графика предельный показатель выбран для наглядности в связи со значительным разбросом данных. 8,6% данных может относится к категории элитного жилья.

# %% [markdown]
# #### total_area - 23699 non-null float64 - площадь квартиры в квадратных метрах (м²).

# %%
# получим общую информацию
print(df['total_area'].value_counts()) # вернёт уникальные значения и их количество;

quantity_of_pass = df['total_area'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

print(len(df['total_area'])) # покажет длину столбца

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/len(df['total_area'])

print('Доля пропусков в столбце total_area:{:.1%}'.format(share_of_pass))
# Out:
# 45.00     419
# 42.00     383
# 60.00     347
# 31.00     346
# 44.00     345
#          ...
# 45.85       1
# 44.18       1
# 59.83       1
# 127.20      1
# 23.55       1
# Name: total_area, Length: 2182, dtype: int64
# 0
# 23699
# Доля пропусков в столбце total_area:0.0%

# %%
# проясним структуру данных
df['total_area'].describe()
# Out:
# count   23699.00
# mean       60.35
# std        35.65
# min        12.00
# 25%        40.00
# 50%        52.00
# 75%        69.90
# max       900.00
# Name: total_area, dtype: float64

# %%
# построим диаграмму размаха:
df.boxplot('total_area') 
plt.ylim(0, 120);

# %%
share_of_deviation_area = len(df.query('10 >= total_area|total_area >= 118')) / len(df) #  доля выбросов
print(share_of_deviation_area)
print(len(df))
print(len(df.query('10 >= total_area|total_area >= 118'))) #  количество данных в выбросе

print('Доля выброса данных в столбце total_area:{:.1%}'.format(share_of_deviation_area))
# Out:
# 0.048356470737161907
# 23699
# 1146
# Доля выброса данных в столбце total_area:4.8%

# %% [markdown]
# Вывод total_area
#
# Доля пропусков в столбце total_area:0.0%. Тип данных можно не менять, так как это площадь квартиры. Значительная часть данных находится в диапазоне 25-45 кв.м. Имеют место выбросы. Доля выбросов 4,8%.

# %% [markdown]
# #### total_images - 23699 non-null int64 - число фотографий квартиры в объявлении. *Не является определяющим*

# %%
# получим общие сведения 
print(df['total_images'].value_counts()) # вернёт уникальные значения и их количество;
quantity_of_pass = df['total_images'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)
print(len(df['total_images'])) # покажет длину столбца
length_of_series = len(df['total_images']) # длина столбца данных

share_of_pass = quantity_of_pass/length_of_series

print('Доля пропусков в столбце total_images:{:.0%}'.format(share_of_pass))
# Out:
# 10    1798
# 9     1725
# 20    1694
# 8     1585
# 7     1521
# 6     1482
# 11    1362
# 5     1301
# 12    1225
# 0     1059
# 13    1015
# 14     986
# 4      986
# 15     948
# 1      872
# 3      769
# 16     761
# 17     650
# 18     642
# 2      640
# 19     603
# 23      16
# 21      12
# 24       8
# 22       8
# 26       5
# 28       4
# 32       4
# 50       3
# 29       3
# 31       2
# 35       2
# 30       2
# 27       2
# 37       1
# 39       1
# 25       1
# 42       1
# Name: total_images, dtype: int64
# 0
# 23699
# Доля пропусков в столбце total_images:0%

# %% [markdown]
# Вывод
#
# столбец total_images — число фотографий квартиры в объявлении - не содержит пропусков, однако, не является определяющим рыночную стоимость объектов недвижимости параметром. И скорее влияет на продвижение самого объявления.

# %% [markdown]
# #### rooms 23699 non-null int64 - число комнат.

# %%
# получим общие сведения
print(df['rooms'].value_counts().sort_index()) # вернёт уникальные значения и их количество;

quantity_of_pass = df['rooms'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

print(len(df['rooms'])) # покажет длину столбца

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/len(df['rooms'])

print('Доля пропусков в столбце rooms:{:.0%}'.format(share_of_pass))
# Out:
# 0      197
# 1     8047
# 2     7940
# 3     5814
# 4     1180
# 5      326
# 6      105
# 7       59
# 8       12
# 9        8
# 10       3
# 11       2
# 12       1
# 14       2
# 15       1
# 16       1
# 19       1
# Name: rooms, dtype: int64
# 0
# 23699
# Доля пропусков в столбце rooms:0%

# %%
# уточним структуру 
df['rooms'].describe()
# Out:
# count   23699.00
# mean        2.07
# std         1.08
# min         0.00
# 25%         1.00
# 50%         2.00
# 75%         3.00
# max        19.00
# Name: rooms, dtype: float64

# %%
# построим гистограмму, чтобы выявить частоту
plt.hist(df['rooms'], bins = 300, color = '#ccff00', range=(0, 10))
plt.axvline(df['rooms'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['rooms'].mean(), color='orange', linestyle='--', label='mean')
plt.title('Количество комнат', fontsize=20)
plt.xlabel('комнат в квартире')
plt.ylabel('частота')
plt.legend()
plt.xticks(rotation=0);

# %%
# построим диаграмму размаха:
df.boxplot('rooms') 
plt.ylim(0, 7);

# %%
share_of_deviation_room = len(df.query('rooms >= 7')) / len(df) #  доля выбросов
print(share_of_deviation_room)
print(len(df.query('rooms >= 7'))) #  количество данных в выбросе
print('Доля выброса данных в столбце rooms:{:.1%}'.format(share_of_deviation_room))
# Out:
# 0.00379762859192371
# 90
# Доля выброса данных в столбце rooms:0.4%

# %% [markdown]
# **Вывод**
#
# **rooms** тип данных менять не нужно. Пропусков нет. Доля выброса данных в столбце rooms:0.4%

# %% [markdown]
# #### ceiling_height 14504 non-null float64 - высота потолков (м).

# %%
# получим общие сведения
print(df['ceiling_height'].value_counts().sort_index()) # вернёт уникальные значения и их количество;

quantity_of_pass = df['ceiling_height'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

print(len(df['ceiling_height'])) # покажет длину столбца

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/len(df['ceiling_height'])

print('Доля пропусков в столбце ceiling_height:{:.0%}'.format(share_of_pass))
# Out:
# 1.00       1
# 1.20       1
# 1.75       1
# 2.00      11
# 2.20       1
#           ..
# 26.00      1
# 27.00      8
# 27.50      1
# 32.00      2
# 100.00     1
# Name: ceiling_height, Length: 183, dtype: int64
# 9195
# 23699
# Доля пропусков в столбце ceiling_height:39%

# %%
print(df.loc[df ['ceiling_height'] >=6])
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 355              17   3600000.00       55.20  2018-07-12T00:00:00      2
# 3148             14   2900000.00       75.00  2018-11-12T00:00:00      3
# 3474              3   1400000.00       30.00  2018-03-16T00:00:00      1
# 4643              0   4300000.00       45.00  2018-02-01T00:00:00      2
# 4876              7   3000000.00       25.00  2017-09-27T00:00:00      0
# 5076              0   3850000.00       30.50  2018-10-03T00:00:00      1
# 5246              0   2500000.00       54.00  2017-10-13T00:00:00      2
# 5669              4   4400000.00       50.00  2017-08-08T00:00:00      2
# 5807             17   8150000.00       80.00  2019-01-09T00:00:00      2
# 5863             20   5650000.00       45.00  2018-08-15T00:00:00      1
# 6246              6   3300000.00       44.40  2019-03-25T00:00:00      2
# 9379              5   3950000.00       42.00  2017-03-26T00:00:00      3
# ...

# %%
# уточним структуру 
df['ceiling_height'].describe()
# Out:
# count   14504.00
# mean        2.77
# std         1.26
# min         1.00
# 25%         2.52
# 50%         2.65
# 75%         2.80
# max       100.00
# Name: ceiling_height, dtype: float64

# %%
# построим гистограмму, чтобы выявить частоту
plt.hist(df['ceiling_height'], bins = 5, color = '#ccff00', range=(0, 5))
plt.axvline(df['ceiling_height'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['ceiling_height'].mean(), color='orange', linestyle='--', label='mean')
plt.title('Высота потолков', fontsize=20)
plt.xlabel('потолки, м')
plt.ylabel('частота')
plt.legend()
plt.xticks(rotation=0);

# %%
# построим диаграмму размаха
df.boxplot('ceiling_height') 
plt.ylim(2.1, 3.3);

# %%
share_of_deviation_ceil = len(df.query('2.1 >=  ceiling_height|ceiling_height >= 3.3')) / len(df)
print (share_of_deviation_ceil )
print (len(df))
print(len(df.query( '2.1 < ceiling_height   | ceiling_height < 3.3'))) # в пределах нормального распределения
print('Доля выброса данных в столбце ceiling_height:{:.1%}'.format(share_of_deviation_ceil))
# Out:
# 0.03215325541162074
# 23699
# 14504
# Доля выброса данных в столбце ceiling_height:3.2%

# %% [markdown]
# N.B. Доля пропусков в столбце ceiling_height:39% - в баг-репорт. Доля выброса данных в столбце ceiling_height:3.2%
# Значения свыше 3.3 - выбросы. Замену пропусков, в целом, на значения выполнять нецелесообразно, так как отсутствуют допонительные параметры, по которым можно было бы определить значение: тип материала (дерево, кирпич, панель), номер серии дома.  Рекомендации разработчикам - внести уточнение. Так как решение принимается без участия и помощи сторонних лиц, я за меню все аномалии на медиану по группе (locality_name).

# %% [markdown]
# #### floors_total 23613 non-null float64 - всего этажей в доме.

# %%
# получим общие сведения
print(df['floors_total'].value_counts().sort_index()) # вернёт уникальные значения и их количество;

quantity_of_pass = df['floors_total'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

print(len(df['floors_total'])) # покажет длину столбца

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/len(df['floors_total'])

print('Доля пропусков в столбце floors_total:{:.1%}'.format(share_of_pass))
# Out:
# 1.00       25
# 2.00      383
# 3.00      668
# 4.00     1200
# 5.00     5788
# 6.00      914
# 7.00      592
# 8.00      390
# 9.00     3761
# 10.00    1174
# 11.00     203
# 12.00    1362
# 13.00     229
# 14.00     553
# 15.00     365
# 16.00    1376
# 17.00     833
# 18.00     505
# 19.00     339
# 20.00     271
# 21.00     158
# 22.00     286
# 23.00     352
# 24.00     469
# 25.00    1075
# 26.00     124
# 27.00     164
# 28.00      21
# 29.00       1
# 33.00       1
# 34.00       1
# 35.00      24
# 36.00       3
# 37.00       1
# 52.00       1
# 60.00       1
# Name: floors_total, dtype: int64
# 86
# 23699
# Доля пропусков в столбце floors_total:0.4%

# %%
# уточним структуру 
df['floors_total'].describe()
# Out:
# count   23613.00
# mean       10.67
# std         6.60
# min         1.00
# 25%         5.00
# 50%         9.00
# 75%        16.00
# max        60.00
# Name: floors_total, dtype: float64

# %%
# построим гистограмму, чтобы выявить частоту
plt.hist(df['floors_total'], bins = 5, color = '#310062', range=(0, 20))
plt.axvline(df['floors_total'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['floors_total'].mean(), color='orange', linestyle='--', label='mean')
plt.title('Этажность дома', fontsize=20)
plt.xlabel('этажей в доме')
plt.ylabel('частота')
plt.legend()
plt.xticks(rotation=0);

# %%
# построим диаграмму размаха
df.boxplot('floors_total') 
plt.ylim(1, 30);

# %%
share_of_deviation_ft = len(df.query('1 >  floors_total|floors_total > 29')) / len(df)
print (share_of_deviation_ft)
print (len(df))
print(len(df.query( '1 <= floors_total | floors_total <= 29'))) # в пределах нормального распределения
print('Доля выброса данных в столбце floors_total:{:.2%}'.format(share_of_deviation_ft))
# Out:
# 0.0013502679437950968
# 23699
# 23613
# Доля выброса данных в столбце floors_total:0.14%

# %% [markdown]
# **Вывод**
#
# Доля пропусков в столбце floors_total:0.4% - незначительна, пропуски можно удалить. Доля выброса данных в столбце floors_total:0.1% - удалим. Нужна замена типа данных, этажность не может быть дробной.

# %% [markdown]
# #### kitchen_area 21421 non-null float64 - площадь кухни в квадратных метрах (м²).

# %%
# получим общие данные

print(df['kitchen_area'].value_counts()) # вернёт уникальные значения и их количество;

quantity_of_pass = df['kitchen_area'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

print(len(df['kitchen_area'])) # покажет длину столбца

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/len(df['kitchen_area'])

print('Доля пропусков в столбце kitchen_area:{:.1%}'.format(share_of_pass))
# Out:
# 6.00     1300
# 10.00    1262
# 8.00     1110
# 9.00     1101
# 7.00     1062
#          ...
# 18.07       1
# 28.20       1
# 37.90       1
# 9.51        1
# 35.40       1
# Name: kitchen_area, Length: 971, dtype: int64
# 2278
# 23699
# Доля пропусков в столбце kitchen_area:9.6%

# %% [markdown]
# N.B. Доля пропусков в столбце kitchen_area:9.6%. Тип данных можно не менять, так как речь идёт о площади. Обратимся СП 54.13330.2016 Здания жилые многоквартирные. Актуализированная редакция СНиП 31-01-2003 (с Изменениями N 1, 2, 3): в однокомнатных квартирах допускается проектировать кухни или кухни-ниши площадью не менее 5 м².
#
# Пропуски могут быть свидетельством того, что продаётся студия или квартира с открытой планировкой.
#
# N.B. Очень большой разброс между максимумом и минимумом

# %%
# построив гистограмму, определим частоту появления значения в исследуемом наборе наблюдений 
plt.hist(df['kitchen_area'], bins = 5, color = '#ccc68b', range=(0, 70))
plt.axvline(df['kitchen_area'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['kitchen_area'].mean(), color='orange', linestyle='--', label='mean')
plt.title('Размер кухни в квартире', fontsize=20)
plt.xlabel('площадь кухни, м.кв.')
plt.ylabel('частота')
plt.legend()
plt.xticks(rotation=0);

# %%
# получим понимание структуры данных в столбце
df['kitchen_area'].describe()
# Out:
# count   21421.00
# mean       10.57
# std         5.91
# min         1.30
# 25%         7.00
# 50%         9.10
# 75%        12.00
# max       112.00
# Name: kitchen_area, dtype: float64

# %%
# визуально оценим характеристики распределения
df.boxplot('kitchen_area') 
plt.ylim(1, 50);

# %% [markdown]
# **Вывод**
#
# Доля пропусков в столбце kitchen_area:9.6% - в баг-репорт. Тип данных можно не менять, так как речь идёт о площади. Обратимся СП 54.13330.2016 Здания жилые многоквартирные. Актуализированная редакция СНиП 31-01-2003 (с Изменениями N 1, 2, 3): в однокомнатных квартирах допускается проектировать кухни или кухни-ниши площадью не менее 5 м². Пропуски могут быть свидетельством того, что продаётся студия или квартира с открытой планировкой. Доля выброса данных в столбце floors_total:5.2%.

# %% [markdown]
# #### living_area 21796 non-null float64 - жилая площадь в квадратных метрах (м²).

# %%
# получим общие данные

print(df['living_area'].value_counts()) # вернёт уникальные значения и их количество;

quantity_of_pass = df['living_area'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

print(len(df['living_area'])) # покажет длину столбца

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/len(df['living_area'])

print('Доля пропусков в столбце living_area:{:.1%}'.format(share_of_pass))
# Out:
# 18.00    882
# 17.00    675
# 30.00    598
# 16.00    486
# 20.00    481
#         ...
# 20.03      1
# 10.55      1
# 24.83      1
# 20.97      1
# 15.55      1
# Name: living_area, Length: 1782, dtype: int64
# 1903
# 23699
# Доля пропусков в столбце living_area:8.0%

# %%
# построив гистограмму, определим частоту появления значения в исследуемом наборе наблюдений 
plt.hist(df['living_area'], bins = 5, color = '#cbff7b', range=(0, 70))
plt.axvline(df['living_area'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['living_area'].mean(), color='orange', linestyle='--', label='mean')
plt.title('Размер жилой площади', fontsize=20)
plt.xlabel('площадь жилая, м.кв.')
plt.ylabel('частота')
plt.legend()
plt.xticks(rotation=0);

# %%
# получим понимание структуры данных в столбце
df['living_area'].describe()
# Out:
# count   21796.00
# mean       34.46
# std        22.03
# min         2.00
# 25%        18.60
# 50%        30.00
# 75%        42.30
# max       409.70
# Name: living_area, dtype: float64

# %%
# визуально оценим характеристики распределения
df.boxplot('living_area') 
plt.ylim(1, 80);

# %%
share_of_deviation_la = len(df.query('1 >=  living_area|living_area >= 78')) / len(df) #  доля выбросов
print (share_of_deviation_la)
print (len(df))
print(len(df.query( '1 < living_area | living_area < 78'))) # количество наблюдений, в пределах нормального распределения
print('Доля выброса данных в столбце living_area:{:.1%}'.format(share_of_deviation_la))
# Out:
# 0.032617410017300306
# 23699
# 21796
# Доля выброса данных в столбце living_area:3.3%

# %% [markdown]
# **Вывод**.
#
# Замена типа данных не требуется, так как площадь измеряется в форме десятичных дробей. Доля пропусков в столбце living_area:8.0%. Доля выброса данных в столбце living_area:3.3%. Разброс значения между максимумом и минимумом значительный. Свыше 78 кв.м. - выброс.

# %% [markdown]
# #### floor 23699 non-null int64 - этаж

# %%
# получим общие данные

print(df['floor'].value_counts()) # вернёт уникальные значения и их количество;

quantity_of_pass = df['floor'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

print(len(df['floor'])) # покажет длину столбца

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/len(df['floor'])

print('Доля пропусков в столбце floor:{:.1%}'.format(share_of_pass))
# Out:
# 2     3368
# 3     3073
# 1     2917
# 4     2804
# 5     2621
# 6     1305
# 7     1218
# 8     1083
# 9     1051
# 10     687
# 12     526
# 11     523
# 13     379
# 15     343
# 14     337
# 16     315
# 17     227
# 18     178
# 19     147
# 21     125
# 22     113
# 20     110
# 23     100
# 24      63
# 25      46
# 26      24
# 27      10
# 28       1
# 33       1
# 29       1
# 30       1
# 32       1
# 31       1
# Name: floor, dtype: int64
# 0
# 23699
# Доля пропусков в столбце floor:0.0%

# %%
# построив гистограмму, определим частоту появления значения в исследуемом наборе наблюдений 
plt.hist(df['floor'], bins = 5, color = '#cbff7b', range=(0, 70))
plt.axvline(df['floor'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['floor'].mean(), color='orange', linestyle='--', label='mean')
plt.title('Этаж', fontsize=20)
plt.xlabel('этаж из ..')
plt.ylabel('частота')
plt.legend()
plt.xticks(rotation=0);

# %%
# получим понимание структуры данных в столбце
df['floor'].describe()
# Out:
# count   23699.00
# mean        5.89
# std         4.89
# min         1.00
# 25%         2.00
# 50%         4.00
# 75%         8.00
# max        33.00
# Name: floor, dtype: float64

# %%
# визуально оценим характеристики распределения
df.boxplot('floor') 
plt.ylim(0, 35);

# %%
share_of_deviation_fl = len(df.query('1 >  floor|floor > 18')) / len(df) #  доля выбросов
print(share_of_deviation_fl)

print(len(df.query('1 >  floor|floor > 18')))#  количество выбросов

print('Доля выброса данных в столбце floor:{:.1%}'.format(share_of_deviation_fl))
# Out:
# 0.031393729693236
# 744
# Доля выброса данных в столбце floor:3.1%

# %% [markdown]
# Вывод floor
#
# Доля пропусков в столбце floor:0.0%. Замена типа данных не требуется. Доля выброса данных в столбце floor:3.1%

# %% [markdown]
# #### balcony 12180 non-null float64 - число балконов

# %%
# получим общие данные

print(df['balcony'].value_counts()) # вернёт уникальные значения и их количество;

quantity_of_pass = df['balcony'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

print(len(df['balcony'])) # покажет длину столбца

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/len(df['balcony'])

print('Доля пропусков в столбце balcony:{:.1%}'.format(share_of_pass))
# Out:
# 1.00    4195
# 0.00    3758
# 2.00    3659
# 5.00     304
# 4.00     183
# 3.00      81
# Name: balcony, dtype: int64
# 11519
# 23699
# Доля пропусков в столбце balcony:48.6%

# %%
# построив гистограмму, определим частоту появления значения в исследуемом наборе наблюдений 
plt.hist(df['balcony'], bins = 5, color = '#b3ff15', range=(0, 70))
plt.axvline(df['balcony'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['balcony'].mean(), color='orange', linestyle='--', label='mean')
plt.title('Балконы', fontsize=20)
plt.xlabel('балкон')
plt.ylabel('частота')
plt.legend()
plt.xticks(rotation=0);

# %%
# получим понимание структуры данных в столбце
df['balcony'].describe()
# Out:
# count   12180.00
# mean        1.15
# std         1.07
# min         0.00
# 25%         0.00
# 50%         1.00
# 75%         2.00
# max         5.00
# Name: balcony, dtype: float64

# %%
# визуально оценим характеристики распределения
df.boxplot('balcony') 
plt.ylim(0, 7);

# %%
share_of_deviation_b = len(df.query('balcony >= 5')) / len(df) #  доля выбросов
print(share_of_deviation_b )

print(len(df.query('balcony >=5')))#  количество выбросов

print('Доля выброса данных в столбце balcony:{:.1%}'.format(share_of_deviation_b ))
# Out:
# 0.01282754546605342
# 304
# Доля выброса данных в столбце balcony:1.3%

# %% [markdown]
# Вывод balcony
#
# Необходима замена типа данных, число балконов - целое. Доля пропусков в столбце balcony:48.6%, если человек не указал число балконов — скорее всего, их нет. Такие пропуски правильно заменить на 0. Доля выброса данных в столбце balcony:1.3%

# %% [markdown]
# #### airports_nearest 18157 non-null float64 - расстояние до ближайшего аэропорта в метрах (м) - получены автоматически

# %%
# получим общие данные

print(df['airports_nearest'].value_counts()) # вернёт уникальные значения и их количество;

quantity_of_pass = df['airports_nearest'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

print(len(df['airports_nearest'])) # покажет длину столбца

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/len(df['airports_nearest'])

print('Доля пропусков в столбце airports_nearest:{:.1%}'.format(share_of_pass))
# Out:
# 37434.00    61
# 21928.00    32
# 39946.00    30
# 44870.00    30
# 37407.00    27
#             ..
# 25122.00     1
# 26768.00     1
# 22248.00     1
# 20475.00     1
# 14579.00     1
# Name: airports_nearest, Length: 8275, dtype: int64
# 5542
# 23699
# Доля пропусков в столбце airports_nearest:23.4%

# %% [markdown]
# **Вывод**
#
# **airports_nearest** расстояние до ближайшего аэропорта не является ключевым фактором, который получен автоматически. Пропуски трудно заменить, так как неизвестно какой аэропорт имеется ввиду. Можно предложить внести уточнения. Пропуски не будут заполнены. Замена типа данных не нужна. Доля пропусков в столбце airports_nearest:23.4%

# %% [markdown]
# #### cityCenters_nearest 18180 non-null float64 - расстояние до центра города (м) - получены автоматически

# %%
#переименуем столбец
df.rename(columns={'cityCenters_nearest': 'cityсenters_nearest'}, inplace=True)

# %%
# получим общие данные
print(df['cityсenters_nearest'].value_counts()) # вернёт уникальные значения и их количество;
quantity_of_pass = df['cityсenters_nearest'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

length_of_series = len(df['cityсenters_nearest'])

print(length_of_series)

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/length_of_series

print('Доля пропусков в столбце cityсenters_nearest:{:.1%}'.format(share_of_pass))
# Out:
# 8460.00     61
# 20802.00    32
# 10720.00    30
# 8434.00     27
# 20444.00    27
#             ..
# 13104.00     1
# 11280.00     1
# 27218.00     1
# 10501.00     1
# 208.00       1
# Name: cityсenters_nearest, Length: 7642, dtype: int64
# 5519
# 23699
# Доля пропусков в столбце cityсenters_nearest:23.3%

# %%
# получим понимание структуры данных в столбце
df['cityсenters_nearest'].describe()
# Out:
# count   18180.00
# mean    14191.28
# std      8608.39
# min       181.00
# 25%      9238.00
# 50%     13098.50
# 75%     16293.00
# max     65968.00
# Name: cityсenters_nearest, dtype: float64

# %%
# построив гистограмму, определим частоту появления значения в исследуемом наборе наблюдений 
plt.hist(df['cityсenters_nearest'], bins = 7, color = '#cbff7b', range=(0, 23000))
plt.axvline(df['cityсenters_nearest'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['cityсenters_nearest'].mean(), color='orange', linestyle='--', label='mean')
plt.title('Удалённость от центра г. Санкт-Петербурга', fontsize=20)
plt.xlabel('расстояние до центра')
plt.ylabel('частота')
plt.legend()
plt.xticks(rotation=0);

# %%
# визуально оценим характеристики распределения
df.boxplot('cityсenters_nearest') 
plt.ylim(0, 28000);

# %%
share_of_deviation_cen = len(df.query('cityсenters_nearest >= 27000')) / len(df) #  доля выбросов
print(share_of_deviation_cen)

print(len(df.query('cityсenters_nearest >= 27000')))#  количество выбросов

print('Доля выброса данных в столбце cityсenters_nearest:{:.1%}'.format(share_of_deviation_cen))
# Out:
# 0.07240811848601207
# 1716
# Доля выброса данных в столбце cityсenters_nearest:7.2%

# %% [markdown]
# **Вывод**
#
# **cityсenters_nearest** Доля пропусков в столбце cityсenters_nearest:23.3%. Необходима измена типа данных на int, точность до метра не нужна. Доля выброса данных в столбце cityсenters_nearest:7.2%. Очевидно, что большая часть квартир находится в 10 и более километрах от центра Питера.

# %% [markdown]
# #### days_exposition - 20518 non-null float64 - сколько дней было размещено объявление (от публикации до снятия)

# %%
# получим общие данные
print(df['days_exposition'].value_counts().sort_index()) # вернёт уникальные значения и их количество;
quantity_of_pass = df['days_exposition'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

length_of_series = len(df['days_exposition'])

print(length_of_series)

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/length_of_series

print('Доля пропусков в столбце days_exposition:{:.1%}'.format(share_of_pass))
# Out:
# 1.00         1
# 2.00         3
# 3.00       158
# 4.00       176
# 5.00       152
#           ...
# 1512.00      2
# 1513.00      1
# 1553.00      1
# 1572.00      1
# 1580.00      1
# Name: days_exposition, Length: 1141, dtype: int64
# 3181
# 23699
# Доля пропусков в столбце days_exposition:13.4%

# %% [markdown]
# N.B. Доля пропусков в столбце days_exposition:13.4%. Пропуски можно заменить путём рассчёта. Нужна заменить тип данных на int, такой точности достаточно.

# %%
# получим понимание структуры данных в столбце
df['days_exposition'].describe()
# Out:
# count   20518.00
# mean      180.89
# std       219.73
# min         1.00
# 25%        45.00
# 50%        95.00
# 75%       232.00
# max      1580.00
# Name: days_exposition, dtype: float64

# %%
# построив гистограмму, определим частоту появления значения в исследуемом наборе наблюдений 
plt.hist(df['days_exposition'], bins = 2, color = '#cbff7b', range=(0,400))
plt.axvline(df['days_exposition'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['days_exposition'].mean(), color='orange', linestyle='--', label='mean')
plt.title('Количество дней размещения', fontsize=20)
plt.xlabel('дней размещения')
plt.ylabel('частота')
plt.legend()
plt.xticks(rotation=0);

# %%
# визуально оценим характеристики распределения
df.boxplot('days_exposition') 
plt.ylim(0, 600);

# %%
share_of_deviation_aoe = len(df.query('days_exposition >= 500')) / len(df) #  доля выбросов
print(share_of_deviation_aoe)

print(len(df.query('days_exposition >= 500')))#  количество выбросов

print('Доля выброса данных в столбце days_exposition:{:.1%}'.format(share_of_deviation_aoe))
# Out:
# 0.07401156166926874
# 1754
# Доля выброса данных в столбце days_exposition:7.4%

# %% [markdown]
# Вывод
#
# days_exposition Доля пропусков в столбце days_exposition:7.4%. Пропуски можно заменить путём рассчёта. Нужна заменить тип данных на int, такой точности достаточно. Доля выброса данных в столбце days_exposition:5.1%.

# %%
# просмотрим - object
df.describe(include=['object']).T
# Out:
#                       count unique                  top   freq
# first_day_exposition  23699   1491  2018-02-01T00:00:00    368
# is_apartment           2775      2                False   2725
# locality_name         23650    364      Санкт-Петербург  15721

# %% [markdown]
# #### first_day_exposition 23699 non-null object - дата публикации

# %%
# получим общие данные
print(df['first_day_exposition'].value_counts().sort_index()) # вернёт уникальные значения и их количество;
quantity_of_pass = df['first_day_exposition'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

length_of_series = len(df['first_day_exposition'])

print(length_of_series)

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/length_of_series

print('Доля пропусков в столбце first_day_exposition:{:.1%}'.format(share_of_pass))
# Out:
# 2014-11-27T00:00:00    19
# 2014-11-29T00:00:00     1
# 2014-12-04T00:00:00     2
# 2014-12-05T00:00:00     1
# 2014-12-08T00:00:00     8
#                        ..
# 2019-04-29T00:00:00    37
# 2019-04-30T00:00:00    27
# 2019-05-01T00:00:00    30
# 2019-05-02T00:00:00    11
# 2019-05-03T00:00:00    20
# Name: first_day_exposition, Length: 1491, dtype: int64
# 0
# 23699
# Доля пропусков в столбце first_day_exposition:0.0%

# %% [markdown]
# **Вывод**
#
# **first_day_exposition** пропуски отсутствуют, необходимо заменить тип данных на дату, без указания времени.

# %% [markdown]
# #### is_apartment 2775 non-null object - апартаменты (булев тип)

# %%
# получим общие данные
print(df['is_apartment'].value_counts().sort_index()) # вернёт уникальные значения и их количество;
quantity_of_pass = df['is_apartment'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

length_of_series = len(df['is_apartment'])

print(length_of_series)

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/length_of_series

print('Доля пропусков в столбце is_apartment:{:.1%}'.format(share_of_pass))
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64
# 20924
# 23699
# Доля пропусков в столбце is_apartment:88.3%

# %% [markdown]
# **Вывод**
# **is_apartment** Тип данных заменим на bool, так логичнее. Очевидно, что данная отметка содержится в менее 10% случаев. Доля пропусков в столбце is_apartment:88.3%, я оставлю и внесу в рекомендации.

# %% [markdown]
# #### locality_name 23650 non-null object - название населённого пункта

# %%
# получим общие данные
print(df['locality_name'].value_counts().sort_index()) # вернёт уникальные значения и их количество;
quantity_of_pass = df['locality_name'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

length_of_series = len(df['locality_name'])

print(length_of_series)

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/length_of_series

print('Доля пропусков в столбце locality_name:{:.1%}'.format(share_of_pass))
# Out:
# Бокситогорск             16
# Волосово                 36
# Волхов                  111
# Всеволожск              398
# Выборг                  237
#                        ...
# село Путилово             2
# село Рождествено          3
# село Русско-Высоцкое      9
# село Старая Ладога        2
# село Шум                  1
# Name: locality_name, Length: 364, dtype: int64
# 49
# 23699
# Доля пропусков в столбце locality_name:0.2%

# %% [markdown]
# **Вывод**
#
# Доля пропусков в столбце locality_name:0.2%. Число незначительное - удалю.

# %%
# просмотрим - bool
df.describe(include=['bool']).T
# Out:
#            count unique    top   freq
# studio     23699      2  False  23550
# open_plan  23699      2  False  23632

# %% [markdown]
# #### studio 23699 non-null bool - квартира-студия (булев тип)

# %%
# получим общие данные
print(df['studio'].value_counts().sort_index()) # вернёт уникальные значения и их количество;
quantity_of_pass = df['studio'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

length_of_series = len(df['studio'])

print(length_of_series)

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/length_of_series

print('Доля пропусков в столбце studio:{:.1%}'.format(share_of_pass))
# Out:
# False    23550
# True       149
# Name: studio, dtype: int64
# 0
# 23699
# Доля пропусков в столбце studio:0.0%

# %% [markdown]
# **Вывод**
#
# **studio** всего 149 студий, пропусков нет. Замена данных не требуется.

# %% [markdown]
# #### open_plan 23699 non-null bool - свободная планировка (булев тип)

# %%
# получим общие данные
print(df['open_plan'].value_counts().sort_index()) # вернёт уникальные значения и их количество;
quantity_of_pass = df['open_plan'].isna().sum() # вернёт количество пропусков;
print(quantity_of_pass)

length_of_series = len(df['open_plan'])

print(length_of_series)

#Доля пропусков будет рассчитана по формуле
share_of_pass = quantity_of_pass/length_of_series

print('Доля пропусков в столбце open_plan:{:.1%}'.format(share_of_pass))
# Out:
# False    23632
# True        67
# Name: open_plan, dtype: int64
# 0
# 23699
# Доля пропусков в столбце open_plan:0.0%

# %% [markdown]
# **Вывод**
#
# **open_plan** всего 67 квартир с открытой планировкой, пропусков нет. Замена данных не требуется.
#
# Датафрейм содержит 2 столбца с булевыми переменными, частота повторов квартир-студий низкая, с открытой планировкой - минимальная. Пропусков нет, замена типа данных не требуется. В обоих типах не предусмотрена отдельная кухня.

# %% [markdown]
# ### Вывод

# %%
# создам описательный датафрейм
data_description = {
    'Наименование столбца': ['last_price', 'total_images', 'total_area', 'rooms', 'ceiling_height', 
                             'floors_total', 'kitchen_area', 'living_area', 'floor', 'balcony',
                            'airports_nearest', 'cityсenters_nearest', 'parks_around3000', 'parks_nearest',
                            'ponds_around3000', 'ponds_nearest', 'days_exposition', 'first_day_exposition', 'is_apartment',
                            'locality_name', 'studio', 'open_plan' ], 
    
    'Характеристика': ['не содержит пропусков, требуется замена типа данных на int.Не указана единица измерения (рубли, рубли/кв.м.). Вопрос с единицами измерения - в баг-репорт. Разброс может объясняться тем, что часть объявлений относится к аренде, часть к продажам недвижимости. Доля выброса данных в столбце last_price:8.6%', 
                       'не содержит пропусков, однако, не является определяющим рыночную стоимость объектов недвижимости параметром. И скорее влияет на продвижение самого объявления.', 
                      'Доля пропусков в столбце total_area:0.0%. Тип данных можно не менять, так как это площать квартиры. Значительная часть данных находится в диапазоне 25-45 кв.м. Доля выброса данных в столбце total_area:4.8%.', 
                    'тип данных менять не нужно. Пропусков нет. Доля выброса данных в столбце rooms:0.4%',
                      'Доля пропусков в столбце ceiling_height:39% - в баг-репорт. Доля выброса данных в столбце ceiling_height:32.8%. Значения свыше 6 - выбросы.'
                       'Замену пропусков, в целом, на значения выполнять нецелесообразно, так как отсутствуют допонительные параметры,' 
                       'по которым можно было бы определить значение: тип материала (дерево, кирпич, панель), номер серии дома.' 
                       'Рекомендации разработчикам - внести уточнение. Непонятная ситуация. Так как решение принимается без участия и помощи сторонних лиц, я заменю пропуски на медиану в зависимости от локации. Обычно все здания в населённых пунктах примерно одного масштаба (locality_name).',
                      'Доля пропусков в столбце floors_total:0.4% - незначительна, пропуски можно удалить. Доля выброса данных в столбце floors_total:0.1% - удалим. Нужна замена типа данных, этажность не может быть дробной.',
                      'Доля пропусков в столбце kitchen_area:9.6% в баг-репорт. Тип данных можно не менять, так как речь идёт о площади. '
                       'Обратимся СП 54.13330.2016 Здания жилые многоквартирные. Актуализированная редакция СНиП 31-01-2003 (с Изменениями N 1, 2, 3): в однокомнатных квартирах допускается проектировать кухни или кухни-ниши площадью не менее 5 м².' 
                       'Пропуски могут быть свидетельством того, что продаётся студия или квартира с открытой планировкой. Доля выброса данных в столбце floors_total:5.2%.', 
                      'Замена типа данных не требуется, так как площадь измеряется в форме десятичных дробей. Доля пропусков в столбце living_area:8.0% в баг-репорт. Доля выброса данных в столбце living_area:3.3%.' 
                       'Разброс значения между максимумом и минимумом значительный. Свыше 78 кв.м. - выброс.',
                      'Доля пропусков в столбце floor:0.0%. Замена типа данных не требуется. Доля выброса данных в столбце floor:3.1%.', 
                      'Необходима замена типа данных, число балконов - целое. Доля пропусков в столбце balcony:48.6% в баг-репорт, если человек не указал число балконов — скорее всего, их нет. Такие пропуски правильно заменить на 0. Доля выброса данных в столбце balcony:1.3%',
                     'расстояние до ближайшего аэропорта не является ключевым фактором, который получен автоматически. Пропуски трудно заменить, так как неизвестно какой аэропорт имеется ввиду.' 
                       'Можно предложить внести уточнения. Пропуски не будут заполнены. Замена типа данных не нужна.', 
                      'Доля пропусков в столбце cityсenters_nearest:23.3% в баг-репорт. Замена типа данных нужна. Доля выброса данных в столбце cityсenters_nearest:7.2%.' 
                       'Очевидно, что большая часть квартир находится в 10 и более километрах от центра Питера.',
                      'Доля пропусков в столбце parks_around3000:23.3% в баг-репорт, не является ключевым фактором, который получен автоматически. Пропуски трудно заменить, так как неизвестно какие парки имееются ввиду. Можно предложить внести уточнения. Пропуски не будут заполнены. Замена типа данных не нужна.',  
                      'Доля пропусков в столбце parks_nearest:65.9%, не является ключевым фактором, который получен автоматически. Пропуски трудно заменить, так как неизвестно какой парк имеется ввиду. Можно предложить внести уточнения. Пропуски не будут заполнены. Замена типа данных не нужна.',
                      'Доля пропусков в столбце ponds_around3000:23.3% в баг-репорт, не является ключевым фактором, который получен автоматически. Пропуски трудно заменить, так как неизвестно какие пруды имеются ввиду. Можно предложить внести уточнения. Пропуски не будут заполнены. Замена типа данных не нужна. Интересно, что в столбце parks_around3000- число парков в радиусе 3 км - такое же количество пропусков.',
                      'Доля пропусков в столбце ponds_nearest:61.6% в баг-репорт, не является ключевым фактором, который получен автоматически. Пропуски трудно заменить, так как неизвестно какой пруд имеется ввиду. Можно предложить внести уточнения. Пропуски не будут заполнены. Замена типа данных не нужна. Интересно, что в столбце расстояние до ближайшего парка - также значительное количество пропусков.',
                      'Доля пропусков в столбце days_exposition:13.4% в баг-репорт. Пропуски можно заменить путём рассчёта. Нужна заменить тип данных на int, такой точности достаточно. Доля выброса данных в столбце days_exposition:5.1%.',
                      'пропуски отсутствуют, необходимо заменить тип данных на дату, без указания времени.', 
                     'Тип данных заменим на bool, так логичнее. Очевидно, что данная отметка содержится в менее 10% случаев. Доля пропусков в столбце is_apartment:88.3%, я оставлю и внесу в рекомендации.',
                       'Доля пропусков в столбце locality_name:0.2%. Число незначительное - удалю.',
                       'всего 149 студий, пропусков нет. Замена данных не требуется.',
                      ' всего 67 квартир с открытой планировкой, пропусков нет. Замена данных не требуется.'                    
                      ]
    
    
                   
} 
 
data_description = pd.DataFrame(data_description)
pd.set_option('max_colwidth', 700)
pd.set_option('display.width', 600)

data_description
# Out:
#     Наименование столбца  \
# 0             last_price
# 1           total_images
# 2             total_area
# 3                  rooms
# 4         ceiling_height
# 5           floors_total
# 6           kitchen_area
# 7            living_area
# 8                  floor
# 9                balcony
# 10      airports_nearest
# 11   cityсenters_nearest
# 12      parks_around3000
# 13         parks_nearest
# 14      ponds_around3000
# 15         ponds_nearest
# 16       days_exposition
# 17  first_day_exposition
# 18          is_apartment
# 19         locality_name
# 20                studio
# 21             open_plan
#
# ...

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Замена пропусков и изменение типа данных

# %%
# создам датафрейм, который будем модернизировать
df_work = df
df_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityсenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# Далее, постепенно проработаем поставленные задачи для каждой группы данных.
# 1. Удалим или заменим пропуски.
# 2. Заменим типы данных, в случае необходимости.

# %%
# заменим тип данных в столбце с ценой.
df_work['last_price'] = df['last_price'].astype(int)
df_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null int64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityсenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %%
# удалим пропуски в locality_name
df_work = df_work.dropna(subset=['locality_name']) 
df_work['locality_name'].isna().sum()
# Out:
# 0

# %%
# приведу к единообразию наименования в locality_name
df_work['locality_name'] = df_work['locality_name'].replace('поселок', 'посёлок', regex=True)
df_work['locality_name'] = df_work['locality_name'].replace('городской посёлок', 'посёлок', regex=True)
df_work['locality_name'].unique()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# array(['Санкт-Петербург', 'посёлок Шушары', 'посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
# ...

# %%
# просмотрим пропуски
df_work['ceiling_height'].isna().sum()
# Out:
# 9160

# %%
# просмотрим аномалии
df_work.loc[df_work['ceiling_height'] >10]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  ceiling_height  floors_total  living_area  floor is_apartment  ...  kitchen_area  balcony          locality_name  airports_nearest cityсenters_nearest  parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  days_exposition
# 355              17     3600000       55.20  2018-07-12T00:00:00      2           25.00          5.00        32.00      2        False  ...           nan     2.00                Гатчина               nan                 nan               nan            nan               nan            nan           259.00
# 3148             14     2900000       75.00  2018-11-12T00:00:00      3           32.00          3.00        53.00      2          NaN  ...          8.00      nan                 Волхов               nan                 nan               nan            nan               nan            nan              nan
# ...

# %% [markdown]
# 25 записей с высотой, выходящей за пределы 10.

# %%
# заменим пропуски в столбце ceiling_height на медиану по группе.
df_work['ceiling_height']= df['ceiling_height'].fillna(df_work['ceiling_height'].median())
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_work['ceiling_height'].isna().sum()
# Out:
# 0

# %%
# check

df_work.loc[(df_work['ceiling_height'] >10), 'ceiling_height'] = df_work.ceiling_height/10
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
# check

df_work['ceiling_height'] = np.where((df_work['ceiling_height'] >10), df_work.ceiling_height/10, df_work.ceiling_height)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# check

df_work[df_work['ceiling_height'] >= 9]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  ceiling_height  floors_total  living_area  floor is_apartment  ...  kitchen_area  balcony    locality_name  airports_nearest cityсenters_nearest  parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  days_exposition
# 22869             0    15000000       25.00  2018-07-25T00:00:00      1           10.00          5.00        14.00      5         True  ...         11.00     5.00  Санкт-Петербург          34963.00             8283.00              1.00         223.00              3.00          30.00            19.00
#
# [1 rows x 22 columns]

# %%
# end of block check

# %%
# сохраню для работы соответствующие условию
df_work = df_work.query('ceiling_height < 10')

# %%
# удалим пропуски floors_total. Доля пропусков в столбце floors_total:0.4% 
df_work = df_work.dropna(subset=['floors_total']) 
df_work['floors_total'].isna().sum()
# Out:
# 0

# %%
# Нужна замена типа данных, этажность не может быть дробной.
df_work['floors_total'] = df_work['floors_total'].astype(int)
df_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23564 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23564 non-null int64
# last_price              23564 non-null int64
# total_area              23564 non-null float64
# first_day_exposition    23564 non-null object
# rooms                   23564 non-null int64
# ceiling_height          23564 non-null float64
# floors_total            23564 non-null int64
# living_area             21699 non-null float64
# floor                   23564 non-null int64
# is_apartment            2759 non-null object
# studio                  23564 non-null bool
# open_plan               23564 non-null bool
# kitchen_area            21342 non-null float64
# balcony                 12089 non-null float64
# locality_name           23564 non-null object
# airports_nearest        18040 non-null float64
# cityсenters_nearest     18063 non-null float64
# parks_around3000        18064 non-null float64
# ...

# %% [markdown]
# kitchen_area
#
# Доля пропусков в столбце kitchen_area:9.6%.

# %%
# заменим на медиану по группе
df_work['kitchen_area'] = df_work['kitchen_area'].fillna(df_work.groupby('locality_name')['kitchen_area'].transform('median'))

# %%
# проверка
df_work['kitchen_area'].isna().sum()
# Out:
# 19

# %%
df_work.dropna(subset=['kitchen_area'], inplace = True)

# %%
df_work.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area              1849
# floor                       0
# is_apartment            20788
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                 11460
# locality_name               0
# airports_nearest         5507
# cityсenters_nearest      5484
# parks_around3000         5483
# parks_nearest           15516
# ponds_around3000         5483
# ponds_nearest           14511
# days_exposition          3170
# dtype: int64

# %% [markdown]
# living_area
#
# Замена типа данных не требуется.Доля пропусков в столбце living_area:8.0%
# Жилая площадь - это сумма площадей жилых комнат, предназначенных проектом для постоянного проживания (спален, гостиных) - https://blog.domclick.ru/. Таким образом, можно применить уже известную долю для кухни в общей площади, принебречь коридорами и санузлом. Явно можно ориентироваться на общую площадь.

# %%
print(df_work['living_area'].corr(df_work['total_area']))
# Out:
# 0.9397691493821273

# %% [markdown]
# очень высокая положительная корреляция

# %%
df_work['total_area'].isna().sum()
# Out:
# 0

# %%
df_work['living_area'].isna().sum()
# Out:
# 1849

# %%
# произведу замену
df_work['living_area'] = df_work['living_area'].fillna(df_work.groupby('locality_name')['living_area'].transform('median'))

# %%
# проверка
df_work['living_area'].isna().sum()
# Out:
# 1

# %%
df_work.dropna(subset = ['living_area'], inplace = True)

# %%
# выполним проверку
mg = df_work[['living_area', 'kitchen_area', 'total_area']]

mg
# Out:
#        living_area  kitchen_area  total_area
# 0            51.00         25.00      108.00
# 1            18.60         11.00       40.40
# 2            34.30          8.30       56.00
# 3            31.30          9.90      159.00
# 4            32.00         41.00      100.00
# ...            ...           ...         ...
# 23694        73.30         13.83      133.81
# 23695        38.00          8.50       59.00
# 23696        29.70          8.15       56.70
# 23697        31.30         23.30       76.75
# 23698        12.30          9.00       32.30
#
# [23544 rows x 3 columns]

# %%
mg = mg.query('living_area +kitchen_area > total_area')
mg
# Out:
#        living_area  kitchen_area  total_area
# 30           28.70          8.35       32.80
# 44           31.30          9.90       40.00
# 164          36.50          7.40       40.30
# 184          26.10          6.20       30.20
# 238          31.30         12.40       43.40
# ...            ...           ...         ...
# 23554        31.30          9.90       26.00
# 23579        18.00         10.69       24.80
# 23632        31.30          9.90       38.00
# 23637        17.00         10.00       26.00
# 23679        30.00          8.20       35.00
#
# [711 rows x 3 columns]

# %% [markdown]
# 710 позиций, где расчёт выполнился неверно

# %%
# оставлю в работе только корректные позиции
df_work = df_work.query('living_area +kitchen_area <= total_area')
df_work
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  ceiling_height  floors_total  living_area  floor is_apartment  ...  kitchen_area  balcony        locality_name  airports_nearest cityсenters_nearest  parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  days_exposition
# 0                20    13000000      108.00  2019-03-07T00:00:00      3            2.70            16        51.00      8          NaN  ...         25.00      nan      Санкт-Петербург          18863.00            16028.00              1.00         482.00              2.00         755.00              nan
# 1                 7     3350000       40.40  2018-12-04T00:00:00      1            2.65            11        18.60      1          NaN  ...         11.00     2.00       посёлок Шушары          12817.00            18603.00              0.00            nan              0.00            nan            81.00
# ...

# %% [markdown]
# balcony
#
# Доля пропусков в столбце balcony:48.6%, если человек не указал число балконов — скорее всего, их нет. Такие пропуски правильно заменить на 0. Нужна замена типа данных, количество балконов не может быть дробью.

# %%
df_work['balcony'] = df_work['balcony'].fillna(0).astype(int)

# %% [markdown]
# Для airports_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest произведу замену пропусков на 0, а также произведу замену типа данных на целочисленный.

# %%
df_work['airports_nearest'] = df_work['airports_nearest'].fillna(0).astype(int)
df_work['parks_around3000'] = df_work['parks_around3000'].fillna(0).astype(int)
df_work['parks_nearest'] = df_work['parks_nearest'].fillna(0).astype(int)
df_work['ponds_around3000'] = df_work['ponds_around3000'].fillna(0).astype(int)
df_work['ponds_nearest'] = df_work['ponds_nearest'].fillna(0).astype(int)

# %% [markdown]
# cityсenters_nearest
#
# Доля пропусков в столбце cityсenters_nearest:23.3%. Замену типа данных прозведём, расчёты до см не нужны.
# Произведу замену пропусков в зависимости от населённого пункта, там где замена будет неуспешной, поставлю 0 - как обозначение отсутствия данных. В первоначальном датафрейме нулей не было.

# %%
df_work['cityсenters_nearest'] = df_work['cityсenters_nearest'].fillna(
    df_work.groupby('locality_name')['cityсenters_nearest'].transform('median'))
df_work['cityсenters_nearest'] = df_work['cityсenters_nearest'].fillna(0).astype(int)
df_work['cityсenters_nearest'].isna().sum()
# Out:
# 0

# %% [markdown]
# first_day_exposition
#
# пропуски отсутствуют, необходимо заменить тип данных на дату, без указания времени

# %%
df_work['first_day_exposition'] = pd.to_datetime(df_work['first_day_exposition'], format='%Y-%m-%d')
df_work.dtypes
# Out:
# total_images                     int64
# last_price                       int64
# total_area                     float64
# first_day_exposition    datetime64[ns]
# rooms                            int64
# ceiling_height                 float64
# floors_total                     int64
# living_area                    float64
# floor                            int64
# is_apartment                    object
# studio                            bool
# open_plan                         bool
# kitchen_area                   float64
# balcony                          int64
# locality_name                   object
# airports_nearest                 int64
# cityсenters_nearest              int64
# parks_around3000                 int64
# parks_nearest                    int64
# ponds_around3000                 int64
# ponds_nearest                    int64
# days_exposition                float64
# dtype: object

# %% [markdown]
# days_exposition
#
# Доля пропусков в столбце days_exposition:13.4%.
# Пропуски можно заменить путём рассчёта. Нужно заменить тип данных на int, такой точности достаточно.

# %%
# я заменю пропуски нулём, чтобы было очевидно отсутствие данных.
# "В этом случае правильно оставить эти значения пустыми. Отсутствие значения — тоже важный сигнал, который не нужно прятать"
df_work['days_exposition'] = df_work['days_exposition'].fillna(0)

df_work['days_exposition'] = df_work['days_exposition'].astype(int)

# %%
df_work['days_exposition'].isna().sum()
df_work['days_exposition']
# Out:
# 0          0
# 1         81
# 2        558
# 3        424
# 4        121
#         ...
# 23694      0
# 23695     45
# 23696      0
# 23697    602
# 23698      0
# Name: days_exposition, Length: 22833, dtype: int64

# %% [markdown]
# is_apartment
#
# Тип данных заменим на bool, так логичнее. Очевидно, что данная отметка содержится в менее 10% случаев. Доля пропусков в столбце is_apartment:88.3%, я заменю на 0, как отсутствие данных и внесу в рекомендации.

# %%
df_work['is_apartment'] = df_work['is_apartment'].fillna(0).astype(bool)
df_work['is_apartment'].isna().sum()
df_work['is_apartment'].dtypes
# Out:
# dtype('bool')

# %%
df_work['is_apartment']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23694    False
# 23695    False
# 23696    False
# 23697    False
# 23698    False
# Name: is_apartment, Length: 22833, dtype: bool

# %% [markdown]
# Баг-репорт.
#
# **Дата фрейм содержал пропуски в следующих категориях данных, вносимых продавцом:**
# Доля пропусков в столбце ceiling_height:39%.
# Доля пропусков в столбце kitchen_area:9.6%.
# Доля пропусков в столбце living_area:8.0%.
# Доля пропусков в столбце balcony:48.6%.
# Доля пропусков в столбце days_exposition:7.4%.
# Доля пропусков в столбце is_apartment:88.3%.
#
# **Дата фрейм содержал пропуски в следующих категориях данных, полученных автоматически:**
# Доля пропусков в столбце airports_nearest:23.4%
# Доля пропусков в столбце cityсenters_nearest:23.3%.
# Доля пропусков в столбце parks_around3000:23.3%.
# Доля пропусков в столбце parks_nearest:65.9%.
# Доля пропусков в столбце ponds_nearest:61.6%.
#
# **Дата фрейм содержит значительные выбросы в следующих категориях данных:**
# Доля выброса данных в столбце cityсenters_nearest:7.2%.
#
# Предлагается:
#
# ввести режим автозаполнения для всех позиций;
#
# обновить или заменить базы, применяемые для внесения автоматических данных;
#
# проанализировать выбросы данных;
#
# провести аудит дат и сроков активности объявлений.

# %% [markdown]
# ### Вывод
# **В ходе выполнения проекта**
#
# произведено первичное исследование тематики в открытых источниках;
#
# проанализированы данные первичного датафрейма;
#
# устранены пропуски посредством:
#
# 1. удаления (locality_name: 0,2%, малая доля в ceiling_height, floors_total:0.4%);
#
# 2. замены расчётными показателями (ceiling_height:39%, kitchen_area:9.6%, living_area:8.0%, сityсenters_nearest:23.3%, days_exposition:7.4%);
#
# 3. замены нулевым показателем - как отметки об отсутствии данных days_exposition. Доля пропусков в столбце balcony:48.6%, если человек не указал число балконов — скорее всего, их нет. Для airports_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest произведу замену пропусков на 0. Доля пропусков в столбце is_apartment:88.3%.
#
# 4. унифицированы типы названий в locality_name;
#
# 5. удалены дубликаты.
#
#
# Причинами появления пропусков могут быть:
#
# невнимательность при вводе;
#
# отсутствие контрольных точек при размещении объявления;
#
# отсутствие режима автозаполнения;
#
# отсутствие актуальных баз.
#
#
# Предлагается:
#
# ввести режим автозаполнения для всех позиций;
#
# обновить или заменить базы, применяемые для внесения автоматических данных;
#
# проанализировать выбросы данных;
#
# провести аудит дат и сроков активности объявлений.

# %%
df_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22833 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            22833 non-null int64
# last_price              22833 non-null int64
# total_area              22833 non-null float64
# first_day_exposition    22833 non-null datetime64[ns]
# rooms                   22833 non-null int64
# ceiling_height          22833 non-null float64
# floors_total            22833 non-null int64
# living_area             22833 non-null float64
# floor                   22833 non-null int64
# is_apartment            22833 non-null bool
# studio                  22833 non-null bool
# open_plan               22833 non-null bool
# kitchen_area            22833 non-null float64
# balcony                 22833 non-null int64
# locality_name           22833 non-null object
# airports_nearest        22833 non-null int64
# cityсenters_nearest     22833 non-null int64
# parks_around3000        22833 non-null int64
# ...

# %%
# Поиск и удаление дубликатов
df_work = df_work.drop_duplicates(subset = ['total_area', 'living_area', 'kitchen_area', 'first_day_exposition'], keep = False)
df_work
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  ceiling_height  floors_total  living_area  floor  is_apartment  ...  kitchen_area  balcony        locality_name  airports_nearest cityсenters_nearest  parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  days_exposition
# 0                20    13000000      108.00           2019-03-07      3            2.70            16        51.00      8         False  ...         25.00        0      Санкт-Петербург             18863               16028                 1            482                 2            755                0
# 1                 7     3350000       40.40           2018-12-04      1            2.65            11        18.60      1         False  ...         11.00        2       посёлок Шушары             12817               18603                 0              0                 0              0               81
# ...

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# ### Расчёт цены квадратного метра

# %%
# Добавлен столбец price_per_meter
df_work['price_per_meter'] = (df_work['last_price'] / df_work['total_area']).astype(int)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Расчёт дня недели, месяца и года публикации объявления

# %%
# Добавлены столбцы
df_work['weekday'] = df_work['first_day_exposition'].dt.weekday
df_work['month'] = df_work['first_day_exposition'].dt.month
df_work['year'] =  df_work['first_day_exposition'].dt.year
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ### Этаж квартиры cгруппирован по вариантам — первый, последний, другой

# %%
# функция для создания категорий

floors_total = df_work['floors_total']

def what_floor(row):
    floor = row['floor']
    if floor == 1:
        return('первый')
    elif floor == row['floors_total']:
        return('последний')
    return('другой')

# %%
# добавление столбца
df_work['floor_type'] = df_work.apply(what_floor, axis=1)
df_work.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    total_images  last_price  total_area first_day_exposition  rooms  ceiling_height  floors_total  living_area  floor  is_apartment  ...  parks_around3000  parks_nearest  ponds_around3000  ponds_nearest days_exposition  price_per_meter  weekday  month  year  floor_type
# 0            20    13000000      108.00           2019-03-07      3            2.70            16        51.00      8         False  ...                 1            482                 2            755               0           120370        3      3  2019      другой
# ...

# %%
# скорректируем данные в соответствии соблюдением этажности
df_work = df_work.query('floor <=floors_total')
df_work
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  ceiling_height  floors_total  living_area  floor  is_apartment  ...  parks_around3000  parks_nearest  ponds_around3000  ponds_nearest days_exposition  price_per_meter  weekday  month  year  floor_type
# 0                20    13000000      108.00           2019-03-07      3            2.70            16        51.00      8         False  ...                 1            482                 2            755               0           120370        3      3  2019      другой
# 1                 7     3350000       40.40           2018-12-04      1            2.65            11        18.60      1         False  ...                 0              0                 0              0              81            82920        1     12  2018      первый
# ...

# %% [markdown]
# ### Рассчитаны соотношения жилой и общей площади, а также площади кухни к общей.

# %%
# рассчитаем долю жилой площади, исходя из общей площади и добавим столбец в датафрейм
df_work['living_area_share_calc'] = df_work['living_area'] /df_work['total_area']

# %%
# рассчитан и добавлен в датафрейм столбец, показывающий отношение площади кухни к общей.
df_work['kitchen_area_share_calc'] = df_work['kitchen_area']/df_work['total_area']
df_work
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  ceiling_height  floors_total  living_area  floor  is_apartment  ...  ponds_around3000  ponds_nearest  days_exposition  price_per_meter weekday  month  year  floor_type  living_area_share_calc  kitchen_area_share_calc
# 0                20    13000000      108.00           2019-03-07      3            2.70            16        51.00      8         False  ...                 2            755                0           120370       3      3  2019      другой                    0.47                     0.23
# 1                 7     3350000       40.40           2018-12-04      1            2.65            11        18.60      1         False  ...                 0              0               81            82920       1     12  2018      первый                    0.46                     0.27
# ...

# %% [markdown]
# ### Вывод
#
# **В ходе выполнения проекта выполнены в соответствии с заданием расчёты с добавлением столбцов в датафрейм**
#
# 1. Расчёт цены квадратного метра. Добавлен столбец price_per_meter.
# 2. Расчёт дня недели(добавлен столбец weekday), месяца(добавлен столбец month) и года(добавлен столбец year) публикации объявления.
# 3. Этаж квартиры cгруппирован по вариантам — первый, последний, другой. Добавлен столбец floor_type.
# 4. Рассчитаны соотношения жилой и общей площади (добавлен столбец living_area_share_calc), а также площади кухни к общей (добавлен столбец kitchen_area_share_calc).

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Исследована цена

# %%
# построим гистограму для last_price, увидим частоту:
plt.hist(df_work['last_price'], bins = 30, color = '#ccff00', range=(0, 22000000))
plt.axvline(df_work['last_price'].median(), color='r', linestyle='--', label='median')
plt.axvline(df_work['last_price'].mean(), color='orange', linestyle='--', label='mean')
plt.title('Цена на момент снятия с публикации', fontsize=20)
plt.xlabel('финальная цена')
plt.ylabel('частота')
plt.legend()
plt.xticks(rotation=15);

# %%
last_price_mean = df_work['last_price'].mean().astype(int)
last_price_median = df_work['last_price'].median().astype(int)
print('Среднее арифметическое значение для last_price - ', last_price_mean)
print('Медианное значение для last_price - ', last_price_median)
# Out:
# Среднее арифметическое значение для last_price -  6644114
# Медианное значение для last_price -  4700000

# %%
df_work.boxplot('last_price') 
plt.ylim(0, 12000000);

# %% [markdown]
# Описание
#
# Видно, что пик смещён влево от центра и медианной линии, а также отражён на графике длинный "хвост". Распределение является асимметричным: основная область расположена в промежутке от 3 до 4,2 млн. Среднее арифметическое значение для last_price - 6.5 млн.Медианное значение - 4,6 млн.

# %%
share_of_deviation_pr = len(df.query('10000 >  last_price|last_price > 20000000')) / len(df_work) #  доля выбросов
print(share_of_deviation_pr)
print(len(df.query('10000 >  last_price|last_price > 11900000'))) #  количество данных в выбросе
print('Доля выброса данных в столбце last_price:{:.1%}'.format(share_of_deviation_pr))
# Out:
# 0.031067363888034452
# 2034
# Доля выброса данных в столбце last_price:3.1%

# %%
# устраним выбросы по признаку last_price
df_work = df_work.query('10000 <=  last_price|last_price <= 25000000')
df_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22757 entries, 0 to 23698
# Data columns (total 29 columns):
# total_images               22757 non-null int64
# last_price                 22757 non-null int64
# total_area                 22757 non-null float64
# first_day_exposition       22757 non-null datetime64[ns]
# rooms                      22757 non-null int64
# ceiling_height             22757 non-null float64
# floors_total               22757 non-null int64
# living_area                22757 non-null float64
# floor                      22757 non-null int64
# is_apartment               22757 non-null bool
# studio                     22757 non-null bool
# open_plan                  22757 non-null bool
# kitchen_area               22757 non-null float64
# balcony                    22757 non-null int64
# locality_name              22757 non-null object
# airports_nearest           22757 non-null int64
# cityсenters_nearest        22757 non-null int64
# ...

# %% [markdown]
# ### Исследован показатель Общая площадь

# %%
# построим гистограму для total_area, увидим частоту:
plt.hist(df_work['total_area'], bins = 30, color = '#ccff00', range=(0, 100))
plt.axvline(df_work['total_area'].median(), color='r', linestyle='--', label='median')
plt.axvline(df_work['total_area'].mean(), color='orange', linestyle='--', label='mean')
plt.title('Площадь квартиры в квадратных метрах (м²)', fontsize=20)
plt.xlabel('площадь')
plt.ylabel('частота')
plt.legend()
plt.xticks(rotation=15);

# %%
total_area_mean = df_work['total_area'].mean().astype(int)
total_area_median = df_work['total_area'].median().astype(int)
print('Среднее арифметическое значение для total_area - ', total_area_mean)
print('Медианное значение для total_area - ', total_area_median)
# Out:
# Среднее арифметическое значение для total_area -  61
# Медианное значение для total_area -  53

# %% [markdown]
# Описание
#
# Видно, что пик смещён влево от центра и медианной линии, а также отражён на графике длинный "хвост". Распределение является асимметричным и неравномерным. Квартиры площадью менее 20 кв.м. практически не встречаются, в среднем площадь квартиры от 30 до 45 кв.м. Среднее арифметическое значение -  60 кв.м. Медианное значение  -  52 кв.м.

# %%
# построим диаграмму размаха:
df_work.boxplot('total_area') 
plt.ylim(0, 120);

# %%
# устраним выбросы по признаку total_area
df_work = df_work.query('total_area >=10 and total_area <= 220')
df_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22583 entries, 0 to 23698
# Data columns (total 29 columns):
# total_images               22583 non-null int64
# last_price                 22583 non-null int64
# total_area                 22583 non-null float64
# first_day_exposition       22583 non-null datetime64[ns]
# rooms                      22583 non-null int64
# ceiling_height             22583 non-null float64
# floors_total               22583 non-null int64
# living_area                22583 non-null float64
# floor                      22583 non-null int64
# is_apartment               22583 non-null bool
# studio                     22583 non-null bool
# open_plan                  22583 non-null bool
# kitchen_area               22583 non-null float64
# balcony                    22583 non-null int64
# locality_name              22583 non-null object
# airports_nearest           22583 non-null int64
# cityсenters_nearest        22583 non-null int64
# ...

# %% [markdown]
# ### Исследован показатель Количество комнат

# %%
# построим гистограмму, чтобы выявить частоту
plt.hist(df_work['rooms'], bins = 15, color = '#ccff00', range=(0, 10))
plt.axvline(df_work['rooms'].median(), color='r', linestyle='--', label='median')
plt.axvline(df_work['rooms'].mean(), color='orange', linestyle='--', label='mean')
plt.title('Количество комнат', fontsize=20)
plt.xlabel('комнат в квартире')
plt.ylabel('частота')
plt.legend()
plt.xticks(rotation=0);

# %%
rooms_mean = df_work['rooms'].mean()
rooms_median = df_work['rooms'].median().astype(int)
print('Среднее арифметическое значение для rooms - ', round(rooms_mean))
print('Медианное значение для rooms - ', rooms_median)
# Out:
# Среднее арифметическое значение для rooms -  2
# Медианное значение для rooms -  2

# %% [markdown]
# Описание
#
# Медиана и среднее совпали в данном случае, самые распространённые квартиры - 2-х комнатные, выбросов почти нет.

# %%
# построим диаграмму размаха:
df_work.boxplot('rooms') 
plt.ylim(0, 12);

# %%
share_of_deviation_room = len(df_work.query('rooms > 7')) / len(df_work) #  доля выбросов
print(share_of_deviation_room)

print('Доля выброса данных в столбце rooms:{:.1%}'.format(share_of_deviation_room))
# Out:
# 0.0002656865783996812
# Доля выброса данных в столбце rooms:0.0%

# %%
df_work = df_work.query('rooms <7')
df_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22546 entries, 0 to 23698
# Data columns (total 29 columns):
# total_images               22546 non-null int64
# last_price                 22546 non-null int64
# total_area                 22546 non-null float64
# first_day_exposition       22546 non-null datetime64[ns]
# rooms                      22546 non-null int64
# ceiling_height             22546 non-null float64
# floors_total               22546 non-null int64
# living_area                22546 non-null float64
# floor                      22546 non-null int64
# is_apartment               22546 non-null bool
# studio                     22546 non-null bool
# open_plan                  22546 non-null bool
# kitchen_area               22546 non-null float64
# balcony                    22546 non-null int64
# locality_name              22546 non-null object
# airports_nearest           22546 non-null int64
# cityсenters_nearest        22546 non-null int64
# ...

# %% [markdown]
# ###  Исследован показатель Высота потолков

# %%
# построим гистограмму, чтобы выявить частоту
plt.hist(df_work['ceiling_height'], bins =8, color = '#ccff00', range=(0, 5))
plt.axvline(df_work['ceiling_height'].median(), color='r', linestyle='--', label='median')
plt.axvline(df_work['ceiling_height'].mean(), color='orange', linestyle='--', label='mean')
plt.title('Высота потолков', fontsize=20)
plt.xlabel('потолки, м')
plt.ylabel('частота')
plt.legend()
plt.xticks(rotation=0);

# %%
ceiling_height_mean = df_work['ceiling_height'].mean()
ceiling_height_median = df_work['ceiling_height'].median()
print('Среднее арифметическое значение для ceiling_height - ', ceiling_height_mean)
print('Медианное значение для ceiling_height - ', ceiling_height_median)
# Out:
# Среднее арифметическое значение для ceiling_height -  2.6937385789053487
# Медианное значение для ceiling_height -  2.65

# %% [markdown]
# Описание
#
# Медиана и среднее совпали в данном случае с пиковым значением, самые распространённые параметры высоты - 2,5 - 3,2 , выбросов почти нет.

# %%
ceiling_height_mean = df_work['ceiling_height'].mean()
ceiling_height_median = df_work['ceiling_height'].median()
print('Среднее арифметическое значение для ceiling_height - ', ceiling_height_mean)
print('Медианное значение для ceiling_height - ', ceiling_height_median)
# Out:
# Среднее арифметическое значение для ceiling_height -  2.6937385789053487
# Медианное значение для ceiling_height -  2.65

# %%
# построим диаграмму размаха:
df_work.boxplot('ceiling_height') 
plt.ylim(2, 3);

# %%
df_work = df_work.query('ceiling_height >=2.4 and ceiling_height <=4')
df_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22486 entries, 0 to 23698
# Data columns (total 29 columns):
# total_images               22486 non-null int64
# last_price                 22486 non-null int64
# total_area                 22486 non-null float64
# first_day_exposition       22486 non-null datetime64[ns]
# rooms                      22486 non-null int64
# ceiling_height             22486 non-null float64
# floors_total               22486 non-null int64
# living_area                22486 non-null float64
# floor                      22486 non-null int64
# is_apartment               22486 non-null bool
# studio                     22486 non-null bool
# open_plan                  22486 non-null bool
# kitchen_area               22486 non-null float64
# balcony                    22486 non-null int64
# locality_name              22486 non-null object
# airports_nearest           22486 non-null int64
# cityсenters_nearest        22486 non-null int64
# ...

# %% [markdown]
# ### Исследовано Время продажи квартиры.

# %% [markdown]
# Задание: изучить время продажи квартиры. Построть гистограмму. Посчитать среднее и медиану. Описать, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?
#
# Предположим, что время продажи квартиры соответствует времени размещения объявления.

# %%
# построим структуру данных:
df_work['days_exposition'].describe()
# Out:
# count   22486.00
# mean      157.36
# std       213.71
# min         0.00
# 25%        22.00
# 50%        75.00
# 75%       200.00
# max      1580.00
# Name: days_exposition, dtype: float64

# %%
# построим диаграмму размаха:
df_work.boxplot('days_exposition')
plt.ylim(-10, 1000);

# %%
# построим гистограмму, чтобы выявить частоту
plt.hist(df_work['days_exposition'], bins =40, color = '#ccff00', range=(0, 2500))
plt.axvline(df_work['days_exposition'].median(), color='r', linestyle='--', label='median')
plt.axvline(df_work['days_exposition'].mean(), color='orange', linestyle='--', label='mean')
plt.title('Количество дней', fontsize=20)
plt.xlabel('дней размещения')
plt.ylabel('частота')
plt.legend()
plt.xticks(rotation=0);

# %% [markdown]
# **Описание**
# Среднее арифметическое  -  307 дней. Медианное значение  -  117 дней
#
# Пиковое положение находится в районе медианного показателя, приближено к среднему, однако, имеется "длинный хвост"
# Самые быстрые продажи 1-3 дня, чаще всего период активности объявления занимет 45 дней.
#
# Можно считать, что объявление дисактивировано быстро, если продажа состоялась в срок до 45 дней, а если сделка состоялась через 361 день (год) и больше  - она длилась долго. В целом, это ненормально, что объявления активны по прошествию 3 лет с момента создания. Я принимаю во внимание, что я проставила пропуски расчётным путём, но у меня нет возможности уточнить данные.

# %%
days_of_exposition_mean = df_work['days_exposition'].mean()
days_of_exposition_median = df_work['days_exposition'].median()
print('Среднее арифметическое значение для days_exposition - ', round(days_of_exposition_mean))
print('Медианное значение для days_of_exposition - ', round(days_of_exposition_median))
# Out:
# Среднее арифметическое значение для days_exposition -  157
# Медианное значение для days_of_exposition -  75

# %%
# Устранены выбросы в данных
df_work = df_work.query('days_exposition <= 820')
df_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21962 entries, 0 to 23698
# Data columns (total 29 columns):
# total_images               21962 non-null int64
# last_price                 21962 non-null int64
# total_area                 21962 non-null float64
# first_day_exposition       21962 non-null datetime64[ns]
# rooms                      21962 non-null int64
# ceiling_height             21962 non-null float64
# floors_total               21962 non-null int64
# living_area                21962 non-null float64
# floor                      21962 non-null int64
# is_apartment               21962 non-null bool
# studio                     21962 non-null bool
# open_plan                  21962 non-null bool
# kitchen_area               21962 non-null float64
# balcony                    21962 non-null int64
# locality_name              21962 non-null object
# airports_nearest           21962 non-null int64
# cityсenters_nearest        21962 non-null int64
# ...

# %% [markdown]
# ### Вывод
#
# **В ходе проведения исследовательского анализа данных проведены следующие мероприятия и получены следующие результаты:**
# 1. При исследовании цены выполнено построение графиков в результате установлено: пик смещён влево от центра и медианной линии, а также отражён на графике длинный "хвост". Распределение является асимметричным: основная область расположена в промежутке от 3 до 4,2 млн. Доля выброса данных в столбце last_price:3.7%. Проведены расчёты: среднее арифметическое значение для last_price - 6.5 млн.Медианное значение - 4,6 млн. Устранены выбросы в данных.
# 2.  При исследовании показателя Общая площадь выполнено построение графиков в результате установлено:пик смещён влево от центра и медианной линии, а также отражён на графике длинный "хвост". Распределение является асимметричным и неравномерным. Квартиры площадью менее 20 кв.м. практически не встречаются, в среднем площадь квартиры от 30 до 45 кв.м. Проведены расчёты: среднее арифметическое значение -  60 кв.м. Медианное значение  -  52 кв.м. Устранены выбросы в данных.
# 3. Исследован показатель Количество комнат, выполнено построение графиков в результате установлено: медиана и среднее совпали в данном случае  в области максимальных показателей, самые распространённые квартиры - 2-х комнатные, выбросов почти нет.Проведены расчёты: среднее арифметическое значение для rooms -  2, медианное значение для rooms -  2.
# 4. Исследован показатель Высота потолков, выполнено построение графиков в результате установлено: медиана и среднее совпали в данном случае с пиковым значением, самые распространённые параметры высоты - 2,5 - 4 , выбросов почти нет. Проведены расчёты: среднее арифметическое значение для ceiling_height -  2.72, медианное значение для ceiling_height -  2.7
# 5. Исследовано Время продажи квартиры, выполнено построение графиков в результате установлено:пиковое положение находится в районе медианного показателя, приближено к среднему, однако, имеется "длинный хвост". Самые быстрые продажи 1-3 дня, чаще всего период активности объявления занимет 45 дней. Можно считать, что объявление дисактивировано быстро, если продажа состоялась в срок до 45 дней, а если сделка состоялась через 361 день (год) и больше  - она длилась долго. В целом, это ненормально, что объявления активны по прошествию 3 лет с момента создания. Заполнены пропуски расчётным путём, но у меня нет возможности уточнить данные. Среднее арифметическое  -  307 дней. Медианное значение  -  117 дней.Устранены выбросы в данных.
#
# После проведённых удалений потери данных составили 7,4%

# %% [markdown]
# ### Исследовано влияние факторов на стоимость квартиры

# %% [markdown]
# #### исследована зависимость цены от площади, числа комнат, удалённости от центра

# %%
# создам датафрейм, в который соберу интересующие показатели, установлю корреляцию
data = df_work[['total_area', 'rooms', 'cityсenters_nearest', 'last_price']]
data_corr = data.corr()
data_corr
# Out:
#                      total_area  rooms  cityсenters_nearest  last_price
# total_area                 1.00   0.78                -0.07        0.66
# rooms                      0.78   1.00                -0.05        0.37
# cityсenters_nearest       -0.07  -0.05                 1.00       -0.04
# last_price                 0.66   0.37                -0.04        1.00

# %%
# проиллюстрируем корреляцию
sns.heatmap(data_corr, cmap="coolwarm", annot=True, vmin=-1, vmax=1)

# %% [markdown]
# **Описание**
#
# Цена имеет следующие корреляции с выбранными показателями:
#
# сильную и прямую с общей площадью;
#
# прямую и менее выраженную с количеством комнат;
#
# обратную слабую с удалённостью от центра.

# %%
# выведем графики взаимозависимости цены от числа комнат
data.plot(kind = 'scatter', y = 'rooms', x = 'last_price');

# %% [markdown]
# Из графика видно следующее: самые дорогие квартиры - 3-х комнатные. Имеет место нелинейная зависимость: в диапазоне от 1 до 3 комнат цена возрастает, в диапазоне 4 - 6 снижается.

# %%
# выведем графики взаимозависимости цены от площади
data.plot(kind = 'scatter', y = 'total_area', x = 'last_price');

# %% [markdown]
# При увеличении площади цена возрастает

# %%
# выведем графики взаимозависимости цены от удалённости от центра
data.plot(kind = 'scatter', y = 'cityсenters_nearest', x = 'last_price');

# %% [markdown]
# Из графика видно следующее: цена в центре выше, чем при отдалении

# %% [markdown]
# **Описание**
#
# Из графиков видно следующее:
#
# имеет место нелинейная зависимость от количества комнат: в диапазоне от 1 до 3 комнат цена возрастает, в диапазоне 4 - 6 снижается;
#
# прямая зависимость от площади;
#
# обратная зависимость от удалённости от центра.

# %% [markdown]
# #### Исследована зависимость от даты размещения: дня недели, месяца и года.

# %%
# создам датафрейм, в который соберу интересующие показатели, установлю корреляцию
data_els = df_work[['floor_type','weekday' , 'month', 'year', 'price_per_meter']]

# %%
# выведем график взаимозависимости цены от дня недели
data_els.plot(kind = 'scatter', y = 'weekday', x = 'price_per_meter', grid=True);

# %%
# выведем график взаимозависимости цены от месяца
data_els.plot(kind = 'scatter', y = 'price_per_meter', x = 'month', grid=True);

# %%
# выведем график взаимозависимости цены от года
data_els.plot(kind = 'scatter', y = 'price_per_meter', x = 'year', grid=True);

# %% [markdown]
# **Описание**
#
# Цена выше в объявлениях, размещённых среди недели и ниже всего в воскресных.
#
# Цена за квадратный метр выше в сентябрьских объявлениях и ниже всего в октябрьских.
#
# Цена за квадратный метр выше в объявлениях, размещённых в 2017, 2019гг.

# %%
# создам дополнительный датафрейм
data_time = df_work[['last_price', 'days_exposition' ]]
data_time
# Out:
#        last_price  days_exposition
# 0        13000000                0
# 1         3350000               81
# 2         5196000              558
# 3        64900000              424
# 4        10000000              121
# ...           ...              ...
# 23694     9700000                0
# 23695     3100000               45
# 23696     2500000                0
# 23697    11475000              602
# 23698     1350000                0
#
# [21962 rows x 2 columns]

# %%
# выведем график взаимозависимости цены от длительности размещения объявления
data_time.plot(kind = 'scatter', y = 'last_price', x = 'days_exposition');

# %% [markdown]
# Из графика видно следующее: мягкое снижение цены при увеличении длительности размещения объявления

# %%
# код от ревьюера

( pd.DataFrame(df_work.groupby(['year', 'month'])['price_per_meter']
                 .mean())
                 .sort_values(['year'],ascending=True)
                 .plot(figsize=(18,5)) 
);

# %% [markdown]
# **Обобщённый вывод при исследовании временной зависимости**
#
# Цена выше в объявлениях, размещённых среди недели и ниже всего в воскресных.
#
# Цена за квадратный метр выше в сентябрьских объявлениях и ниже всего в октябрьских.
#
# Цена за квадратный метр выше в объявлениях, размещённых в 2017, 2019гг.
#
# Мягкое снижение цены при увеличении длительности размещения объявления.

# %% [markdown]
# #### Исследована зависимость цены от того, на каком этаже расположена квартира: в вариантах: первом, последнем или другом.

# %%
# создам датафрейм, в который соберу интересующие показатели, установлю корреляцию
data_elss = df_work[['floor_type','price_per_meter']]

# %%
for col in data_elss.drop(columns='price_per_meter').columns:
  plt.figure(figsize=(10, 3), dpi=80)
  (data_elss[col]
    .value_counts()
    .sort_values()
    [:20]
    .plot.bar(rot=45))
  plt.title(col)
  plt.show()

# %%
# воспользуюсь предложением
( pd.DataFrame(df_work.groupby(['floor_type'])['price_per_meter']
                 .mean())
                 .sort_values(['floor_type'],ascending=True)
                 .plot(figsize=(5,5)) 
);

# %%
df_work.groupby('floor_type')['price_per_meter'].mean().plot.bar();

# %% [markdown]
# **Описание**
#
# Цена за квадратный метр выше в объявлениях, в которых указана категория "другой" этаж и примерно одинаковая для категорий "первый" и "последний".

# %% [markdown]
# #### 10 населённых пунктов
# Задача:
#
# Выберать 10 населённых пунктов с наибольшим числом объявлений.
#
# Посчитать среднюю цену квадратного метра в этих населённых пунктах.
#
# Выделить среди них населённые пункты с самой высокой и низкой стоимостью жилья.

# %%
# датафрейм, в котором локация и цена за квадратный метр, создам сводную таблицу
ten_cities = df_work.loc[:, ['locality_name', 'price_per_meter']]
ten_cities = ten_cities.pivot_table(index='locality_name', values='price_per_meter', aggfunc=['count', 'mean'])
ten_cities.columns = ['count', 'mean_price']

# десятка самых дорогих городов
top_ten_cities = ten_cities.sort_values(by='count', ascending=False).head(10)
top_ten_cities
# Out:
#                    count  mean_price
# locality_name
# Санкт-Петербург    14536   113161.37
# посёлок Мурино       485    85145.36
# посёлок Шушары       419    77919.88
# Всеволожск           374    68668.55
# Пушкин               347   102956.33
# Колпино              328    75179.25
# посёлок Парголово    318    90280.21
# Гатчина              293    68691.49
# деревня Кудрово      261    91869.71
# Выборг               214    58084.48

# %%
# самая высокая средняя стоимость жилья
top_ten_cities.query('mean_price == mean_price.max()')
# Out:
#                  count  mean_price
# locality_name
# Санкт-Петербург  14536   113161.37

# %%
# самая низкая средняя стоимость жилья
top_ten_cities.query('mean_price == mean_price.min()')
# Out:
#                count  mean_price
# locality_name
# Выборг           214    58084.48

# %% [markdown]
# Описание
#
# В Петербурге самая высокая стоимость жилья.
#
# В Выборге самая низкая стоимость жилья.

# %%
# выведем график взаимозависимости цены от длительности размещения объявления

top_ten_cities.plot(y='count', kind='pie', figsize=(7, 7));

# %%
# выведем график взаимозависимости цены от длительности размещения объявления

top_ten_cities.plot(y='mean_price', kind='bar', figsize=(7, 7));

# %% [markdown]
# #### Выделить и исследовать продажу квартир в центре.
#
# Задача:
# выяснить, какая область входит в центр. Создать столбец с расстоянием до центра в километрах: округлить до целых значений. После этого посчитать среднюю цену для каждого километра. Построить график: он должен показывать, как цена зависит от удалённости от центра. Определить границу, где график сильно меняется, — это и будет центральная зона.
# Выделить сегмент квартир в центре. Проанализировать эту территорию и изучить следующие параметры: площадь, цена, число комнат, высота потолков. Также выделить факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайть выводы. Отличаются ли они от общих выводов по всему городу?

# %%
# соберу  в новый датафрейм интресующие показатели
piter = df_work[['cityсenters_nearest', 'locality_name', 'total_area', 'last_price','rooms', 
                       'ceiling_height','floor_type' ]]

# только питерские объявления
piter = piter.query('locality_name == "Санкт-Петербург"')

# расстояние до центра в км.
piter['km_for_center'] = (piter['cityсenters_nearest']/1000).round()
piter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14536 entries, 0 to 23697
# Data columns (total 8 columns):
# cityсenters_nearest    14536 non-null int64
# locality_name          14536 non-null object
# total_area             14536 non-null float64
# last_price             14536 non-null int64
# rooms                  14536 non-null int64
# ceiling_height         14536 non-null float64
# floor_type             14536 non-null object
# km_for_center          14536 non-null float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 1022.1+ KB

# %%
# создам сводную таблицу для рассчётов
piter_pivot = piter.pivot_table(index='km_for_center', values='last_price', aggfunc=('mean'))
piter_pivot
# Out:
#                last_price
# km_for_center
# 0.00          26439214.29
# 1.00          16487499.37
# 2.00          14456575.49
# 3.00          10267936.82
# 4.00          10878597.25
# 5.00          11742844.03
# 6.00          12266384.29
# 7.00          13609743.58
# 8.00           8969487.21
# 9.00           7058779.47
# 10.00          6483747.71
# 11.00          6154268.14
# 12.00          6142001.37
# 13.00          6112706.39
# 14.00          5640928.92
# 15.00          5876081.20
# 16.00          5432166.52
# 17.00          5330804.39
# 18.00          4983969.54
# 19.00          5056650.45
# 20.00          6117372.82
# 21.00          5631023.34
# 22.00          5478927.72
# 23.00          4997666.67
# 24.00          3958608.70
# 25.00          4289492.64
# 26.00          3996902.90
# 27.00          8300000.00
# 28.00          5026428.57
# 29.00          4210000.00

# %%
# создам график Зависимость цены от расстояния до центра Петербурга
piter_pivot.plot(grid=True, figsize=(8, 6), title='Зависимость цены от расстояния до центра Петербурга')
plt.show()

# %% [markdown]
# Определим границу центра г. Санкт-петербургаЖ где график сильно меняется — это и будет центральная зона.
#
# Согласно получившейся кривой, самые высокие цены в диапазоне  от центра до 3 км. 5 км — это и будет центральная зона.

# %%
#Нужно исследовать как факторы влияют на продажи недвижимости в целом по городу Санкт-Петербургу, 
# а также на реализацию квартир в центре. Создам датафрейм с аналогичным набором факторов для центра.
# удалю столбец первичного датафрейма с расстоянием в метрах
piter = piter.drop(['cityсenters_nearest'], axis = 1)

piter_center = piter
piter_center = piter_center.query('km_for_center <=5')

piter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14536 entries, 0 to 23697
# Data columns (total 7 columns):
# locality_name     14536 non-null object
# total_area        14536 non-null float64
# last_price        14536 non-null int64
# rooms             14536 non-null int64
# ceiling_height    14536 non-null float64
# floor_type        14536 non-null object
# km_for_center     14536 non-null float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 908.5+ KB

# %% [markdown]
# **Оценим влияние следующих факторов на цену продажи жилья в Санкт-Петербурге и его центральной части:  площадь, число комнат, высота потолков, тип этажа, удалённость от центра, дата размещения объявления.**

# %%
piter_center_corr = piter_center.corr()

piter_corr = piter.corr()
# исследуем корреляции для центра Питера

sns.heatmap(piter_center_corr, cmap="coolwarm", annot=True, vmin=-1, vmax=1);

# %%
( pd.DataFrame(df_work.groupby(['days_exposition'])['price_per_meter']
                 .mean())
                 .sort_values(['days_exposition'],ascending=True)
                 .plot(figsize=(18,5)) 
);

# %% [markdown]
# Количество дней размещения объявления не имеет однозначного влияния: после 500 дней активности возникают скачки, что довольно трудно объяснимо, так как многие даты остались не заполненными, а период уже в прошлом.

# %%
piter_center['days_exposition']=df_work['days_exposition']
piter_center['price_per_meter']=df_work['price_per_meter']
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
( pd.DataFrame(piter_center.groupby(['days_exposition'])['price_per_meter']
                 .mean())
                 .sort_values(['days_exposition'],ascending=True)
                 .plot(figsize=(18,5)) 
);

# %% [markdown]
# Количество дней размещения объявления для Центра не имеет однозначного влияния: значительные скачки наблюдаются во всех периодах

# %% [markdown]
# **Описание**
#
# На продажи в центре Питера имеет прямое сильное влияние площадь.  Имеет место прямая зависимость цены от количества комнат и в меньшей степени от высоты потолков.

# %%
df_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21962 entries, 0 to 23698
# Data columns (total 29 columns):
# total_images               21962 non-null int64
# last_price                 21962 non-null int64
# total_area                 21962 non-null float64
# first_day_exposition       21962 non-null datetime64[ns]
# rooms                      21962 non-null int64
# ceiling_height             21962 non-null float64
# floors_total               21962 non-null int64
# living_area                21962 non-null float64
# floor                      21962 non-null int64
# is_apartment               21962 non-null bool
# studio                     21962 non-null bool
# open_plan                  21962 non-null bool
# kitchen_area               21962 non-null float64
# balcony                    21962 non-null int64
# locality_name              21962 non-null object
# airports_nearest           21962 non-null int64
# cityсenters_nearest        21962 non-null int64
# ...

# %%
data_data = df_work[['year','month', 'price_per_meter' ]]
er =data_data.pivot_table(index=['year','month'], values='price_per_meter', aggfunc=['count', 'mean'])
er.columns = ['count', 'mean_price']

# %%
er.reset_index().sort_values(by = 'year', ascending = False)
# Out:
#     year  month  count  mean_price
# 54  2019      5     58   115524.41
# 53  2019      4    908   104465.15
# 52  2019      3    846   106279.38
# 51  2019      2    544   111021.77
# 50  2019      1    403   101988.37
# 44  2018      7    807    94852.01
# 38  2018      1    549    93868.11
# 39  2018      2   1240    93530.88
# 40  2018      3    957    93136.34
# 41  2018      4    283   105164.16
# 43  2018      6    497    96446.65
# 42  2018      5    142   103919.25
# 45  2018      8    784   100872.82
# 46  2018      9    744    99324.66
# 47  2018     10    874    97844.98
# 48  2018     11    800   100103.25
# 49  2018     12    346   100532.72
# 28  2017      3    215    92930.01
# 37  2017     12    817    95058.97
# 36  2017     11   1176    96030.73
# 35  2017     10    896    95471.99
# 34  2017      9    953    98181.82
# 33  2017      8    713    98352.03
# 32  2017      7    555    99921.51
# 31  2017      6    645    92210.36
# 30  2017      5    533    94043.81
# ...

# %%
er.reset_index().sort_values(by = 'count', ascending = False)
# Out:
#     year  month  count  mean_price
# 39  2018      2   1240    93530.88
# 36  2017     11   1176    96030.73
# 40  2018      3    957    93136.34
# 34  2017      9    953    98181.82
# 53  2019      4    908   104465.15
# 35  2017     10    896    95471.99
# 47  2018     10    874    97844.98
# 52  2019      3    846   106279.38
# 37  2017     12    817    95058.97
# 44  2018      7    807    94852.01
# 48  2018     11    800   100103.25
# 45  2018      8    784   100872.82
# 46  2018      9    744    99324.66
# 33  2017      8    713    98352.03
# 31  2017      6    645    92210.36
# 29  2017      4    610    95685.55
# 32  2017      7    555    99921.51
# 38  2018      1    549    93868.11
# 51  2019      2    544   111021.77
# 30  2017      5    533    94043.81
# 43  2018      6    497    96446.65
# 27  2017      2    423    97507.53
# 19  2016      6    421   101274.89
# 50  2019      1    403   101988.37
# 18  2016      5    390    97513.46
# 17  2016      4    383    91700.42
# ...

# %%
er.reset_index().sort_values(by = 'mean_price', ascending = False)
# Out:
#     year  month  count  mean_price
# 0   2014     11      8   139451.38
# 2   2015      1     36   121661.92
# 1   2014     12     59   117343.15
# 54  2019      5     58   115524.41
# 10  2015      9     48   114508.77
# 3   2015      2     27   112534.41
# 7   2015      6     65   112274.17
# 51  2019      2    544   111021.77
# 52  2019      3    846   106279.38
# 41  2018      4    283   105164.16
# 53  2019      4    908   104465.15
# 13  2015     12    134   104030.28
# 42  2018      5    142   103919.25
# 50  2019      1    403   101988.37
# 19  2016      6    421   101274.89
# 45  2018      8    784   100872.82
# 49  2018     12    346   100532.72
# 4   2015      3     47   100500.36
# 26  2017      1    278   100421.69
# 23  2016     10    113   100308.45
# 48  2018     11    800   100103.25
# 32  2017      7    555    99921.51
# 46  2018      9    744    99324.66
# 8   2015      7     67    99115.54
# 33  2017      8    713    98352.03
# 11  2015     10    114    98290.71
# ...

# %% [markdown]
# Проведено иное исследование относительно временного влияния:
#
# 1. будь у нас id-объявления, было бы намного легче;
# 2. Количество дней размещения объявления не имеет однозначного влияния: после 500 дней активности возникают скачки, что довольно трудно объяснимо, так как многие даты остались не заполненными, а период уже в прошлом. Количество дней размещения объявления для Центра не имеет однозначного влияния: значительные скачки наблюдаются во всех периодах.
# 3. Картина не может быть реалистичной, так как имеется информация за неполные периоды 5 лет: 2 месяца 2014г, 5 меясцев 2019г (даже можно сказать 4, последняя дата 03.05.) и 2015-2018гг.
# 4. По имеющимся данным больше всего объявлений было размещено в феврале 2018 - 1238	со средней ценой за метр - 93566.63 (данные за полный год). В ноябре 2014	было размещено 	8 объявлений со средней ценой за метр -	139451.38 (данные только за месяца).
#
# Сделать однозначный вывод о влиянии времени на цену невозможно на имеющемся материале.

# %%
# исследуем корреляции для Сантк-петербурга в целом
sns.heatmap(piter_corr, cmap="coolwarm", annot=True, vmin=-1, vmax=1);

# %% [markdown]
# ### Вывод
#
# **Описание**
#
# На продажи в Санкт-Петербурге в целом имеет прямое сильное влияние площадь.  Прямая зависимость цены от количества комнат и в меньшей степени от  высоты потолков. Обратно пропорциональная зависимость наблюдается цены и удалённости от центра города.
#
# Количество дней размещения объявления не имеет однозначного влияния.
#
# Картина не может быть реалистичной, так как имеется информация за неполные периоды 5 лет: 2 месяца 2014г, 5 меясцев 2019г (даже можно сказать 4, последняя дата 03.05.) и 2015-2018гг.
#
# Сделать однозначный вывод о влиянии времени на цену невозможно на имеющемся материале.

# %% [markdown]
# **При исследовании влияния факторов на стоимость квартиры получены следующие результаты**:
# 1. исследована зависимость цены от площади, числа комнат, удалённости от центра, результат: имеет место нелинейная зависимость от количества комнат: в диапазоне от 1 до 3 комнат цена возрастает, в диапазоне 4 - 6 снижается; прямая зависимость от площади;
# обратная зависимость от удалённости от центра.
#
# 2. исследована зависимость от даты размещения: дня недели, месяца и года, результат: цена за квадратный метр выше в объявлениях, размещённых в четверг и ниже всего в воскресных. Цена за квадратный метр выше в сентябрьских объявлениях и ниже всего в майских.
#
# 3. Исследована зависимость цены от того, на каком этаже расположена квартира: в вариантах: первом, последнем или другом. Результат: цена за квадратный метр выше в объявлениях, в которых указана категория "другой" этаж и примерно одинаковая для категорий "первый" и "последний".
#
# 4. При исследовании 10 населённых пунктов с максимальными ценами на недвижимость установлено, что в Петербурге самая высокая стоимость жилья, в Выборге самая низкая стоимость жилья (из сформированного списка).
#
# **5. Сравнение зависимости цен при реализации жилья в центре Санкт-Петербурга и городе в целом:**
# 1. На продажи в центре Питера имеет прямое сильное влияние площадь, как и в городе в целом.
# 2. Продажи в центре Питера имеют прямую зависимость цены от количества комнат, как и в городе в целом.
# 3. Продажи в центре Питера имеют прямую слабую зависимость цены от от высоты потолков, как и в городе в целом.
# 4. Установить однозначную зависимость от дня, месяца и года размещения объявления не удалось. Выявлена мягкая динамика снижения цены при увеличении длительности размещения объявления.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **В ходе выполнения проекта**
#
# **произведено первичное исследование тематики в открытых источниках;**
#
# **проанализированы данные первичного датафрейма;**
#
# **устранены пропуски посредством:** 1. удаления  (locality_name: 0,2%, малая доля в ceiling_height, floors_total:0.4%); 2. замены расчётными показателями (ceiling_height:39%, kitchen_area:9.6%, living_area:8.0%, сityсenters_nearest:23.3%, days_exposition:7.4%); 3. замены нулевым показателем - как отметки об отсутствии данных (Доля пропусков в столбце balcony:48.6%, если человек не указал число балконов — скорее всего, их нет. Для airports_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest произведу замену пропусков на 0. Доля пропусков в столбце is_apartment:88.3%).
#
# **Для расчёта введён расчётный столбец days_of_exposition - количество дней активности объявления.**
#
# **Причинами появления пропусков могут быть:** невнимательность при вводе;отсутствие котрольных точек при размещении объявления;
#
# отсутствие режима автозаполнения;отсутствие актуальных баз.
#
# **В ходе выполнения проекта выполнены в соответствии с заданием расчёты с добавлением столбцов в датафрейм**: 1. Расчёт цены квадратного метра. Добавлен столбец price_per_meter. 2. Расчёт дня недели(добавлен столбец weekday), месяца(добавлен столбец month) и года(добавлен столбец year) публикации объявления. 3. Этаж квартиры cгруппирован по вариантам — первый, последний, другой. Добавлен столбец floor_type. 4. Рассчитаны соотношения жилой и общей площади (добавлен столбец living_area_share_calc), а также площади кухни к общей (добавлен столбец kitchen_area_share_calc).
#
# **В ходе проведения исследовательского анализа данных проведены следующие мероприятия и получены следующие результаты:**
#
# 1. При исследовании цены выполнено построение графиков в результате установлено: пик смещён влево от центра и медианной линии, а также отражён на графике длинный "хвост". Распределение является асимметричным: основная область расположена в промежутке от 3 до 4,2 млн. Доля выброса данных в столбце last_price:8.7%. Проведены расчёты: среднее арифметическое значение для last_price - 6.5 млн.Медианное значение - 4,6 млн. Устранены выбросы в данных.
#
# 2.  При исследовании показателя Общая площадь выполнено построение графиков в результате установлено:пик смещён влево от центра и медианной линии, а также отражён на графике длинный "хвост". Распределение является асимметричным и неравномерным. Квартиры площадью менее 20 кв.м. практически не встречаются, в среднем площадь квартиры от 30 до 45 кв.м. Проведены расчёты: среднее арифметическое значение -  60 кв.м. Медианное значение  -  52 кв.м. Устранены выбросы в данных.
#
# 3. Исследован показатель Количество комнат, выполнено построение графиков в результате установлено: медиана и среднее совпали в данном случае  в области максимальных показателей, самые распространённые квартиры - 2-х комнатные, выбросов почти нет.Проведены расчёты: среднее арифметическое значение для rooms -  2, медианное значение для rooms -  2.
#
# 4. Исследован показатель Высота потолков, выполнено построение графиков в результате установлено: медиана и среднее совпали в данном случае с пиковым значением, самые распространённые параметры высоты - 2,5 - 4 , выбросов почти нет. Проведены расчёты: среднее арифметическое значение для ceiling_height -  2.72, медианное значение для ceiling_height -  2.7.
#
# 5. Исследовано Время продажи квартиры, выполнено построение графиков в результате установлено:пиковое положение находится в районе медианного показателя, приближено к среднему, однако, имеется "длинный хвост". Самые быстрые продажи 1-3 дня, чаще всего период активности объявления занимет 45 дней. Можно считать, что объявление дисактивировано быстро, если продажа состоялась в срок до 45 дней, а если сделка состоялась через 361 день (год) и больше  - она длилась долго. В целом, это ненормально, что объявления активны по прошествию 3 лет с момента создания. Заполнены пропуски расчётным путём, но у меня нет возможности уточнить данные. Среднее арифметическое  -  307 дней. Медианное значение  -  117 дней.Устранены выбросы в данных.
#
# **После проведённых удалений потери данных составили 7,4%.**
#
# **При исследовании влияния факторов на стоимость квартиры получены следующие результаты**:
#
# 1. исследована зависимость цены от площади, числа комнат, удалённости от центра, результат: имеет место нелинейная зависимость от количества комнат: в диапазоне от 1 до 3 комнат цена возрастает, в диапазоне 4 - 6 снижается; прямая зависимость от площади;
# обратная зависимость от удалённости от центра.
#
# 2. исследована зависимость от даты размещения: дня недели, месяца и года, результат: цена за квадратный метр выше в объявлениях, размещённых в четверг и ниже всего в воскресных. Цена за квадратный метр выше в сентябрьских объявлениях и ниже всего в майских.
#
# 3. Исследована зависимость цены от того, на каком этаже расположена квартира: в вариантах: первом, последнем или другом. Результат: цена за квадратный метр выше в объявлениях, в которых указана категория "другой" этаж и примерно одинаковая для категорий "первый" и "последний".
#
# 4. При исследовании 10 населённых пунктов с максимальными ценами на недвижимость установлено, что в Петербурге самая высокая стоимость жилья, в Выборге самая низкая стоимость жилья (из сформированного списка).
#
# **5. Сравнение зависимости цен при реализации жилья в центре Санкт-Петербурга и городе в целом:**
# 1. На продажи в центре Питера имеет прямое сильное влияние площадь, как и в городе в целом.
# 2. Продажи в центре Питера имеют прямую зависимость цены от количества комнат, как и в городе в целом.
# 3. Продажи в центре Питера имеют прямую слабую зависимость цены от от высоты потолков, как и в городе в целом.
# 4. Установить однозначную зависимость от дня, месяца и года размещения объявления не удалось.Выявлена мягкая динамика снижения цены при увеличении длительности размещения объявления.

# %% [markdown]
# # ИТОГОВЫЙ ВЫВОД:
# Цена недвижимости в центре Питера как и в городе в целом имеют зависимость от следующих факторов
# площадь (в значительной степени),
# количество комнат (в меньшем объёме),
# высота потолков (слабо),
#
# Различия зафиксированы в незначительном объёме:
# в зависимости от месяца размещения объявления:
# в центральном сегменте - в марте и декабре цены выше,
# цена за квадратный метр в целом по городу выше в сентябрьских объявления.
#
# Полученный результат соответствует сведениям открытых источников.

# %% [markdown]
# **Баг-репорт.**
#
# **Дата фрейм содержал пропуски в следующих категориях данных, вносимых продавцом:**
# Доля пропусков в столбце ceiling_height:39%.
# Доля пропусков в столбце kitchen_area:9.6%.
# Доля пропусков в столбце living_area:8.0%.
# Доля пропусков в столбце balcony:48.6%.
# Доля пропусков в столбце days_exposition:7.4%.
# Доля пропусков в столбце is_apartment:88.3%.
#
# **Дата фрейм содержал пропуски в следующих категориях данных, полученных автоматически:**
# Доля пропусков в столбце airports_nearest:23.4%
# Доля пропусков в столбце cityсenters_nearest:23.3%.
# Доля пропусков в столбце parks_around3000:23.3%.
# Доля пропусков в столбце parks_nearest:65.9%.
# Доля пропусков в столбце ponds_nearest:61.6%.
#
# **Дата фрейм содержит значительные выбросы в следующих категориях данных:**
# Доля выброса данных в столбце last_price:8.6%.
# Доля выброса данных в столбце cityсenters_nearest:7.2%.
#
# **Предлагается:**
#
# ввести режим автозаполнения для всех позиций;
#
# обновить или заменить базы, применяемые для внесения автоматических данных;
#
# проанализировать выбросы данных;
#
# провести аудит дат и сроков активности объявлений.
#
# **ввести id-объявления**
#
# **предоставить данные за полные периоды**

# %% [markdown]
# Спасибо за внимание!:)

# %%
# код ревьюера
spb_city_center = piter_center.query('km_for_center <=8')

# %%
import seaborn as sns

# %%
# создаем выборки
df_spb = pd.DataFrame(spb_city_center.last_price)
df_all = pd.DataFrame(df_work.last_price)

list_name = ['Вся выборка',  'Центр Питера']

# строим графики
plt.figure(figsize=(15, 2))
ax = sns.boxplot(x = [df_all,  df_spb], y = list_name , orient = 'h', palette = 'husl')

# масштаб оси
plt.xlim(0, 20_000_000)

# размер заголовка
ax.set_title('Сравнение цен за кв. м. на 2-х выборках',
                fontfamily = 'monospace',
                fontstyle = 'normal',
                fontsize = 14)

# размер подписей оси y
ax.set_yticklabels(list_name, fontsize = 12, fontfamily = 'monospace');

# %% [markdown]
# # Диаграмма рассеяния при помощи библиотеки сиборн

# %%
sns.pairplot(df_work[['last_price', 'total_area', 'cityсenters_nearest', 'rooms', 'ceiling_height']]);
